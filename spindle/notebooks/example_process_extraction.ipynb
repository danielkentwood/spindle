# %% [markdown]
# # Process DAG Extraction and Graph Ingestion
#
# This walkthrough shows how to extract a directed acyclic graph (DAG) representing a business process from raw text with `spindle.extractor.extract_process_graph`, and then persist it as triples inside the embedded Kùzu-backed `GraphStore`.

# %% [markdown]
# ## Prerequisites
#
# - Install dependencies (if you have not already):
#   ```bash
#   uv pip install kuzu pandas
#   ```
# - Make sure the Spindle package is installed in editable mode so notebook imports resolve correctly.

# %%
from __future__ import annotations

import json
from datetime import datetime

import pandas as pd

from spindle import extractor, triples_to_dict
from spindle.graph_store import GraphStore
from spindle.baml_client.types import (
    AttributeValue,
    CharacterSpan,
    Entity,
    ProcessExtractionResult,
    ProcessGraph,
    SourceMetadata,
    Triple,
)

# %% [markdown]
# ## 1. Provide a process narrative
#
# We will work with a short operations playbook describing how support tickets are triaged and resolved. The text intentionally contains parallel work and a feedback loop so we can see how the DAG captures dependencies.

# %%
sample_text = """
When a new customer ticket arrives, the support lead logs it in the tracker and assigns an initial priority.
High-priority tickets require an on-call engineer to begin diagnosis immediately while the support lead notifies the customer that work has started.
For medium and low priority tickets, an agent drafts a response template and checks previous similar cases before the engineer is looped in.
After an engineer finishes investigating, they post a root-cause summary and proposed fix.
The support lead reviews the fix, confirms customer communication, and, if the customer reports success, closes the ticket.
If the fix fails, the lead reopens the ticket and the engineer repeats the diagnosis step.
"""

process_hint = "Customer support ticket resolution workflow"
print(sample_text)
# Out:
# When a new customer ticket arrives, the support lead logs it in the tracker and assigns an initial priority.
# High-priority tickets require an on-call engineer to begin diagnosis immediately while the support lead notifies the customer that work has started.
# For medium and low priority tickets, an agent drafts a response template and checks previous similar cases before the engineer is looped in.
# After an engineer finishes investigating, they post a root-cause summary and proposed fix.
# The support lead reviews the fix, confirms customer communication, and, if the customer reports success, closes the ticket.
# If the fix fails, the lead reopens the ticket and the engineer repeats the diagnosis step.

# %% [markdown]
# ## 2. Extract the process DAG
#
# `extract_process_graph` returns a `ProcessExtractionResult` with a structured `ProcessGraph`. We pass the optional `process_hint` to provide extra context for the model.

# %%
result: ProcessExtractionResult = extractor.extract_process_graph(
    text=sample_text,
    process_hint=process_hint,
)

result.status, len(result.issues)
# Out:
# 2025-11-07T16:12:01.859 [BAML INFO] Function ExtractProcessGraph:
#     Client: CustomHaiku (claude-3-5-haiku-20241022) - 24045ms. StopReason: end_turn. Tokens(in/out): 1206/1735
#     ---PROMPT---
#     user: You are a process modelling specialist. Extract a directed acyclic graph (DAG) that captures the end-to-end process described in the provided text. Represent the process with well-defined steps and explicit dependencies.TEXT:
#
#     When a new customer ticket arrives, the support lead logs it in the tracker and assigns an initial priority.
#     High-priority tickets require an on-call engineer to begin diagnosis immediately while the support lead notifies the customer that work has started.
#     For medium and low priority tickets, an agent drafts a response template and checks previous similar cases before the engineer is looped in.
#     After an engineer finishes investigating, they post a root-cause summary and proposed fix.
#     The support lead reviews the fix, confirms customer communication, and, if the customer reports success, closes the ticket.
#     If the fix fails, the lead reopens the ticket and the engineer repeats the diagnosis step.
#
#
#     PROCESS HINT:
#     Customer support ticket resolution workflow
#
#
#     OUTPUT REQUIREMENTS:
#     1. Return status "no_process" if the text lacks procedural content.
#     2. Always ensure dependency targets reference defined step identifiers.
#     3. Identify start and end steps explicitly using computed arrays.
#     4. Capture conditional flows, loops described as repeated checks, and parallel work using step types and dependency relation labels.
#     5. Provide issues for ambiguous, conflicting, or incomplete information rather than guessing.
#     6. Summarise reasoning with numbered bullet points that justify the chosen structure and highlight any assumptions.
#
#     ProcessStepType
#     ----
#     - ACTIVITY: Linear action that advances the process
#     - DECISION: Branching evaluation that selects one of multiple paths
#     - EVENT: External trigger or milestone that influences the process
#     - PARALLEL_GATEWAY: Point where multiple activities run concurrently
#     - SUBPROCESS: Reference to a nested process or reusable routine
#
#     Answer in JSON using this schema:
#     {
#       // Outcome of the extraction attempt
#       status: "process_found" or "no_process" or "incomplete",
#       // Structured representation of the process when available
#       graph: {
#         // Human-readable name or title for the overall process
#         process_name: string or null,
#         // Short description of the process boundaries or context
#         scope: string or null,
#         // Statement summarising the overall objective of the process
#         primary_goal: string,
#         // Identifiers of steps that have no incoming dependencies
#         start_step_ids: string[],
#         // Identifiers of steps that have no outgoing dependencies
#         end_step_ids: string[],
#         // All steps that participate in the process
#         steps: [
#           {
#             // Stable identifier used for references and dependencies
#             step_id: string,
#             // Short human-readable name for the step
#             title: string,
#             // Concise explanation of what happens during this step
#             summary: string,
#             // Category that characterises the behaviour of the step
#             step_type: ProcessStepType,
#             // People, roles, or systems responsible for executing the step
#             actors: string[],
#             // Key inputs, prerequisites, or artifacts consumed by this step
#             inputs: string[],
#             // Artifacts, decisions, or state transitions produced by this step
#             outputs: string[],
#             // Estimated timing or duration information if mentioned
#             duration: string or null,
#             // Step identifiers that must be completed before this step starts
#             prerequisites: string[],
#             // Supporting text spans drawn from the source material
#             evidence: [
#               {
#                 // Exact excerpt from the source that supports the step or dependency
#                 text: string,
#                 // Zero-based start index of the span within the text
#                 start: int or null,
#                 // End index (exclusive) of the span within the text
#                 end: int or null,
#               }
#             ],
#           }
#         ],
#         // Directed edges connecting steps to form a DAG
#         dependencies: [
#           {
#             // Identifier of the antecedent step
#             from_step: string,
#             // Identifier of the dependent step
#             to_step: string,
#             // Nature of the dependency, e.g., 'precedes', 'blocks', 'enables'
#             relation: string,
#             // Conditional logic or guard that must be satisfied for the dependency
#             condition: string or null,
#             // Supporting spans demonstrating this dependency in the text
#             evidence: [
#               {
#                 // Exact excerpt from the source that supports the step or dependency
#                 text: string,
#                 // Zero-based start index of the span within the text
#                 start: int or null,
#                 // End index (exclusive) of the span within the text
#                 end: int or null,
#               }
#             ],
#           }
#         ],
#         // Additional remarks, open questions, or caveats captured by the model
#         notes: string[],
#       } or null,
#       // Narrative justification covering modelling choices and DAG structure
#       reasoning: string,
#       // Non-fatal problems encountered during extraction
#       issues: [
#         {
#           // Machine-friendly identifier describing the issue
#           code: string,
#           // Human-readable explanation of the issue or warning
#           message: string,
#           // Step identifiers relevant to this issue
#           related_step_ids: string[],
#         }
#       ],
#     }
#
#     ---LLM REPLY---
#     {
#       "status": "process_found",
#       "graph": {
#         "process_name": "Customer Support Ticket Resolution",
#         "scope": "End-to-end ticket handling workflow",
#         "primary_goal": "Resolve customer support tickets efficiently and effectively",
#         "start_step_ids": ["ticket_arrival"],
#         "end_step_ids": ["ticket_closure"],
#         "steps": [
#           {
#             "step_id": "ticket_arrival",
#             "title": "Ticket Logging",
#             "summary": "New customer ticket enters the support system",
#             "step_type": "EVENT",
#             "actors": ["Support Lead"],
#             "inputs": ["Customer Ticket"],
#             "outputs": ["Logged Ticket", "Initial Priority"],
#             "prerequisites": [],
#             "evidence": [
#               {
#                 "text": "When a new customer ticket arrives, the support lead logs it in the tracker and assigns an initial priority.",
#                 "start": 0,
#                 "end": 108
#               }
#             ]
#           },
#           {
#             "step_id": "priority_handling",
#             "title": "Priority-Based Routing",
#             "summary": "Determine ticket handling approach based on priority",
#             "step_type": "DECISION",
#             "actors": ["Support Lead"],
#             "inputs": ["Initial Priority"],
#             "outputs": ["Routing Decision"],
#             "prerequisites": ["ticket_arrival"],
#             "evidence": [
#               {
#                 "text": "High-priority tickets require an on-call engineer to begin diagnosis immediately while the support lead notifies the customer that work has started.",
#                 "start": 109,
#                 "end": 259
#               }
#             ]
#           },
#           {
#             "step_id": "high_priority_diagnosis",
#             "title": "High Priority Diagnosis",
#             "summary": "Immediate technical investigation for high-priority tickets",
#             "step_type": "ACTIVITY",
#             "actors": ["On-Call Engineer"],
#             "inputs": ["Ticket Details"],
#             "outputs": ["Initial Diagnosis"],
#             "prerequisites": ["priority_handling"],
#             "evidence": [
#               {
#                 "text": "High-priority tickets require an on-call engineer to begin diagnosis immediately",
#                 "start": 109,
#                 "end": 209
#               }
#             ]
#           },
#           {
#             "step_id": "medium_low_preparation",
#             "title": "Ticket Preparation",
#             "summary": "Preliminary response preparation for medium/low priority tickets",
#             "step_type": "ACTIVITY",
#             "actors": ["Support Agent"],
#             "inputs": ["Ticket Details"],
#             "outputs": ["Response Template", "Case History Review"],
#             "prerequisites": ["priority_handling"],
#             "evidence": [
#               {
#                 "text": "For medium and low priority tickets, an agent drafts a response template and checks previous similar cases before the engineer is looped in.",
#                 "start": 260,
#                 "end": 421
#               }
#             ]
#           },
#           {
#             "step_id": "technical_investigation",
#             "title": "Technical Diagnosis",
#             "summary": "Comprehensive technical investigation of the ticket",
#             "step_type": "ACTIVITY",
#             "actors": ["Engineer"],
#             "inputs": ["Ticket Details", "Case History"],
#             "outputs": ["Root Cause Summary", "Proposed Fix"],
#             "prerequisites": ["high_priority_diagnosis", "medium_low_preparation"],
#             "evidence": [
#               {
#                 "text": "After an engineer finishes investigating, they post a root-cause summary and proposed fix.",
#                 "start": 422,
#                 "end": 522
#               }
#             ]
#           },
#           {
#             "step_id": "fix_review",
#             "title": "Solution Validation",
#             "summary": "Review and validate proposed technical solution",
#             "step_type": "ACTIVITY",
#             "actors": ["Support Lead"],
#             "inputs": ["Proposed Fix", "Root Cause Summary"],
#             "outputs": ["Verified Solution", "Customer Communication"],
#             "prerequisites": ["technical_investigation"],
#             "evidence": [
#               {
#                 "text": "The support lead reviews the fix, confirms customer communication",
#                 "start": 523,
#                 "end": 598
#               }
#             ]
#           },
#           {
#             "step_id": "ticket_closure",
#             "title": "Ticket Resolution",
#             "summary": "Final closure or reopening based on customer feedback",
#             "step_type": "DECISION",
#             "actors": ["Support Lead"],
#             "inputs": ["Customer Feedback"],
#             "outputs": ["Closed Ticket", "Reopened Ticket"],
#             "prerequisites": ["fix_review"],
#             "evidence": [
#               {
#                 "text": "if the customer reports success, closes the ticket. If the fix fails, the lead reopens the ticket and the engineer repeats the diagnosis step.",
#                 "start": 599,
#                 "end": 751
#               }
#             ]
#           }
#         ],
#         "dependencies": [
#           {
#             "from_step": "ticket_arrival",
#             "to_step": "priority_handling",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "priority_handling",
#             "to_step": "high_priority_diagnosis",
#             "relation": "enables",
#             "condition": "ticket is high priority",
#             "evidence": []
#           },
#           {
#             "from_step": "priority_handling",
#             "to_step": "medium_low_preparation",
#             "relation": "enables",
#             "condition": "ticket is medium or low priority",
#             "evidence": []
#           },
#           {
#             "from_step": "high_priority_diagnosis",
#             "to_step": "technical_investigation",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "medium_low_preparation",
#             "to_step": "technical_investigation",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "technical_investigation",
#             "to_step": "fix_review",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "fix_review",
#             "to_step": "ticket_closure",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "ticket_closure",
#             "to_step": "technical_investigation",
#             "relation": "loops_back",
#             "condition": "fix failed",
#             "evidence": []
#           }
#         ],
#         "notes": [
#           "Process includes a potential loop for unsuccessful fixes",
#           "Implicit parallel processing between high and medium/low priority paths"
#         ]
#       },
#       "reasoning": "The process was modeled as a directed acyclic graph with steps representing key stages in ticket resolution, capturing the sequential and conditional flow described in the text.",
#       "issues": []
#     }
#     ---Parsed Response (class ProcessExtractionResult)---
#     {
#       "status": "process_found",
#       "graph": {
#         "process_name": "Customer Support Ticket Resolution",
#         "scope": "End-to-end ticket handling workflow",
#         "primary_goal": "Resolve customer support tickets efficiently and effectively",
#         "start_step_ids": [
#           "ticket_arrival"
#         ],
#         "end_step_ids": [
#           "ticket_closure"
#         ],
#         "steps": [
#           {
#             "step_id": "ticket_arrival",
#             "title": "Ticket Logging",
#             "summary": "New customer ticket enters the support system",
#             "step_type": "EVENT",
#             "actors": [
#               "Support Lead"
#             ],
#             "inputs": [
#               "Customer Ticket"
#             ],
#             "outputs": [
#               "Logged Ticket",
#               "Initial Priority"
#             ],
#             "duration": null,
#             "prerequisites": [],
#             "evidence": [
#               {
#                 "text": "When a new customer ticket arrives, the support lead logs it in the tracker and assigns an initial priority.",
#                 "start": 0,
#                 "end": 108
#               }
#             ]
#           },
#           {
#             "step_id": "priority_handling",
#             "title": "Priority-Based Routing",
#             "summary": "Determine ticket handling approach based on priority",
#             "step_type": "DECISION",
#             "actors": [
#               "Support Lead"
#             ],
#             "inputs": [
#               "Initial Priority"
#             ],
#             "outputs": [
#               "Routing Decision"
#             ],
#             "duration": null,
#             "prerequisites": [
#               "ticket_arrival"
#             ],
#             "evidence": [
#               {
#                 "text": "High-priority tickets require an on-call engineer to begin diagnosis immediately while the support lead notifies the customer that work has started.",
#                 "start": 109,
#                 "end": 259
#               }
#             ]
#           },
#           {
#             "step_id": "high_priority_diagnosis",
#             "title": "High Priority Diagnosis",
#             "summary": "Immediate technical investigation for high-priority tickets",
#             "step_type": "ACTIVITY",
#             "actors": [
#               "On-Call Engineer"
#             ],
#             "inputs": [
#               "Ticket Details"
#             ],
#             "outputs": [
#               "Initial Diagnosis"
#             ],
#             "duration": null,
#             "prerequisites": [
#               "priority_handling"
#             ],
#             "evidence": [
#               {
#                 "text": "High-priority tickets require an on-call engineer to begin diagnosis immediately",
#                 "start": 109,
#                 "end": 209
#               }
#             ]
#           },
#           {
#             "step_id": "medium_low_preparation",
#             "title": "Ticket Preparation",
#             "summary": "Preliminary response preparation for medium/low priority tickets",
#             "step_type": "ACTIVITY",
#             "actors": [
#               "Support Agent"
#             ],
#             "inputs": [
#               "Ticket Details"
#             ],
#             "outputs": [
#               "Response Template",
#               "Case History Review"
#             ],
#             "duration": null,
#             "prerequisites": [
#               "priority_handling"
#             ],
#             "evidence": [
#               {
#                 "text": "For medium and low priority tickets, an agent drafts a response template and checks previous similar cases before the engineer is looped in.",
#                 "start": 260,
#                 "end": 421
#               }
#             ]
#           },
#           {
#             "step_id": "technical_investigation",
#             "title": "Technical Diagnosis",
#             "summary": "Comprehensive technical investigation of the ticket",
#             "step_type": "ACTIVITY",
#             "actors": [
#               "Engineer"
#             ],
#             "inputs": [
#               "Ticket Details",
#               "Case History"
#             ],
#             "outputs": [
#               "Root Cause Summary",
#               "Proposed Fix"
#             ],
#             "duration": null,
#             "prerequisites": [
#               "high_priority_diagnosis",
#               "medium_low_preparation"
#             ],
#             "evidence": [
#               {
#                 "text": "After an engineer finishes investigating, they post a root-cause summary and proposed fix.",
#                 "start": 422,
#                 "end": 522
#               }
#             ]
#           },
#           {
#             "step_id": "fix_review",
#             "title": "Solution Validation",
#             "summary": "Review and validate proposed technical solution",
#             "step_type": "ACTIVITY",
#             "actors": [
#               "Support Lead"
#             ],
#             "inputs": [
#               "Proposed Fix",
#               "Root Cause Summary"
#             ],
#             "outputs": [
#               "Verified Solution",
#               "Customer Communication"
#             ],
#             "duration": null,
#             "prerequisites": [
#               "technical_investigation"
#             ],
#             "evidence": [
#               {
#                 "text": "The support lead reviews the fix, confirms customer communication",
#                 "start": 523,
#                 "end": 598
#               }
#             ]
#           },
#           {
#             "step_id": "ticket_closure",
#             "title": "Ticket Resolution",
#             "summary": "Final closure or reopening based on customer feedback",
#             "step_type": "DECISION",
#             "actors": [
#               "Support Lead"
#             ],
#             "inputs": [
#               "Customer Feedback"
#             ],
#             "outputs": [
#               "Closed Ticket",
#               "Reopened Ticket"
#             ],
#             "duration": null,
#             "prerequisites": [
#               "fix_review"
#             ],
#             "evidence": [
#               {
#                 "text": "if the customer reports success, closes the ticket. If the fix fails, the lead reopens the ticket and the engineer repeats the diagnosis step.",
#                 "start": 599,
#                 "end": 751
#               }
#             ]
#           }
#         ],
#         "dependencies": [
#           {
#             "from_step": "ticket_arrival",
#             "to_step": "priority_handling",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "priority_handling",
#             "to_step": "high_priority_diagnosis",
#             "relation": "enables",
#             "condition": "ticket is high priority",
#             "evidence": []
#           },
#           {
#             "from_step": "priority_handling",
#             "to_step": "medium_low_preparation",
#             "relation": "enables",
#             "condition": "ticket is medium or low priority",
#             "evidence": []
#           },
#           {
#             "from_step": "high_priority_diagnosis",
#             "to_step": "technical_investigation",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "medium_low_preparation",
#             "to_step": "technical_investigation",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "technical_investigation",
#             "to_step": "fix_review",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "fix_review",
#             "to_step": "ticket_closure",
#             "relation": "precedes",
#             "condition": null,
#             "evidence": []
#           },
#           {
#             "from_step": "ticket_closure",
#             "to_step": "technical_investigation",
#             "relation": "loops_back",
#             "condition": "fix failed",
#             "evidence": []
#           }
#         ],
#         "notes": [
#           "Process includes a potential loop for unsuccessful fixes",
#           "Implicit parallel processing between high and medium/low priority paths"
#         ]
#       },
#       "reasoning": "The process was modeled as a directed acyclic graph with steps representing key stages in ticket resolution, capturing the sequential and conditional flow described in the text.",
#       "issues": []
#     }
# ('process_found', 1)

# %%
if result.issues:
    for issue in result.issues:
        print(f"Issue: {issue.code} -> {issue.message}")
else:
    print("No validation issues raised.")
# Out:
# Issue: cycle_detected -> Detected cycles within the process dependencies; review relations or step ordering.

# %% [markdown]
# ### Inspect extracted steps
#
# The `ProcessGraph` captures every step, its type, and supporting evidence. Let’s tabulate the steps for a quick glance.

# %%
process_graph: ProcessGraph = result.graph

steps_df = pd.DataFrame(
    [
        {
            "step_id": step.step_id,
            "title": step.title,
            "type": step.step_type.value if hasattr(step.step_type, "value") else str(step.step_type),
            "actors": ", ".join(step.actors),
            "inputs": ", ".join(step.inputs),
            "outputs": ", ".join(step.outputs),
            "prerequisites": ", ".join(step.prerequisites),
        }
        for step in process_graph.steps
    ]
)
steps_df
# Out:
#                    step_id                    title      type  \
# 0           ticket_arrival           Ticket Logging     EVENT
# 1        priority_handling   Priority-Based Routing  DECISION
# 2  high_priority_diagnosis  High Priority Diagnosis  ACTIVITY
# 3   medium_low_preparation       Ticket Preparation  ACTIVITY
# 4  technical_investigation      Technical Diagnosis  ACTIVITY
# 5               fix_review      Solution Validation  ACTIVITY
# 6           ticket_closure        Ticket Resolution  DECISION
#
#              actors                            inputs  \
# 0      Support Lead                   Customer Ticket
# 1      Support Lead                  Initial Priority
# 2  On-Call Engineer                    Ticket Details
# 3     Support Agent                    Ticket Details
# 4          Engineer      Ticket Details, Case History
# 5      Support Lead  Proposed Fix, Root Cause Summary
# 6      Support Lead                 Customer Feedback
#
#                                      outputs  \
# 0            Logged Ticket, Initial Priority
# 1                           Routing Decision
# 2                          Initial Diagnosis
# 3     Response Template, Case History Review
# 4           Root Cause Summary, Proposed Fix
# 5  Verified Solution, Customer Communication
# 6             Closed Ticket, Reopened Ticket
#
#                                      prerequisites
# 0
# 1                                   ticket_arrival
# 2                                priority_handling
# 3                                priority_handling
# 4  high_priority_diagnosis, medium_low_preparation
# 5                          technical_investigation
# 6                                       fix_review

# %% [markdown]
# ### Dependency edges
#
# Each dependency includes a relation label (defaults to `precedes`) and optional conditional notes.

# %%
pd.DataFrame(
    [
        {
            "from": dependency.from_step,
            "to": dependency.to_step,
            "relation": dependency.relation or "precedes",
            "condition": dependency.condition or "",
            "evidence": " | ".join(span.text for span in dependency.evidence),
        }
        for dependency in process_graph.dependencies
    ]
)
# Out:
#                       from                       to    relation  \
# 0           ticket_arrival        priority_handling    precedes
# 1        priority_handling  high_priority_diagnosis     enables
# 2        priority_handling   medium_low_preparation     enables
# 3  high_priority_diagnosis  technical_investigation    precedes
# 4   medium_low_preparation  technical_investigation    precedes
# 5  technical_investigation               fix_review    precedes
# 6               fix_review           ticket_closure    precedes
# 7           ticket_closure  technical_investigation  loops_back
#
#                           condition evidence
# 0
# 1           ticket is high priority
# 2  ticket is medium or low priority
# 3
# 4
# 5
# 6
# 7                        fix failed

# %% [markdown]
# ## 3. Convert the process DAG to triples
#
# `GraphStore` works with knowledge-graph triples. We will flatten each process dependency into a `(step -> relation -> step)` triple and preserve rich step metadata inside `Entity.custom_atts`.

# %%
def process_graph_to_triples(
    graph: ProcessGraph,
    source_name: str,
    source_url: str | None = None,
) -> list[Triple]:
    """Flatten a process graph into Triple objects suitable for GraphStore."""

    if graph is None:
        return []

    source_metadata = SourceMetadata(source_name=source_name, source_url=source_url)
    extraction_time = datetime.utcnow().isoformat()

    # Build entity objects with reusable metadata
    step_entities: dict[str, Entity] = {}
    for step in graph.steps:
        attrs = {
            "step_type": AttributeValue(value=str(step.step_type), type="string"),
            "actors": AttributeValue(value=json.dumps(step.actors), type="json"),
            "inputs": AttributeValue(value=json.dumps(step.inputs), type="json"),
            "outputs": AttributeValue(value=json.dumps(step.outputs), type="json"),
            "duration": AttributeValue(value=step.duration or "", type="string"),
        }
        if graph.process_name:
            attrs["process_name"] = AttributeValue(value=graph.process_name, type="string")
        if graph.scope:
            attrs["scope"] = AttributeValue(value=graph.scope, type="string")

        node_label = f"{graph.process_name or 'Process'}::{step.step_id}" if graph.process_name else step.step_id
        step_entities[step.step_id] = Entity(
            name=node_label,
            type="ProcessStep",
            description=step.summary,
            custom_atts=attrs,
        )

    # Build triples using dependency edges
    triples: list[Triple] = []
    for dependency in graph.dependencies:
        subject = step_entities[dependency.from_step]
        obj = step_entities[dependency.to_step]

        spans = [
            CharacterSpan(text=span.text, start=span.start, end=span.end)
            for span in dependency.evidence
        ] or [CharacterSpan(text="Derived from process description", start=None, end=None)]

        predicate = dependency.relation or "precedes"
        if dependency.condition:
            predicate = f"{predicate} (condition: {dependency.condition})"

        triples.append(
            Triple(
                subject=subject,
                predicate=predicate,
                object=obj,
                source=source_metadata,
                supporting_spans=spans,
                extraction_datetime=extraction_time,
            )
        )

    return triples

# %%
process_triples = process_graph_to_triples(
    graph=process_graph,
    source_name="support_ticket_playbook.md",
)

process_triples[0]
# Out:
# Triple(subject=Entity(name='Customer Support Ticket Resolution::ticket_arrival', type='ProcessStep', description='New customer ticket enters the support system', custom_atts={'step_type': AttributeValue(value='ProcessStepType.EVENT', type='string'), 'actors': AttributeValue(value='["Support Lead"]', type='json'), 'inputs': AttributeValue(value='["Customer Ticket"]', type='json'), 'outputs': AttributeValue(value='["Logged Ticket", "Initial Priority"]', type='json'), 'duration': AttributeValue(value='', type='string'), 'process_name': AttributeValue(value='Customer Support Ticket Resolution', type='string'), 'scope': AttributeValue(value='End-to-end ticket handling workflow', type='string')}), predicate='precedes', object=Entity(name='Customer Support Ticket Resolution::priority_handling', type='ProcessStep', description='Determine ticket handling approach based on priority', custom_atts={'step_type': AttributeValue(value='ProcessStepType.DECISION', type='string'), 'actors': AttributeValue(value='["Support Lead"]', type='json'), 'inputs': AttributeValue(value='["Initial Priority"]', type='json'), 'outputs': AttributeValue(value='["Routing Decision"]', type='json'), 'duration': AttributeValue(value='', type='string'), 'process_name': AttributeValue(value='Customer Support Ticket Resolution', type='string'), 'scope': AttributeValue(value='End-to-end ticket handling workflow', type='string')}), source=SourceMetadata(source_name='support_ticket_playbook.md', source_url=None), supporting_spans=[CharacterSpan(text='Derived from process description', start=None, end=None)], extraction_datetime='2025-11-07T22:15:32.946550')

# %% [markdown]
# ## 4. Load the triples into `GraphStore`
#
# Kùzu stores data on disk. We create a demo database named `process_demo` (located under `spindle/graphs/process_demo/graph.db`). Re-running the notebook will reset the database to avoid duplicate data.

# %%
graph_name = "process_demo"

store = GraphStore(graph_name)
store.delete_graph()
store.create_graph(graph_name)

inserted = store.add_triples(process_triples)
print(f"Inserted {inserted} process triples into '{graph_name}'.")
# Out:
# Inserted 8 process triples into 'process_demo'.

# %%
edges = store.query_by_pattern(predicate="precedes")

dependency_df = pd.DataFrame(
    [
        {
            "subject": edge["subject"],
            "predicate": edge["predicate"],
            "object": edge["object"],
        }
        for edge in edges
    ]
)

dependency_df
# Out:
#                                              subject predicate  \
# 0  CUSTOMER SUPPORT TICKET RESOLUTION::TICKET_ARR...  PRECEDES
# 1  CUSTOMER SUPPORT TICKET RESOLUTION::HIGH_PRIOR...  PRECEDES
# 2  CUSTOMER SUPPORT TICKET RESOLUTION::MEDIUM_LOW...  PRECEDES
# 3  CUSTOMER SUPPORT TICKET RESOLUTION::TECHNICAL_...  PRECEDES
# 4     CUSTOMER SUPPORT TICKET RESOLUTION::FIX_REVIEW  PRECEDES
#
#                                               object
# 0  CUSTOMER SUPPORT TICKET RESOLUTION::PRIORITY_H...
# 1  CUSTOMER SUPPORT TICKET RESOLUTION::TECHNICAL_...
# 2  CUSTOMER SUPPORT TICKET RESOLUTION::TECHNICAL_...
# 3     CUSTOMER SUPPORT TICKET RESOLUTION::FIX_REVIEW
# 4  CUSTOMER SUPPORT TICKET RESOLUTION::TICKET_CLO...

# %% [markdown]
# Note: `GraphStore` normalizes entity names to uppercase when storing them. You can map them back to human-friendly labels if needed when presenting results.

# %% [markdown]
# ## 5. Next steps
#
# - Use `GraphStore.query_cypher` for more expressive queries or integrate the process DAG with other knowledge graphs imported from documents.
# - Extend the conversion logic to store additional attributes (e.g., cycle warnings) or to sync process data with external workflow tools.
# - When you are done exploring, call `store.close()` or use the context manager interface to release the database handle.

# %%
store.close()
