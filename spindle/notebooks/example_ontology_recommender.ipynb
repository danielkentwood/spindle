# %% [markdown]
# Example usage of the OntologyRecommender service.
#
# This notebook demonstrates:
# 1. Analyzing text to automatically recommend an ontology
# 2. Using the recommended ontology to extract triples
# 3. Automatic ontology recommendation when using SpindleExtractor without an ontology
# 4. Conservative ontology extension for new domains
# 5. Serialization and inspection of recommendations and extensions

# %%
import os
import json
from dotenv import load_dotenv
from spindle import (
    OntologyRecommender,
    SpindleExtractor,
    create_ontology,
    recommendation_to_dict,
    triples_to_dict,
    extension_to_dict,
    ontology_to_dict
)

# Load environment variables (API keys)
load_dotenv()

# Check if API key is set
if not os.getenv("ANTHROPIC_API_KEY"):
    print("Error: ANTHROPIC_API_KEY environment variable not set.")
    print("Please set it in a .env file or as an environment variable.")

# %%
print("=" * 70)
print("Ontology Recommender Example")
print("=" * 70)
print()

# Example text: Medical research abstract
medical_text = """
A recent clinical trial evaluated the efficacy of Medication A in treating 
patients with chronic migraines. The study, conducted at Massachusetts General 
Hospital, enrolled 250 patients aged 18-65 who experienced at least 8 migraine 
days per month. Dr. Sarah Chen, the principal investigator, led a team of 
neurologists who administered the drug over a 12-week period.

Results showed that Medication A reduced migraine frequency by an average of 
50% compared to the placebo group. Common side effects included nausea and 
dizziness, which affected approximately 15% of participants. The medication 
works by inhibiting CGRP receptors, which are known to play a role in migraine 
pathophysiology.

Dr. Chen reported the findings at the American Academy of Neurology conference 
in Seattle, where the research was well-received by the medical community. The 
FDA is expected to review the data for potential approval in the coming year. 
Massachusetts General Hospital has been a leading research institution in 
neurology for decades and continues to conduct groundbreaking studies in 
headache disorders.
"""

print("Step 1: Recommend ontology from medical text")
print("-" * 70)
print(f"Input text:\n{medical_text}\n")
# Out:
# ======================================================================
# Ontology Recommender Example
# ======================================================================
#
# Step 1: Recommend ontology from medical text
# ----------------------------------------------------------------------
# Input text:
#
# A recent clinical trial evaluated the efficacy of Medication A in treating
# patients with chronic migraines. The study, conducted at Massachusetts General
# Hospital, enrolled 250 patients aged 18-65 who experienced at least 8 migraine
# days per month. Dr. Sarah Chen, the principal investigator, led a team of
# neurologists who administered the drug over a 12-week period.
#
# Results showed that Medication A reduced migraine frequency by an average of
# 50% compared to the placebo group. Common side effects included nausea and
# dizziness, which affected approximately 15% of participants. The medication
# works by inhibiting CGRP receptors, which are known to play a role in migraine
# pathophysiology.
#
# Dr. Chen reported the findings at the American Academy of Neurology conference
# in Seattle, where the research was well-received by the medical community. The
# FDA is expected to review the data for potential approval in the coming year.
# Massachusetts General Hospital has been a leading research institution in
# neurology for decades and continues to conduct groundbreaking studies in
# headache disorders.

# %%
# Create the recommender
recommender = OntologyRecommender()

# Get ontology recommendation
recommendation = recommender.recommend(
    text=medical_text,
    scope="balanced"  # "minimal", "balanced", or "comprehensive"
)

print("Text Purpose:")
print(f"  {recommendation.text_purpose}\n")

print("Recommended Entity Types:")
for i, entity_type in enumerate(recommendation.ontology.entity_types, 1):
    print(f"  {i}. {entity_type.name}: {entity_type.description}")
print()

print("Recommended Relation Types:")
for i, relation_type in enumerate(recommendation.ontology.relation_types, 1):
    print(f"  {i}. {relation_type.name}: {relation_type.description}")
    print(f"     ({relation_type.domain} → {relation_type.range})")
print()

print("Reasoning:")
print(f"  {recommendation.reasoning}\n")
# Out:
# 2025-11-03T16:59:08.544 [BAML INFO] Function RecommendOntology:
#     Client: CustomGPT5Mini (gpt-5-mini-2025-08-07) - 74827ms. StopReason: completed. Tokens(in/out): 2469/5483
#     ---PROMPT---
#     system: You are a knowledge graph ontology design expert. Your task is to analyze the provided text, understand its overarching purpose and domain, and recommend an appropriate ontology (entity types and relation types) that would be suitable for extracting knowledge from this and similar texts.
#     user: TEXT TO ANALYZE:
#
#     A recent clinical trial evaluated the efficacy of Medication A in treating
#     patients with chronic migraines. The study, conducted at Massachusetts General
#     Hospital, enrolled 250 patients aged 18-65 who experienced at least 8 migraine
#     days per month. Dr. Sarah Chen, the principal investigator, led a team of
#     neurologists who administered the drug over a 12-week period.
#
#     Results showed that Medication A reduced migraine frequency by an average of
#     50% compared to the placebo group. Common side effects included nausea and
#     dizziness, which affected approximately 15% of participants. The medication
#     works by inhibiting CGRP receptors, which are known to play a role in migraine
#     pathophysiology.
#
#     Dr. Chen reported the findings at the American Academy of Neurology conference
#     in Seattle, where the research was well-received by the medical community. The
#     FDA is expected to review the data for potential approval in the coming year.
#     Massachusetts General Hospital has been a leading research institution in
#     neurology for decades and continues to conduct groundbreaking studies in
#     headache disorders.
#
#
#     ONTOLOGY SCOPE: balanced
#
#     GRANULARITY GUIDELINES:
#
#     Your goal is to design an ontology with balanced scope. Use these principles to guide your decisions about how many types to create and how granular to make them.
#
#     ENTITY TYPE GRANULARITY PRINCIPLES:
#
#     1. **Abstraction Level**: Choose the right level of abstraction
#        - Too broad: "Thing", "Entity" (not useful)
#        - Too narrow: "SoftwareEngineerAtGoogle", "CEOOfTechStartup" (overfitting)
#        - Just right: "Person", "Organization", "JobRole" (reusable across instances)
#
#     2. **Domain Relevance**: Include entity types that are central to THIS domain
#        - For medical text: Patient, Medication, Condition, Procedure, Hospital
#        - For business text: Company, Person, Investment, Product, Market
#        - Don't include types that rarely appear or aren't relevant to this specific text
#
#     3. **Distinctiveness Test**: Only create separate types if they have:
#        - Different attributes or characteristics
#        - Different relationship patterns
#        - Different analytical value
#        - Example: "Professor" and "Student" are distinct if their relationships differ
#        - Example: "CEO" and "CTO" might both be "ExecutiveRole" if relationships are similar
#
#     4. **Generalization**: Combine similar concepts under broader types when appropriate
#        - Instead of: "Dog", "Cat", "Bird" → use "Animal" (if distinctions don't matter)
#        - Instead of: "Laptop", "Desktop", "Tablet" → use "Device" or "Computer"
#        - BUT: Keep separate if the distinction is analytically important for this domain
#
#     5. **Coverage**: Ensure types cover the main concepts in the text
#        - Don't create types for concepts that appear only once
#        - DO create types for recurring or structurally important concepts
#        - Focus on concepts that are central to understanding this domain
#
#     RELATION TYPE GRANULARITY PRINCIPLES:
#
#     1. **Semantic Precision**: Relations should capture meaningful distinctions
#        - Too vague: "related_to", "associated_with" (not informative)
#        - Too specific: "works_at_as_senior_engineer_since_2020" (overfitting)
#        - Just right: "works_at", "employed_by", "manages" (clear semantics)
#
#     2. **Directionality Matters**: Choose direction that reflects real-world semantics
#        - "Person works_at Organization" (natural)
#        - Not "Organization employs Person" (unless that's the focus)
#        - Be consistent in your directional choices
#
#     3. **Relationship Patterns**: Include relations that appear or could appear multiple times
#        - Medical: "treats", "prescribes", "diagnoses", "hospitalized_at"
#        - Business: "invests_in", "founded", "acquired_by", "partners_with"
#        - Focus on the relationships that matter for this domain
#
#     4. **Avoid Redundancy**: Don't create near-synonyms unless there's semantic distinction
#        - Don't have both "works_at" and "employed_by" (pick one)
#        - Don't have both "located_in" and "based_in" (pick one)
#        - DO have "founded" and "acquired" (different events with different meanings)
#
#     5. **Completeness**: Capture the key relationship types in the domain
#        - Think: "What questions would someone ask about this data?"
#        - Include relations that support those analytical questions
#        - Every relation should serve a clear analytical purpose
#
#     SCOPE-SPECIFIC GUIDANCE:
#
#     **If scope is "minimal":**
#     - Create only the most essential entity types (core concepts only)
#     - Focus on the most frequent and important relationships
#     - Err on the side of broader categories that combine similar concepts
#     - Typical result: 3-8 entity types, 4-10 relation types
#     - Use case: Quick extraction, simple queries, identifying broad patterns
#     - Example: For a business article → Person, Organization, Location, works_at, located_in
#
#     **If scope is "balanced":**
#     - Include entity types for all significant concepts in the domain
#     - Capture the main relationship patterns without over-specifying
#     - Balance specificity with reusability across similar texts
#     - Typical result: 6-12 entity types, 8-15 relation types
#     - Use case: Standard analysis, general-purpose extraction, most common scenarios
#     - Example: For a business article → Person, Organization, Location, Product, Investment, works_at, located_in, founded, invests_in, develops
#
#     **If scope is "comprehensive":**
#     - Include entity types for all distinct and meaningful concepts
#     - Capture nuanced relationship types that reflect domain expertise
#     - Allow for more domain-specific and specialized types
#     - Typical result: 10-20 entity types, 12-25 relation types
#     - Use case: Detailed analysis, domain expertise, research, specialized queries
#     - Example: For a business article → Person, Organization, Location, Product, Investment, Technology, Market, Role, works_at, located_in, founded, invests_in, develops, competes_with, targets, acquired_by, partners_with
#
#     QUALITY OVER QUANTITY:
#     - It's better to have fewer, well-defined types than many poorly-defined ones
#     - Each type should have a clear, distinct purpose and detailed description
#     - Each type should be distinguishable from others in meaningful ways
#     - Every type you create should be useful for analysis and querying
#     - The numbers above are guidelines, not requirements - use your judgment
#
#     SELF-CHECK QUESTIONS:
#     Before finalizing your ontology, ask yourself:
#     1. Can I clearly explain when to use each entity type vs. others?
#     2. Would two different people classify entities consistently with these types?
#     3. Are my relation types capturing distinct semantic relationships?
#     4. Can I extract useful, actionable information with this ontology?
#     5. Is this ontology reusable for similar texts in this domain?
#     6. Does the granularity match the requested scope level?
#
#     ONTOLOGY DESIGN PRINCIPLES:
#     - Entity types should be nouns representing concrete or abstract concepts
#     - Relation types should be verbs or verb phrases that connect entities
#     - Each relation type must specify its domain (subject entity type) and range (object entity type)
#     - Prefer commonly understood terms over jargon unless domain-specific terms are essential
#     - Think about what would be useful for querying and analyzing this type of text
#     - Ensure descriptions are clear and detailed enough for accurate extraction
#
#     CUSTOM ATTRIBUTES FOR ENTITY TYPES:
#
#     For each entity type, you should define custom attributes that capture type-specific information:
#
#     1. **Identify Key Attributes**: What information is important for this entity type?
#        - For Person: birth_date, nationality, occupation
#        - For Organization: founded_date, headquarters_location, industry
#        - For Campaign: launch_date, end_date, budget, target_audience
#        - For Product: release_date, version, price
#
#     2. **Attribute Types**: Use appropriate data types
#        - "string": General text (names, descriptions, IDs)
#        - "int": Whole numbers (counts, quantities, years)
#        - "float": Decimal numbers (prices, percentages, measurements)
#        - "bool": True/false values (is_active, is_public)
#        - "date": ISO dates (YYYY-MM-DD format)
#        - Nested objects: For complex structured data (use JSON schema description)
#
#     3. **Domain-Relevant Attributes**: Focus on what matters for this domain
#        - Medical domain: diagnosis_date, treatment_status, dosage
#        - Business domain: funding_amount, employee_count, revenue
#        - Academic domain: publication_date, citation_count, affiliation
#
#     4. **Extraction-Friendly**: Choose attributes that can be extracted from text
#        - Prefer attributes commonly mentioned in text
#        - Avoid attributes requiring external knowledge
#        - Balance detail with extractability
#
#     5. **Scope Considerations**:
#        - Minimal scope: 0-2 attributes per entity type (only essential ones)
#        - Balanced scope: 2-4 attributes per entity type (common, useful attributes)
#        - Comprehensive scope: 4-8 attributes per entity type (detailed characterization)
#
#     EXAMPLE ENTITY TYPE WITH ATTRIBUTES:
#
#     ```
#     EntityType: Campaign
#     Description: A marketing or outreach campaign
#     Attributes:
#       - name: campaign_launch_dt
#         type: date
#         description: The date when the campaign was launched
#       - name: campaign_completion_dt
#         type: date
#         description: The date when the campaign ended or is planned to end
#       - name: target_audience
#         type: string
#         description: The intended audience or demographic for the campaign
#       - name: campaign_budget
#         type: float
#         description: The budget allocated for the campaign in dollars
#     ```
#
#     Your task is to analyze THIS specific text and recommend the most appropriate ontology for it,
#     following the principles above and designing for the requested "balanced" scope level.
#     Include appropriate custom attributes for each entity type based on the domain and text content.
#
#     Answer in JSON using this schema:
#     {
#       // The recommended ontology with entity and relation types
#       ontology: {
#         // List of valid entity types
#         entity_types: [
#           {
#             // The name of the entity type (e.g., 'Person', 'Organization', 'Campaign')
#             name: string,
#             // A description of what this entity type represents
#             description: string,
#             // List of custom attributes that should be extracted for entities of this type
#             attributes: [
#               {
#                 // The name of the attribute (e.g., 'campaign_launch_dt', 'founded_date')
#                 name: string,
#                 // Data type: 'string', 'int', 'float', 'bool', 'date', or a nested object schema definition
#                 type: string,
#                 // A description of what this attribute represents
#                 description: string,
#               }
#             ],
#           }
#         ],
#         // List of valid relation types
#         relation_types: [
#           {
#             // The name of the relation type (e.g., 'works_at', 'located_in')
#             name: string,
#             // A description of what this relation represents
#             description: string,
#             // The entity type that can be the subject of this relation
#             domain: string,
#             // The entity type that can be the object of this relation
#             range: string,
#           }
#         ],
#       },
#       // Analysis of the text's overarching purpose or goal
#       text_purpose: string,
#       // Explanation of why these entity and relation types were recommended
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     {
#       "ontology": {
#         "entity_types": [
#           {
#             "name": "Person",
#             "description": "An individual mentioned in the text (e.g., investigators, clinicians, presenters, patients when named).",
#             "attribuText Purpose:
#   Summarize and report a clinical trial evaluating Medication A for chronic migraines — including study design, participants, results (efficacy and side effects), mechanism of action, presentation at a conference, institutional context, and anticipated regulatory review.
#
# Recommended Entity Types:
#   1. Person: An individual mentioned in the text (e.g., investigators, clinicians, presenters, patients when named).
#   2. Organization: An institutional entity (e.g., hospitals, research institutions, regulatory agencies, professional societies).
#   3. ClinicalTrial: A clinical study or trial described in the text.
#   4. Medication: A therapeutic compound or drug evaluated or mentioned in the text.
#   5. Condition: A medical condition, disease, or disorder discussed (e.g., chronic migraine).
#   6. Outcome: A measured result or endpoint from a study (e.g., reduction in migraine frequency).
#   7. AdverseEvent: An adverse effect or side effect reported in association with an intervention.
#   8. BiologicalTarget: A biological molecule or target referenced as the mechanism of action (e.g., CGRP receptor).
#   9. Event: A meeting or conference where results are presented (e.g., American Academy of Neurology conference).
#   10. RegulatoryAction: A regulatory process or action mentioned (e.g., expected FDA review, approval).
#   11. Location: Geographic place referenced (city, state, country) useful for events and organization locations.
#
# Recommended Relation Types:
#   1. works_at: Indicates that a person is affiliated with or works at an organization.
#      (Person → Organization)
#   2. leads_trial: A person (e.g., principal investigator) leads or directs a clinical trial.
#      (Person → ClinicalTrial)
#   3. conducted_by: The organization that conducted or hosted the clinical trial.
#      (ClinicalTrial → Organization)
#   4. tests_medication: Indicates that a clinical trial evaluated or tested a given medication.
#      (ClinicalTrial → Medication)
#   5. targets_condition: The clinical trial is aimed at studying or treating a specific condition.
#      (ClinicalTrial → Condition)
#   6. has_outcome: Links a clinical trial to a reported outcome or endpoint.
#      (ClinicalTrial → Outcome)
#   7. measures_condition: An outcome metric that measures or quantifies a condition.
#      (Outcome → Condition)
#   8. reports_adverse_event: A clinical trial reports one or more adverse events observed among participants.
#      (ClinicalTrial → AdverseEvent)
#   9. causes_adverse_event: Indicates an association between a medication and an adverse event.
#      (Medication → AdverseEvent)
#   10. has_mechanism: Connects a medication to its biological target or mechanism of action.
#      (Medication → BiologicalTarget)
#   11. presented_at: A person presented findings at an event (conference).
#      (Person → Event)
#   12. reported_at: The clinical trial's results were reported or presented at an event.
#      (ClinicalTrial → Event)
#   13. located_in: Indicates the geographic location of an organization or event.
#      (Organization → Location)
#   14. event_located_in: Specifies the geographic location for an event.
#      (Event → Location)
#   15. reviews: A regulatory organization reviews trial data or a medication (e.g., FDA reviewing data).
#      (Organization → ClinicalTrial)
#   16. regulatory_action_by: Links a regulatory action record to the agency or organization performing it.
#      (RegulatoryAction → Organization)
#   17. regulatory_action_targets_trial: Indicates that a regulatory action is targeted at a clinical trial or its data.
#      (RegulatoryAction → ClinicalTrial)
#   18. regulatory_action_targets_medication: Indicates that a regulatory action is targeted at a medication (e.g., approval/review).
#      (RegulatoryAction → Medication)
#
# Reasoning:
#   I designed a balanced ontology focused on clinical research and related entities that appear in the text. Entity types were chosen to cover recurring and central concepts: persons (investigators/presenters), organizations (hospital, FDA, professional society), clinical trials (study-level metadata), medications, medical conditions, outcomes (endpoints/results), adverse events (side effects), biological targets (mechanism), events (conferences), regulatory actions (expected reviews), and locations. This set is general enough to apply across similar clinical-trial reports yet specific enough to capture analytically important distinctions (e.g., outcomes vs. adverse events, trials vs. medications). Relation types were selected to reflect common, meaningful interactions in clinical reports: affiliations (works_at), trial leadership, which organization conducted a trial, trial→medication and trial→condition links, how outcomes map to conditions, reporting of adverse events, mechanism links (medication→target), presentation/reporting at conferences, and regulatory review actions. Attribute choices follow the 'balanced' guideline (2–4 useful, extractable attributes per entity) emphasizing information commonly present in such texts (enrollment counts, age ranges, duration, effect sizes, incidence percentages, mechanism descriptions, and expected regulatory dates). The ontology avoids overly specific roles or redundant relations while supporting typical queries: Who led the trial? Where was it conducted? What medication and mechanism were studied? What were the efficacy and side-effect rates? Has the FDA or another agency been engaged? This design should allow consistent classification by different annotators and be reusable across similar clinical trial summaries.
#
# tes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Full name of the person."
#               },
#               {
#                 "name": "role",
#                 "type": "string",
#                 "description": "Role or function in the context (e.g., principal investigator, neurologist, presenter)."
#               },
#               {
#                 "name": "specialty",
#                 "type": "string",
#                 "description": "Professional specialty or occupation (e.g., neurologist)."
#               },
#               {
#                 "name": "affiliation_name",
#                 "type": "string",
#                 "description": "Name of the primary organization with which the person is affiliated (extractable from text)."
#               }
#             ]
#           },
#           {
#             "name": "Organization",
#             "description": "An institutional entity (e.g., hospitals, research institutions, regulatory agencies, professional societies).",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Official name of the organization."
#               },
#               {
#                 "name": "type",
#                 "type": "string",
#                 "description": "Category of organization (e.g., hospital, regulatory_agency, professional_society, research_institution)."
#               },
#               {
#                 "name": "location_name",
#                 "type": "string",
#                 "description": "Textual location or headquarters (city, state, country) if mentioned."
#               },
#               {
#                 "name": "research_focus",
#                 "type": "string",
#                 "description": "Short description of the organization's domain or area of research (if stated)."
#               }
#             ]
#           },
#           {
#             "name": "ClinicalTrial",
#             "description": "A clinical study or trial described in the text.",
#             "attributes": [
#               {
#                 "name": "trial_id",
#                 "type": "string",
#                 "description": "Name or identifier of the trial (as given in text)."
#               },
#               {
#                 "name": "enrollment_count",
#                 "type": "int",
#                 "description": "Number of participants enrolled in the trial."
#               },
#               {
#                 "name": "age_min",
#                 "type": "int",
#                 "description": "Minimum participant age included in the trial (years)."
#               },
#               {
#                 "name": "age_max",
#                 "type": "int",
#                 "description": "Maximum participant age included in the trial (years)."
#               },
#               {
#                 "name": "duration_weeks",
#                 "type": "int",
#                 "description": "Planned or actual duration of intervention/follow-up in weeks."
#               },
#               {
#                 "name": "control_type",
#                 "type": "string",
#                 "description": "Control or comparator used (e.g., placebo-controlled, active comparator)."
#               },
#               {
#                 "name": "status",
#                 "type": "string",
#                 "description": "Trial status mentioned (e.g., completed, ongoing, results_presented)."
#               }
#             ]
#           },
#           {
#             "name": "Medication",
#             "description": "A therapeutic compound or drug evaluated or mentioned in the text.",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Medication name or identifier."
#               },
#               {
#                 "name": "indication",
#                 "type": "string",
#                 "description": "Condition(s) the medication is intended to treat (as mentioned)."
#               },
#               {
#                 "name": "mechanism_summary",
#                 "type": "string",
#                 "description": "Short description of the drug's mechanism of action (e.g., inhibits CGRP receptors)."
#               },
#               {
#                 "name": "approval_status",
#                 "type": "string",
#                 "description": "Regulatory status or expected regulatory action as mentioned (e.g., FDA review expected)."
#               }
#             ]
#           },
#           {
#             "name": "Condition",
#             "description": "A medical condition, disease, or disorder discussed (e.g., chronic migraine).",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Name of the condition."
#               },
#               {
#                 "name": "chronic",
#                 "type": "bool",
#                 "description": "Whether the condition is described as chronic in the text."
#               },
#               {
#                 "name": "frequency_per_month",
#                 "type": "float",
#                 "description": "Frequency metric if provided (e.g., migraine days per month)."
#               },
#               {
#                 "name": "typical_symptoms",
#                 "type": "string",
#                 "description": "Short description of core symptoms if mentioned."
#               }
#             ]
#           },
#           {
#             "name": "Outcome",
#             "description": "A measured result or endpoint from a study (e.g., reduction in migraine frequency).",
#             "attributes": [
#               {
#                 "name": "metric_name",
#                 "type": "string",
#                 "description": "Name of the outcome metric (e.g., migraine_frequency_reduction)."
#               },
#               {
#                 "name": "value",
#                 "type": "float",
#                 "description": "Numeric value of the outcome (e.g., 50)."
#               },
#               {
#                 "name": "unit",
#                 "type": "string",
#                 "description": "Unit for the outcome value (e.g., percent, days/month)."
#               },
#               {
#                 "name": "comparison",
#                 "type": "string",
#                 "description": "Comparator stated (e.g., versus placebo)."
#               }
#             ]
#           },
#           {
#             "name": "AdverseEvent",
#             "description": "An adverse effect or side effect reported in association with an intervention.",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Name or description of the adverse event (e.g., nausea)."
#               },
#               {
#                 "name": "incidence_rate",
#                 "type": "float",
#                 "description": "Reported incidence as a percentage (if provided)."
#               },
#               {
#                 "name": "severity",
#                 "type": "string",
#                 "description": "Severity descriptor if given (e.g., common, severe)."
#               }
#             ]
#           },
#           {
#             "name": "BiologicalTarget",
#             "description": "A biological molecule or target referenced as the mechanism of action (e.g., CGRP receptor).",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Name of the biological target."
#               },
#               {
#                 "name": "target_type",
#                 "type": "string",
#                 "description": "Type of biological entity (e.g., receptor, enzyme, pathway)."
#               },
#               {
#                 "name": "role_description",
#                 "type": "string",
#                 "description": "Short description of its role in disease or mechanism (if present)."
#               }
#             ]
#           },
#           {
#             "name": "Event",
#             "description": "A meeting or conference where results are presented (e.g., American Academy of Neurology conference).",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Name of the event or conference."
#               },
#               {
#                 "name": "location_name",
#                 "type": "string",
#                 "description": "Location of the event (city, venue) as mentioned."
#               },
#               {
#                 "name": "date",
#                 "type": "date",
#                 "description": "Date or year of the event (if extractable)."
#               },
#               {
#                 "name": "reception",
#                 "type": "string",
#                 "description": "How the presentation was received (e.g., well-received by the medical community)."
#               }
#             ]
#           },
#           {
#             "name": "RegulatoryAction",
#             "description": "A regulatory process or action mentioned (e.g., expected FDA review, approval).",
#             "attributes": [
#               {
#                 "name": "action",
#                 "type": "string",
#                 "description": "Type of regulatory action (e.g., review, approval)."
#               },
#               {
#                 "name": "agency_name",
#                 "type": "string",
#                 "description": "Name of the regulatory agency involved (e.g., FDA)."
#               },
#               {
#                 "name": "expected_date",
#                 "type": "date",
#                 "description": "Expected date or time frame for the action if mentioned."
#               },
#               {
#                 "name": "status",
#                 "type": "string",
#                 "description": "Status or outcome if reported (e.g., pending, approved)."
#               }
#             ]
#           },
#           {
#             "name": "Location",
#             "description": "Geographic place referenced (city, state, country) useful for events and organization locations.",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Textual name of the location (e.g., Seattle)."
#               },
#               {
#                 "name": "city",
#                 "type": "string",
#                 "description": "City name if present."
#               },
#               {
#                 "name": "state_or_region",
#                 "type": "string",
#                 "description": "State or region if present."
#               },
#               {
#                 "name": "country",
#                 "type": "string",
#                 "description": "Country name if present."
#               }
#             ]
#           }
#         ],
#         "relation_types": [
#           {
#             "name": "works_at",
#             "description": "Indicates that a person is affiliated with or works at an organization.",
#             "domain": "Person",
#             "range": "Organization"
#           },
#           {
#             "name": "leads_trial",
#             "description": "A person (e.g., principal investigator) leads or directs a clinical trial.",
#             "domain": "Person",
#             "range": "ClinicalTrial"
#           },
#           {
#             "name": "conducted_by",
#             "description": "The organization that conducted or hosted the clinical trial.",
#             "domain": "ClinicalTrial",
#             "range": "Organization"
#           },
#           {
#             "name": "tests_medication",
#             "description": "Indicates that a clinical trial evaluated or tested a given medication.",
#             "domain": "ClinicalTrial",
#             "range": "Medication"
#           },
#           {
#             "name": "targets_condition",
#             "description": "The clinical trial is aimed at studying or treating a specific condition.",
#             "domain": "ClinicalTrial",
#             "range": "Condition"
#           },
#           {
#             "name": "has_outcome",
#             "description": "Links a clinical trial to a reported outcome or endpoint.",
#             "domain": "ClinicalTrial",
#             "range": "Outcome"
#           },
#           {
#             "name": "measures_condition",
#             "description": "An outcome metric that measures or quantifies a condition.",
#             "domain": "Outcome",
#             "range": "Condition"
#           },
#           {
#             "name": "reports_adverse_event",
#             "description": "A clinical trial reports one or more adverse events observed among participants.",
#             "domain": "ClinicalTrial",
#             "range": "AdverseEvent"
#           },
#           {
#             "name": "causes_adverse_event",
#             "description": "Indicates an association between a medication and an adverse event.",
#             "domain": "Medication",
#             "range": "AdverseEvent"
#           },
#           {
#             "name": "has_mechanism",
#             "description": "Connects a medication to its biological target or mechanism of action.",
#             "domain": "Medication",
#             "range": "BiologicalTarget"
#           },
#           {
#             "name": "presented_at",
#             "description": "A person presented findings at an event (conference).",
#             "domain": "Person",
#             "range": "Event"
#           },
#           {
#             "name": "reported_at",
#             "description": "The clinical trial's results were reported or presented at an event.",
#             "domain": "ClinicalTrial",
#             "range": "Event"
#           },
#           {
#             "name": "located_in",
#             "description": "Indicates the geographic location of an organization or event.",
#             "domain": "Organization",
#             "range": "Location"
#           },
#           {
#             "name": "event_located_in",
#             "description": "Specifies the geographic location for an event.",
#             "domain": "Event",
#             "range": "Location"
#           },
#           {
#             "name": "reviews",
#             "description": "A regulatory organization reviews trial data or a medication (e.g., FDA reviewing data).",
#             "domain": "Organization",
#             "range": "ClinicalTrial"
#           },
#           {
#             "name": "regulatory_action_by",
#             "description": "Links a regulatory action record to the agency or organization performing it.",
#             "domain": "RegulatoryAction",
#             "range": "Organization"
#           },
#           {
#             "name": "regulatory_action_targets_trial",
#             "description": "Indicates that a regulatory action is targeted at a clinical trial or its data.",
#             "domain": "RegulatoryAction",
#             "range": "ClinicalTrial"
#           },
#           {
#             "name": "regulatory_action_targets_medication",
#             "description": "Indicates that a regulatory action is targeted at a medication (e.g., approval/review).",
#             "domain": "RegulatoryAction",
#             "range": "Medication"
#           }
#         ]
#       },
#       "text_purpose": "Summarize and report a clinical trial evaluating Medication A for chronic migraines — including study design, participants, results (efficacy and side effects), mechanism of action, presentation at a conference, institutional context, and anticipated regulatory review.",
#       "reasoning": "I designed a balanced ontology focused on clinical research and related entities that appear in the text. Entity types were chosen to cover recurring and central concepts: persons (investigators/presenters), organizations (hospital, FDA, professional society), clinical trials (study-level metadata), medications, medical conditions, outcomes (endpoints/results), adverse events (side effects), biological targets (mechanism), events (conferences), regulatory actions (expected reviews), and locations. This set is general enough to apply across similar clinical-trial reports yet specific enough to capture analytically important distinctions (e.g., outcomes vs. adverse events, trials vs. medications). Relation types were selected to reflect common, meaningful interactions in clinical reports: affiliations (works_at), trial leadership, which organization conducted a trial, trial→medication and trial→condition links, how outcomes map to conditions, reporting of adverse events, mechanism links (medication→target), presentation/reporting at conferences, and regulatory review actions. Attribute choices follow the 'balanced' guideline (2–4 useful, extractable attributes per entity) emphasizing information commonly present in such texts (enrollment counts, age ranges, duration, effect sizes, incidence percentages, mechanism descriptions, and expected regulatory dates). The ontology avoids overly specific roles or redundant relations while supporting typical queries: Who led the trial? Where was it conducted? What medication and mechanism were studied? What were the efficacy and side-effect rates? Has the FDA or another agency been engaged? This design should allow consistent classification by different annotators and be reusable across similar clinical trial summaries."
#     }
#     ---Parsed Response (class OntologyRecommendation)---
#     {
#       "ontology": {
#         "entity_types": [
#           {
#             "name": "Person",
#             "description": "An individual mentioned in the text (e.g., investigators, clinicians, presenters, patients when named).",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Full name of the person."
#               },
#               {
#                 "name": "role",
#                 "type": "string",
#                 "description": "Role or function in the context (e.g., principal investigator, neurologist, presenter)."
#               },
#               {
#                 "name": "specialty",
#                 "type": "string",
#                 "description": "Professional specialty or occupation (e.g., neurologist)."
#               },
#               {
#                 "name": "affiliation_name",
#                 "type": "string",
#                 "description": "Name of the primary organization with which the person is affiliated (extractable from text)."
#               }
#             ]
#           },
#           {
#             "name": "Organization",
#             "description": "An institutional entity (e.g., hospitals, research institutions, regulatory agencies, professional societies).",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Official name of the organization."
#               },
#               {
#                 "name": "type",
#                 "type": "string",
#                 "description": "Category of organization (e.g., hospital, regulatory_agency, professional_society, research_institution)."
#               },
#               {
#                 "name": "location_name",
#                 "type": "string",
#                 "description": "Textual location or headquarters (city, state, country) if mentioned."
#               },
#               {
#                 "name": "research_focus",
#                 "type": "string",
#                 "description": "Short description of the organization's domain or area of research (if stated)."
#               }
#             ]
#           },
#           {
#             "name": "ClinicalTrial",
#             "description": "A clinical study or trial described in the text.",
#             "attributes": [
#               {
#                 "name": "trial_id",
#                 "type": "string",
#                 "description": "Name or identifier of the trial (as given in text)."
#               },
#               {
#                 "name": "enrollment_count",
#                 "type": "int",
#                 "description": "Number of participants enrolled in the trial."
#               },
#               {
#                 "name": "age_min",
#                 "type": "int",
#                 "description": "Minimum participant age included in the trial (years)."
#               },
#               {
#                 "name": "age_max",
#                 "type": "int",
#                 "description": "Maximum participant age included in the trial (years)."
#               },
#               {
#                 "name": "duration_weeks",
#                 "type": "int",
#                 "description": "Planned or actual duration of intervention/follow-up in weeks."
#               },
#               {
#                 "name": "control_type",
#                 "type": "string",
#                 "description": "Control or comparator used (e.g., placebo-controlled, active comparator)."
#               },
#               {
#                 "name": "status",
#                 "type": "string",
#                 "description": "Trial status mentioned (e.g., completed, ongoing, results_presented)."
#               }
#             ]
#           },
#           {
#             "name": "Medication",
#             "description": "A therapeutic compound or drug evaluated or mentioned in the text.",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Medication name or identifier."
#               },
#               {
#                 "name": "indication",
#                 "type": "string",
#                 "description": "Condition(s) the medication is intended to treat (as mentioned)."
#               },
#               {
#                 "name": "mechanism_summary",
#                 "type": "string",
#                 "description": "Short description of the drug's mechanism of action (e.g., inhibits CGRP receptors)."
#               },
#               {
#                 "name": "approval_status",
#                 "type": "string",
#                 "description": "Regulatory status or expected regulatory action as mentioned (e.g., FDA review expected)."
#               }
#             ]
#           },
#           {
#             "name": "Condition",
#             "description": "A medical condition, disease, or disorder discussed (e.g., chronic migraine).",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Name of the condition."
#               },
#               {
#                 "name": "chronic",
#                 "type": "bool",
#                 "description": "Whether the condition is described as chronic in the text."
#               },
#               {
#                 "name": "frequency_per_month",
#                 "type": "float",
#                 "description": "Frequency metric if provided (e.g., migraine days per month)."
#               },
#               {
#                 "name": "typical_symptoms",
#                 "type": "string",
#                 "description": "Short description of core symptoms if mentioned."
#               }
#             ]
#           },
#           {
#             "name": "Outcome",
#             "description": "A measured result or endpoint from a study (e.g., reduction in migraine frequency).",
#             "attributes": [
#               {
#                 "name": "metric_name",
#                 "type": "string",
#                 "description": "Name of the outcome metric (e.g., migraine_frequency_reduction)."
#               },
#               {
#                 "name": "value",
#                 "type": "float",
#                 "description": "Numeric value of the outcome (e.g., 50)."
#               },
#               {
#                 "name": "unit",
#                 "type": "string",
#                 "description": "Unit for the outcome value (e.g., percent, days/month)."
#               },
#               {
#                 "name": "comparison",
#                 "type": "string",
#                 "description": "Comparator stated (e.g., versus placebo)."
#               }
#             ]
#           },
#           {
#             "name": "AdverseEvent",
#             "description": "An adverse effect or side effect reported in association with an intervention.",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Name or description of the adverse event (e.g., nausea)."
#               },
#               {
#                 "name": "incidence_rate",
#                 "type": "float",
#                 "description": "Reported incidence as a percentage (if provided)."
#               },
#               {
#                 "name": "severity",
#                 "type": "string",
#                 "description": "Severity descriptor if given (e.g., common, severe)."
#               }
#             ]
#           },
#           {
#             "name": "BiologicalTarget",
#             "description": "A biological molecule or target referenced as the mechanism of action (e.g., CGRP receptor).",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Name of the biological target."
#               },
#               {
#                 "name": "target_type",
#                 "type": "string",
#                 "description": "Type of biological entity (e.g., receptor, enzyme, pathway)."
#               },
#               {
#                 "name": "role_description",
#                 "type": "string",
#                 "description": "Short description of its role in disease or mechanism (if present)."
#               }
#             ]
#           },
#           {
#             "name": "Event",
#             "description": "A meeting or conference where results are presented (e.g., American Academy of Neurology conference).",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Name of the event or conference."
#               },
#               {
#                 "name": "location_name",
#                 "type": "string",
#                 "description": "Location of the event (city, venue) as mentioned."
#               },
#               {
#                 "name": "date",
#                 "type": "date",
#                 "description": "Date or year of the event (if extractable)."
#               },
#               {
#                 "name": "reception",
#                 "type": "string",
#                 "description": "How the presentation was received (e.g., well-received by the medical community)."
#               }
#             ]
#           },
#           {
#             "name": "RegulatoryAction",
#             "description": "A regulatory process or action mentioned (e.g., expected FDA review, approval).",
#             "attributes": [
#               {
#                 "name": "action",
#                 "type": "string",
#                 "description": "Type of regulatory action (e.g., review, approval)."
#               },
#               {
#                 "name": "agency_name",
#                 "type": "string",
#                 "description": "Name of the regulatory agency involved (e.g., FDA)."
#               },
#               {
#                 "name": "expected_date",
#                 "type": "date",
#                 "description": "Expected date or time frame for the action if mentioned."
#               },
#               {
#                 "name": "status",
#                 "type": "string",
#                 "description": "Status or outcome if reported (e.g., pending, approved)."
#               }
#             ]
#           },
#           {
#             "name": "Location",
#             "description": "Geographic place referenced (city, state, country) useful for events and organization locations.",
#             "attributes": [
#               {
#                 "name": "name",
#                 "type": "string",
#                 "description": "Textual name of the location (e.g., Seattle)."
#               },
#               {
#                 "name": "city",
#                 "type": "string",
#                 "description": "City name if present."
#               },
#               {
#                 "name": "state_or_region",
#                 "type": "string",
#                 "description": "State or region if present."
#               },
#               {
#                 "name": "country",
#                 "type": "string",
#                 "description": "Country name if present."
#               }
#             ]
#           }
#         ],
#         "relation_types": [
#           {
#             "name": "works_at",
#             "description": "Indicates that a person is affiliated with or works at an organization.",
#             "domain": "Person",
#             "range": "Organization"
#           },
#           {
#             "name": "leads_trial",
#             "description": "A person (e.g., principal investigator) leads or directs a clinical trial.",
#             "domain": "Person",
#             "range": "ClinicalTrial"
#           },
#           {
#             "name": "conducted_by",
#             "description": "The organization that conducted or hosted the clinical trial.",
#             "domain": "ClinicalTrial",
#             "range": "Organization"
#           },
#           {
#             "name": "tests_medication",
#             "description": "Indicates that a clinical trial evaluated or tested a given medication.",
#             "domain": "ClinicalTrial",
#             "range": "Medication"
#           },
#           {
#             "name": "targets_condition",
#             "description": "The clinical trial is aimed at studying or treating a specific condition.",
#             "domain": "ClinicalTrial",
#             "range": "Condition"
#           },
#           {
#             "name": "has_outcome",
#             "description": "Links a clinical trial to a reported outcome or endpoint.",
#             "domain": "ClinicalTrial",
#             "range": "Outcome"
#           },
#           {
#             "name": "measures_condition",
#             "description": "An outcome metric that measures or quantifies a condition.",
#             "domain": "Outcome",
#             "range": "Condition"
#           },
#           {
#             "name": "reports_adverse_event",
#             "description": "A clinical trial reports one or more adverse events observed among participants.",
#             "domain": "ClinicalTrial",
#             "range": "AdverseEvent"
#           },
#           {
#             "name": "causes_adverse_event",
#             "description": "Indicates an association between a medication and an adverse event.",
#             "domain": "Medication",
#             "range": "AdverseEvent"
#           },
#           {
#             "name": "has_mechanism",
#             "description": "Connects a medication to its biological target or mechanism of action.",
#             "domain": "Medication",
#             "range": "BiologicalTarget"
#           },
#           {
#             "name": "presented_at",
#             "description": "A person presented findings at an event (conference).",
#             "domain": "Person",
#             "range": "Event"
#           },
#           {
#             "name": "reported_at",
#             "description": "The clinical trial's results were reported or presented at an event.",
#             "domain": "ClinicalTrial",
#             "range": "Event"
#           },
#           {
#             "name": "located_in",
#             "description": "Indicates the geographic location of an organization or event.",
#             "domain": "Organization",
#             "range": "Location"
#           },
#           {
#             "name": "event_located_in",
#             "description": "Specifies the geographic location for an event.",
#             "domain": "Event",
#             "range": "Location"
#           },
#           {
#             "name": "reviews",
#             "description": "A regulatory organization reviews trial data or a medication (e.g., FDA reviewing data).",
#             "domain": "Organization",
#             "range": "ClinicalTrial"
#           },
#           {
#             "name": "regulatory_action_by",
#             "description": "Links a regulatory action record to the agency or organization performing it.",
#             "domain": "RegulatoryAction",
#             "range": "Organization"
#           },
#           {
#             "name": "regulatory_action_targets_trial",
#             "description": "Indicates that a regulatory action is targeted at a clinical trial or its data.",
#             "domain": "RegulatoryAction",
#             "range": "ClinicalTrial"
#           },
#           {
#             "name": "regulatory_action_targets_medication",
#             "description": "Indicates that a regulatory action is targeted at a medication (e.g., approval/review).",
#             "domain": "RegulatoryAction",
#             "range": "Medication"
#           }
#         ]
#       },
#       "text_purpose": "Summarize and report a clinical trial evaluating Medication A for chronic migraines — including study design, participants, results (efficacy and side effects), mechanism of action, presentation at a conference, institutional context, and anticipated regulatory review.",
#       "reasoning": "I designed a balanced ontology focused on clinical research and related entities that appear in the text. Entity types were chosen to cover recurring and central concepts: persons (investigators/presenters), organizations (hospital, FDA, professional society), clinical trials (study-level metadata), medications, medical conditions, outcomes (endpoints/results), adverse events (side effects), biological targets (mechanism), events (conferences), regulatory actions (expected reviews), and locations. This set is general enough to apply across similar clinical-trial reports yet specific enough to capture analytically important distinctions (e.g., outcomes vs. adverse events, trials vs. medications). Relation types were selected to reflect common, meaningful interactions in clinical reports: affiliations (works_at), trial leadership, which organization conducted a trial, trial→medication and trial→condition links, how outcomes map to conditions, reporting of adverse events, mechanism links (medication→target), presentation/reporting at conferences, and regulatory review actions. Attribute choices follow the 'balanced' guideline (2–4 useful, extractable attributes per entity) emphasizing information commonly present in such texts (enrollment counts, age ranges, duration, effect sizes, incidence percentages, mechanism descriptions, and expected regulatory dates). The ontology avoids overly specific roles or redundant relations while supporting typical queries: Who led the trial? Where was it conducted? What medication and mechanism were studied? What were the efficacy and side-effect rates? Has the FDA or another agency been engaged? This design should allow consistent classification by different annotators and be reusable across similar clinical trial summaries."
#     }

# %%
# Step 2: Use the recommended ontology to extract triples
print("Step 2: Extract triples using recommended ontology")
print("-" * 70)

extractor = SpindleExtractor(recommendation.ontology)
extraction_result = extractor.extract(
    text=medical_text,
    source_name="Medical Research Abstract 2024",
    source_url="https://example.com/research/abstract-001"
)

print(f"Extracted {len(extraction_result.triples)} triples:\n")
# Out:
# Step 2: Extract triples using recommended ontology
# ----------------------------------------------------------------------
# 2025-11-03T16:59:32.623 [BAML INFO] Function ExtractTriples:
#     Client: CustomHaiku (claude-3-5-haiku-20241022) - 19790ms. StopReason: end_turn. Tokens(in/out): 3491/1501
#     ---PROMPT---
#     user: You are a knowledge graph extraction expert. Your task is to extract structured triples (subject-predicate-object) from the provided text, with rich entity metadata, custom attributes, and supporting evidence.ONTOLOGY:
#     You must extract triples that conform to the following ontology:
#
#     Valid Entity Types:
#     - Person: An individual mentioned in the text (e.g., investigators, clinicians, presenters, patients when named).
#       Custom Attributes:
#         * name (string): Full name of the person.
#         * role (string): Role or function in the context (e.g., principal investigator, neurologist, presenter).
#         * specialty (string): Professional specialty or occupation (e.g., neurologist).
#         * affiliation_name (string): Name of the primary organization with which the person is affiliated (extractable from text).
#     - Organization: An institutional entity (e.g., hospitals, research institutions, regulatory agencies, professional societies).
#       Custom Attributes:
#         * name (string): Official name of the organization.
#         * type (string): Category of organization (e.g., hospital, regulatory_agency, professional_society, research_institution).
#         * location_name (string): Textual location or headquarters (city, state, country) if mentioned.
#         * research_focus (string): Short description of the organization's domain or area of research (if stated).
#     - ClinicalTrial: A clinical study or trial described in the text.
#       Custom Attributes:
#         * trial_id (string): Name or identifier of the trial (as given in text).
#         * enrollment_count (int): Number of participants enrolled in the trial.
#         * age_min (int): Minimum participant age included in the trial (years).
#     Extracted 3 triples:
#
#     * age_max (int): Maximum participant age included in the trial (years).
#         * duration_weeks (int): Planned or actual duration of intervention/follow-up in weeks.
#         * control_type (string): Control or comparator used (e.g., placebo-controlled, active comparator).
#         * status (string): Trial status mentioned (e.g., completed, ongoing, results_presented).
#     - Medication: A therapeutic compound or drug evaluated or mentioned in the text.
#       Custom Attributes:
#         * name (string): Medication name or identifier.
#         * indication (string): Condition(s) the medication is intended to treat (as mentioned).
#         * mechanism_summary (string): Short description of the drug's mechanism of action (e.g., inhibits CGRP receptors).
#         * approval_status (string): Regulatory status or expected regulatory action as mentioned (e.g., FDA review expected).
#     - Condition: A medical condition, disease, or disorder discussed (e.g., chronic migraine).
#       Custom Attributes:
#         * name (string): Name of the condition.
#         * chronic (bool): Whether the condition is described as chronic in the text.
#         * frequency_per_month (float): Frequency metric if provided (e.g., migraine days per month).
#         * typical_symptoms (string): Short description of core symptoms if mentioned.
#     - Outcome: A measured result or endpoint from a study (e.g., reduction in migraine frequency).
#       Custom Attributes:
#         * metric_name (string): Name of the outcome metric (e.g., migraine_frequency_reduction).
#         * value (float): Numeric value of the outcome (e.g., 50).
#         * unit (string): Unit for the outcome value (e.g., percent, days/month).
#         * comparison (string): Comparator stated (e.g., versus placebo).
#     - AdverseEvent: An adverse effect or side effect reported in association with an intervention.
#       Custom Attributes:
#         * name (string): Name or description of the adverse event (e.g., nausea).
#         * incidence_rate (float): Reported incidence as a percentage (if provided).
#         * severity (string): Severity descriptor if given (e.g., common, severe).
#     - BiologicalTarget: A biological molecule or target referenced as the mechanism of action (e.g., CGRP receptor).
#       Custom Attributes:
#         * name (string): Name of the biological target.
#         * target_type (string): Type of biological entity (e.g., receptor, enzyme, pathway).
#         * role_description (string): Short description of its role in disease or mechanism (if present).
#     - Event: A meeting or conference where results are presented (e.g., American Academy of Neurology conference).
#       Custom Attributes:
#         * name (string): Name of the event or conference.
#         * location_name (string): Location of the event (city, venue) as mentioned.
#         * date (date): Date or year of the event (if extractable).
#         * reception (string): How the presentation was received (e.g., well-received by the medical community).
#     - RegulatoryAction: A regulatory process or action mentioned (e.g., expected FDA review, approval).
#       Custom Attributes:
#         * action (string): Type of regulatory action (e.g., review, approval).
#         * agency_name (string): Name of the regulatory agency involved (e.g., FDA).
#         * expected_date (date): Expected date or time frame for the action if mentioned.
#         * status (string): Status or outcome if reported (e.g., pending, approved).
#     - Location: Geographic place referenced (city, state, country) useful for events and organization locations.
#       Custom Attributes:
#         * name (string): Textual name of the location (e.g., Seattle).
#         * city (string): City name if present.
#         * state_or_region (string): State or region if present.
#         * country (string): Country name if present.
#
#     Valid Relation Types:
#     - works_at: Indicates that a person is affiliated with or works at an organization.
#       (Domain: Person, Range: Organization)
#     - leads_trial: A person (e.g., principal investigator) leads or directs a clinical trial.
#       (Domain: Person, Range: ClinicalTrial)
#     - conducted_by: The organization that conducted or hosted the clinical trial.
#       (Domain: ClinicalTrial, Range: Organization)
#     - tests_medication: Indicates that a clinical trial evaluated or tested a given medication.
#       (Domain: ClinicalTrial, Range: Medication)
#     - targets_condition: The clinical trial is aimed at studying or treating a specific condition.
#       (Domain: ClinicalTrial, Range: Condition)
#     - has_outcome: Links a clinical trial to a reported outcome or endpoint.
#       (Domain: ClinicalTrial, Range: Outcome)
#     - measures_condition: An outcome metric that measures or quantifies a condition.
#       (Domain: Outcome, Range: Condition)
#     - reports_adverse_event: A clinical trial reports one or more adverse events observed among participants.
#       (Domain: ClinicalTrial, Range: AdverseEvent)
#     - causes_adverse_event: Indicates an association between a medication and an adverse event.
#       (Domain: Medication, Range: AdverseEvent)
#     - has_mechanism: Connects a medication to its biological target or mechanism of action.
#       (Domain: Medication, Range: BiologicalTarget)
#     - presented_at: A person presented findings at an event (conference).
#       (Domain: Person, Range: Event)
#     - reported_at: The clinical trial's results were reported or presented at an event.
#       (Domain: ClinicalTrial, Range: Event)
#     - located_in: Indicates the geographic location of an organization or event.
#       (Domain: Organization, Range: Location)
#     - event_located_in: Specifies the geographic location for an event.
#       (Domain: Event, Range: Location)
#     - reviews: A regulatory organization reviews trial data or a medication (e.g., FDA reviewing data).
#       (Domain: Organization, Range: ClinicalTrial)
#     - regulatory_action_by: Links a regulatory action record to the agency or organization performing it.
#       (Domain: RegulatoryAction, Range: Organization)
#     - regulatory_action_targets_trial: Indicates that a regulatory action is targeted at a clinical trial or its data.
#       (Domain: RegulatoryAction, Range: ClinicalTrial)
#     - regulatory_action_targets_medication: Indicates that a regulatory action is targeted at a medication (e.g., approval/review).
#       (Domain: RegulatoryAction, Range: Medication)
#
#     SOURCE METADATA:
#     Source Name: Medical Research Abstract 2024
#     Source URL: https://example.com/research/abstract-001
#
#     EXISTING TRIPLES:
#     This is the first extraction, so there are no existing triples to consider.
#
#     TEXT TO ANALYZE:
#
#     A recent clinical trial evaluated the efficacy of Medication A in treating
#     patients with chronic migraines. The study, conducted at Massachusetts General
#     Hospital, enrolled 250 patients aged 18-65 who experienced at least 8 migraine
#     days per month. Dr. Sarah Chen, the principal investigator, led a team of
#     neurologists who administered the drug over a 12-week period.
#
#     Results showed that Medication A reduced migraine frequency by an average of
#     50% compared to the placebo group. Common side effects included nausea and
#     dizziness, which affected approximately 15% of participants. The medication
#     works by inhibiting CGRP receptors, which are known to play a role in migraine
#     pathophysiology.
#
#     Dr. Chen reported the findings at the American Academy of Neurology conference
#     in Seattle, where the research was well-received by the medical community. The
#     FDA is expected to review the data for potential approval in the coming year.
#     Massachusetts General Hospital has been a leading research institution in
#     neurology for decades and continues to conduct groundbreaking studies in
#     headache disorders.
#
#
#     ENTITY EXTRACTION INSTRUCTIONS:
#
#     For each entity in a triple (both subject and object), you MUST provide:
#
#     1. **name**: The entity's name or identifier from the text
#        - Use clear, consistent names (e.g., "John Smith" not "John" or "Smith")
#        - If the entity appears in existing triples, use the EXACT same name
#
#     2. **type**: The entity type from the ontology
#        - Must match exactly one of the EntityType names defined above
#        - Check domain/range constraints in relation types
#
#     3. **description**: A brief description of the entity
#        - Generate this from the text context (1-2 sentences)
#        - Include relevant details that help identify or characterize the entity
#        - Be concise but informative
#
#     4. **custom_atts**: Extract ALL attributes defined for this entity type
#        - Format: {"attribute_name": {"value": "extracted_value", "type": "attribute_type"}}
#        - Set "value" to null if the attribute is not mentioned in the text
#        - "type" must match the type from the AttributeDefinition
#        - Extract dates in ISO format (YYYY-MM-DD) when possible
#        - For nested objects, use JSON string representation
#
#     TRIPLE EXTRACTION INSTRUCTIONS:
#
#     1. Extract all meaningful triples from the text that conform to the ontology
#     2. Only use entity types and relation types defined in the ontology
#     3. For each triple, identify TEXT SPANS that provide evidence:
#        - Copy the EXACT text from the source that supports the triple
#        - You can include multiple text spans if evidence is spread across different parts
#        - Be precise - copy text exactly as it appears, including punctuation and spacing
#        - Include enough context to make the evidence clear
#     4. Provide reasoning explaining your extraction decisions
#
#     EXAMPLE:
#
#     Text: "The Check Your A1C campaign launched on August 10, 2025, targeting diabetic members to remind them to get their A1C checked."
#
#     Ontology has EntityType "Campaign" with attributes:
#     - campaign_launch_dt (date): Launch date
#     - campaign_completion_dt (date): Completion date
#
#     Extracted entity for subject:
#     {
#       "name": "Check Your A1C campaign",
#       "type": "Campaign",
#       "description": "A campaign targeting diabetic members to remind them to get their A1C checked",
#       "custom_atts": {
#         "campaign_launch_dt": {"value": "2025-08-10", "type": "date"},
#         "campaign_completion_dt": {"value": null, "type": "date"}
#       }
#     }
#
#     Note: Character indices for supporting spans will be computed automatically in post-processing.
#
#     Answer in JSON using this schema:
#     {
#       // List of extracted triples from the text
#       triples: [
#         {
#           // The subject entity with full metadata and attributes
#           subject: {
#             // The entity's name or identifier extracted from the text
#             name: string,
#             // The entity type from the ontology (must match an EntityType.name exactly)
#             type: string,
#             // A brief description of the entity generated from the text context
#             description: string,
#             // Type-specific attributes as defined in the entity type's AttributeDefinition list
#             custom_atts: map<string, {
#               // The extracted value as a string, or null if not found in the text
#               value: string or null,
#               // The data type of this attribute (matches the type from AttributeDefinition)
#               type: string,
#             }>,
#           },
#           // The relationship/predicate connecting subject and object
#           predicate: string,
#           // The object entity with full metadata and attributes
#           object: {
#             // The entity's name or identifier extracted from the text
#             name: string,
#             // The entity type from the ontology (must match an EntityType.name exactly)
#             type: string,
#             // A brief description of the entity generated from the text context
#             description: string,
#             // Type-specific attributes as defined in the entity type's AttributeDefinition list
#             custom_atts: map<string, {
#               // The extracted value as a string, or null if not found in the text
#               value: string or null,
#               // The data type of this attribute (matches the type from AttributeDefinition)
#               type: string,
#             }>,
#           },
#           // Metadata about the source of this triple
#           source: {
#             // The name or identifier of the source document
#             source_name: string,
#             // Optional URL of the source document
#             source_url: string or null,
#           },
#           // Character spans in the source text that support this triple
#           supporting_spans: [
#             {
#               // The exact text from the source that supports this triple
#               text: string,
#               // Starting character index in the source text (0-based, computed in post-processing)
#               start: int or null,
#               // Ending character index in the source text (exclusive, computed in post-processing)
#               end: int or null,
#             }
#           ],
#           // ISO 8601 datetime when this triple was extracted (set automatically in post-processing)
#           extraction_datetime: string or null,
#         }
#       ],
#       // Explanation of the extraction decisions and entity consistency choices
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     I'll help you extract the knowledge graph triples from this medical research abstract. I'll follow the specified ontology and extraction guidelines.
#
#     {
#       "triples": [
#         {
#           "subject": {
#             "name": "Sarah Chen",
#             "type": "Person",
#             "description": "Principal investigator of a clinical trial studying medication for chronic migraines",
#             "custom_atts": {
#               "name": {"value": "Sarah Chen", "type": "string"},
#               "role": {"value": "Principal Investigator", "type": "string"},
#               "specialty": {"value": "Neurologist", "type": "string"},
#               "affiliation_name": {"value": "Massachusetts General Hospital", "type": "string"}
#             }
#           },
#           "predicate": "works_at",
#           "object": {
#             "name": "Massachusetts General Hospital",
#             "type": "Organization",
#             "description": "A leading research institution in neurology that conducted a clinical trial on migraine medication",
#             "custom_atts": {
#               "name": {"value": "Massachusetts General Hospital", "type": "string"},
#               "type": {"value": "hospital", "type": "string"},
#               "location_name": {"value": null, "type": "string"},
#               "research_focus": {"value": "Neurology and headache disorders", "type": "string"}
#             }
#           },
#           "source": {
#             "source_name": "Medical Research Abstract 2024",
#             "source_url": "https://example.com/research/abstract-001"
#           },
#           "supporting_spans": [
#             {
#               "text": "Dr. Sarah Chen, the principal investigator, led a team of neurologists who administered the drug over a 12-week period.",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "Clinical Trial for Medication A",
#             "type": "ClinicalTrial",
#             "description": "A 12-week study evaluating the efficacy of Medication A in treating chronic migraines",
#             "custom_atts": {
#               "trial_id": {"value": null, "type": "string"},
#               "enrollment_count": {"value": "250", "type": "int"},
#               "age_min": {"value": "18", "type": "int"},
#               "age_max": {"value": "65", "type": "int"},
#               "duration_weeks": {"value": "12", "type": "int"},
#               "control_type": {"value": "placebo-controlled", "type": "string"},
#               "status": {"value": "completed", "type": "string"}
#             }
#           },
#           "predicate": "conducted_by",
#           "object": {
#             "name": "Massachusetts General Hospital",
#             "type": "Organization",
#             "description": "A leading research institution in neurology that conducted a clinical trial on migraine medication",
#             "custom_atts": {
#               "name": {"value": "Massachusetts General Hospital", "type": "string"},
#               "type": {"value": "hospital", "type": "string"},
#               "location_name": {"value": null, "type": "string"},
#               "research_focus": {"value": "Neurology and headache disorders", "type": "string"}
#             }
#           },
#           "source": {
#             "source_name": "Medical Research Abstract 2024",
#             "source_url": "https://example.com/research/abstract-001"
#           },
#           "supporting_spans": [
#             {
#               "text": "A recent clinical trial evaluated the efficacy of Medication A in treating patients with chronic migraines. The study, conducted at Massachusetts General Hospital, enrolled 250 patients aged 18-65 who experienced at least 8 migraine days per month.",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "Medication A",
#             "type": "Medication",
#             "description": "A drug developed to treat chronic migraines by targeting CGRP receptors",
#             "custom_atts": {
#               "name": {"value": "Medication A", "type": "string"},
#               "indication": {"value": "Chronic Migraine", "type": "string"},
#               "mechanism_summary": {"value": "Inhibits CGRP receptors", "type": "string"},
#               "approval_status": {"value": "FDA review expected", "type": "string"}
#             }
#           },
#           "predicate": "tests_medication",
#           "object": {
#             "name": "Clinical Trial for Medication A",
#             "type": "ClinicalTrial",
#             "description": "A 12-week study evaluating the efficacy of Medication A in treating chronic migraines",
#             "custom_atts": {
#               "trial_id": {"value": null, "type": "string"},
#               "enrollment_count": {"value": "250", "type": "int"},
#               "age_min": {"value": "18", "type": "int"},
#               "age_max": {"value": "65", "type": "int"},
#               "duration_weeks": {"value": "12", "type": "int"},
#               "control_type": {"value": "placebo-controlled", "type": "string"},
#               "status": {"value": "completed", "type": "string"}
#             }
#           },
#           "source": {
#             "source_name": "Medical Research Abstract 2024",
#             "source_url": "https://example.com/research/abstract-001"
#           },
#           "supporting_spans": [
#             {
#               "text": "A recent clinical trial evaluated the efficacy of Medication A in treating patients with chronic migraines.",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         }
#       ],
#       "reasoning": "Extracted key relationships between people, organizations, medications, and clinical trials. Focused on capturing the core entities and their connections based on the text. Ensured that entity names, types, and attributes match the specified ontology."
#     }
#     ---Parsed Response (class ExtractionResult)---
#     {
#       "triples": [
#         {
#           "subject": {
#             "name": "Sarah Chen",
#             "type": "Person",
#             "description": "Principal investigator of a clinical trial studying medication for chronic migraines",
#             "custom_atts": {
#               "name": {
#                 "value": "Sarah Chen",
#                 "type": "string"
#               },
#               "role": {
#                 "value": "Principal Investigator",
#                 "type": "string"
#               },
#               "specialty": {
#                 "value": "Neurologist",
#                 "type": "string"
#               },
#               "affiliation_name": {
#                 "value": "Massachusetts General Hospital",
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "works_at",
#           "object": {
#             "name": "Massachusetts General Hospital",
#             "type": "Organization",
#             "description": "A leading research institution in neurology that conducted a clinical trial on migraine medication",
#             "custom_atts": {
#               "name": {
#                 "value": "Massachusetts General Hospital",
#                 "type": "string"
#               },
#               "type": {
#                 "value": "hospital",
#                 "type": "string"
#               },
#               "location_name": {
#                 "value": null,
#                 "type": "string"
#               },
#               "research_focus": {
#                 "value": "Neurology and headache disorders",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "Medical Research Abstract 2024",
#             "source_url": "https://example.com/research/abstract-001"
#           },
#           "supporting_spans": [
#             {
#               "text": "Dr. Sarah Chen, the principal investigator, led a team of neurologists who administered the drug over a 12-week period.",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "Clinical Trial for Medication A",
#             "type": "ClinicalTrial",
#             "description": "A 12-week study evaluating the efficacy of Medication A in treating chronic migraines",
#             "custom_atts": {
#               "trial_id": {
#                 "value": null,
#                 "type": "string"
#               },
#               "enrollment_count": {
#                 "value": "250",
#                 "type": "int"
#               },
#               "age_min": {
#                 "value": "18",
#                 "type": "int"
#               },
#               "age_max": {
#                 "value": "65",
#                 "type": "int"
#               },
#               "duration_weeks": {
#                 "value": "12",
#                 "type": "int"
#               },
#               "control_type": {
#                 "value": "placebo-controlled",
#                 "type": "string"
#               },
#               "status": {
#                 "value": "completed",
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "conducted_by",
#           "object": {
#             "name": "Massachusetts General Hospital",
#             "type": "Organization",
#             "description": "A leading research institution in neurology that conducted a clinical trial on migraine medication",
#             "custom_atts": {
#               "name": {
#                 "value": "Massachusetts General Hospital",
#                 "type": "string"
#               },
#               "type": {
#                 "value": "hospital",
#                 "type": "string"
#               },
#               "location_name": {
#                 "value": null,
#                 "type": "string"
#               },
#               "research_focus": {
#                 "value": "Neurology and headache disorders",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "Medical Research Abstract 2024",
#             "source_url": "https://example.com/research/abstract-001"
#           },
#           "supporting_spans": [
#             {
#               "text": "A recent clinical trial evaluated the efficacy of Medication A in treating patients with chronic migraines. The study, conducted at Massachusetts General Hospital, enrolled 250 patients aged 18-65 who experienced at least 8 migraine days per month.",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "Medication A",
#             "type": "Medication",
#             "description": "A drug developed to treat chronic migraines by targeting CGRP receptors",
#             "custom_atts": {
#               "name": {
#                 "value": "Medication A",
#                 "type": "string"
#               },
#               "indication": {
#                 "value": "Chronic Migraine",
#                 "type": "string"
#               },
#               "mechanism_summary": {
#                 "value": "Inhibits CGRP receptors",
#                 "type": "string"
#               },
#               "approval_status": {
#                 "value": "FDA review expected",
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "tests_medication",
#           "object": {
#             "name": "Clinical Trial for Medication A",
#             "type": "ClinicalTrial",
#             "description": "A 12-week study evaluating the efficacy of Medication A in treating chronic migraines",
#             "custom_atts": {
#               "trial_id": {
#                 "value": null,
#                 "type": "string"
#               },
#               "enrollment_count": {
#                 "value": "250",
#                 "type": "int"
#               },
#               "age_min": {
#                 "value": "18",
#                 "type": "int"
#               },
#               "age_max": {
#                 "value": "65",
#                 "type": "int"
#               },
#               "duration_weeks": {
#                 "value": "12",
#                 "type": "int"
#               },
#               "control_type": {
#                 "value": "placebo-controlled",
#                 "type": "string"
#               },
#               "status": {
#                 "value": "completed",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "Medical Research Abstract 2024",
#             "source_url": "https://example.com/research/abstract-001"
#           },
#           "supporting_spans": [
#             {
#               "text": "A recent clinical trial evaluated the efficacy of Medication A in treating patients with chronic migraines.",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         }
#       ],
#       "reasoning": "Extracted key relationships between people, organizations, medications, and clinical trials. Focused on capturing the core entities and their connections based on the text. Ensured that entity names, types, and attributes match the specified ontology."
#     }

# %%
for i, triple in enumerate(extraction_result.triples, 1):
    print(f"  {i}. ({triple.subject}) --[{triple.predicate}]--> ({triple.object})")
    print(f"     Evidence: {len(triple.supporting_spans)} span(s)")
    print(f"     Extraction datetime: {triple.extraction_datetime}")
    for j, span in enumerate(triple.supporting_spans, 1):
        print(f"       Span {j}: start={span.start}, end={span.end}, text=\"{span.text[:50]}...\"")
print()
# Out:
#   1. (name='Sarah Chen' type='Person' description='Principal investigator of a clinical trial studying medication for chronic migraines' custom_atts={'name': AttributeValue(value='Sarah Chen', type='string'), 'role': AttributeValue(value='Principal Investigator', type='string'), 'specialty': AttributeValue(value='Neurologist', type='string'), 'affiliation_name': AttributeValue(value='Massachusetts General Hospital', type='string')}) --[works_at]--> (name='Massachusetts General Hospital' type='Organization' description='A leading research institution in neurology that conducted a clinical trial on migraine medication' custom_atts={'name': AttributeValue(value='Massachusetts General Hospital', type='string'), 'type': AttributeValue(value='hospital', type='string'), 'location_name': AttributeValue(value=None, type='string'), 'research_focus': AttributeValue(value='Neurology and headache disorders', type='string')})
#      Evidence: 1 span(s)
#      Extraction datetime: 2025-11-03T22:59:32Z
#        Span 1: start=253, end=373, text="Dr. Sarah Chen, the principal investigator, led a ..."
#   2. (name='Clinical Trial for Medication A' type='ClinicalTrial' description='A 12-week study evaluating the efficacy of Medication A in treating chronic migraines' custom_atts={'trial_id': AttributeValue(value=None, type='string'), 'enrollment_count': AttributeValue(value='250', type='int'), 'age_min': AttributeValue(value='18', type='int'), 'age_max': AttributeValue(value='65', type='int'), 'duration_weeks': AttributeValue(value='12', type='int'), 'control_type': AttributeValue(value='placebo-controlled', type='string'), 'status': AttributeValue(value='completed', type='string')}) --[conducted_by]--> (name='Massachusetts General Hospital' type='Organization' description='A leading research institution in neurology that conducted a clinical trial on migraine medication' custom_atts={'name': AttributeValue(value='Massachusetts General Hospital', type='string'), 'type': AttributeValue(value='hospital', type='string'), 'location_name': AttributeValue(value=None, type='string'), 'research_focus': AttributeValue(value='Neurology and headache disorders', type='string')})
#      Evidence: 1 span(s)
#      Extraction datetime: 2025-11-03T22:59:32Z
#        Span 1: start=1, end=252, text="A recent clinical trial evaluated the efficacy of ..."
#   3. (name='Medication A' type='Medication' description='A drug developed to treat chronic migraines by targeting CGRP receptors' custom_atts={'name': AttributeValue(value='Medication A', type='string'), 'indication': AttributeValue(value='Chronic Migraine', type='string'), 'mechanism_summary': AttributeValue(value='Inhibits CGRP receptors', type='string'), 'approval_status': AttributeValue(value='FDA review expected', type='string')}) --[tests_medication]--> (name='Clinical Trial for Medication A' type='ClinicalTrial' description='A 12-week study evaluating the efficacy of Medication A in treating chronic migraines' custom_atts={'trial_id': AttributeValue(value=None, type='string'), 'enrollment_count': AttributeValue(value='250', type='int'), 'age_min': AttributeValue(value='18', type='int'), 'age_max': AttributeValue(value='65', type='int'), 'duration_weeks': AttributeValue(value='12', type='int'), 'control_type': AttributeValue(value='placebo-controlled', type='string'), 'status': AttributeValue(value='completed', type='string')})
#      Evidence: 1 span(s)
#      Extraction datetime: 2025-11-03T22:59:32Z
#        Span 1: start=1, end=109, text="A recent clinical trial evaluated the efficacy of ..."

# %%
# Step 3: Display extraction result with detailed span information
print("Step 3: Detailed extraction result with span indices")
print("-" * 70)

triples_dict = triples_to_dict(extraction_result.triples)
print(json.dumps(triples_dict, indent=2))
# Out:
# Step 3: Detailed extraction result with span indices
# ----------------------------------------------------------------------
# [
#   {
#     "subject": {
#       "name": "Sarah Chen",
#       "type": "Person",
#       "description": "Principal investigator of a clinical trial studying medication for chronic migraines",
#       "custom_atts": {
#         "name": {
#           "value": "Sarah Chen",
#           "type": "string"
#         },
#         "role": {
#           "value": "Principal Investigator",
#           "type": "string"
#         },
#         "specialty": {
#           "value": "Neurologist",
#           "type": "string"
#         },
#         "affiliation_name": {
#           "value": "Massachusetts General Hospital",
#           "type": "string"
#         }
#       }
#     },
#     "predicate": "works_at",
#     "object": {
#       "name": "Massachusetts General Hospital",
#       "type": "Organization",
#       "description": "A leading research institution in neurology that conducted a clinical trial on migraine medication",
#       "custom_atts": {
#         "name": {
#           "value": "Massachusetts General Hospital",
#           "type": "string"
#         },
#         "type": {
#           "value": "hospital",
#           "type": "string"
#         },
#         "location_name": {
#           "value": null,
#           "type": "string"
#         },
#         "research_focus": {
#           "value": "Neurology and headache disorders",
#           "type": "string"
#         }
#       }
#     },
#     "source": {
#       "source_name": "Medical Research Abstract 2024",
#       "source_url": "https://example.com/research/abstract-001"
#     },
#     "supporting_spans": [
#       {
#         "text": "Dr. Sarah Chen, the principal investigator, led a team of neurologists who administered the drug over a 12-week period.",
#         "start": 253,
#         "end": 373
#       }
#     ],
#     "extraction_datetime": "2025-11-03T22:59:32Z"
#   },
#   {
#     "subject": {
#       "name": "Clinical Trial for Medication A",
#       "type": "ClinicalTrial",
#       "description": "A 12-week study evaluating the efficacy of Medication A in treating chronic migraines",
#       "custom_atts": {
#         "trial_id": {
#           "value": null,
#           "type": "string"
#         },
#         "enrollment_count": {
#           "value": "250",
#           "type": "int"
#         },
#         "age_min": {
#           "value": "18",
#           "type": "int"
#         },
#         "age_max": {
#           "value": "65",
#           "type": "int"
#         },
#         "duration_weeks": {
#           "value": "12",
#           "type": "int"
#         },
#         "control_type": {
#           "value": "placebo-controlled",
#           "type": "string"
#         },
#         "status": {
#           "value": "completed",
#           "type": "string"
#         }
#       }
#     },
#     "predicate": "conducted_by",
#     "object": {
#       "name": "Massachusetts General Hospital",
#       "type": "Organization",
#       "description": "A leading research institution in neurology that conducted a clinical trial on migraine medication",
#       "custom_atts": {
#         "name": {
#           "value": "Massachusetts General Hospital",
#           "type": "string"
#         },
#         "type": {
#           "value": "hospital",
#           "type": "string"
#         },
#         "location_name": {
#           "value": null,
#           "type": "string"
#         },
#         "research_focus": {
#           "value": "Neurology and headache disorders",
#           "type": "string"
#         }
#       }
#     },
#     "source": {
#       "source_name": "Medical Research Abstract 2024",
#       "source_url": "https://example.com/research/abstract-001"
#     },
#     "supporting_spans": [
#       {
#         "text": "A recent clinical trial evaluated the efficacy of Medication A in treating patients with chronic migraines. The study, conducted at Massachusetts General Hospital, enrolled 250 patients aged 18-65 who experienced at least 8 migraine days per month.",
#         "start": 1,
#         "end": 252
#       }
#     ],
#     "extraction_datetime": "2025-11-03T22:59:32Z"
#   },
#   {
#     "subject": {
#       "name": "Medication A",
#       "type": "Medication",
#       "description": "A drug developed to treat chronic migraines by targeting CGRP receptors",
#       "custom_atts": {
#         "name": {
#           "value": "Medication A",
#           "type": "string"
#         },
#         "indication": {
#           "value": "Chronic Migraine",
#           "type": "string"
#         },
#         "mechanism_summary": {
#           "value": "Inhibits CGRP receptors",
#           "type": "string"
#         },
#         "approval_status": {
#           "value": "FDA review expected",
#           "type": "string"
#         }
#       }
#     },
#     "predicate": "tests_medication",
#     "object": {
#       "name": "Clinical Trial for Medication A",
#       "type": "ClinicalTrial",
#       "description": "A 12-week study evaluating the efficacy of Medication A in treating chronic migraines",
#       "custom_atts": {
#         "trial_id": {
#           "value": null,
#           "type": "string"
#         },
#         "enrollment_count": {
#           "value": "250",
#           "type": "int"
#         },
#         "age_min": {
#           "value": "18",
#           "type": "int"
#         },
#         "age_max": {
#           "value": "65",
#           "type": "int"
#         },
#         "duration_weeks": {
#           "value": "12",
#           "type": "int"
#         },
#         "control_type": {
#           "value": "placebo-controlled",
#           "type": "string"
#         },
#         "status": {
#           "value": "completed",
#           "type": "string"
#         }
#       }
#     },
#     "source": {
#       "source_name": "Medical Research Abstract 2024",
#       "source_url": "https://example.com/research/abstract-001"
#     },
#     "supporting_spans": [
#       {
#         "text": "A recent clinical trial evaluated the efficacy of Medication A in treating patients with chronic migraines.",
#         "start": 1,
#         "end": 109
#       }
#     ],
#     "extraction_datetime": "2025-11-03T22:59:32Z"
#   }
# ]

# %% [markdown]
# ## Part 1: Basic Ontology Recommendation
#
# This section demonstrates the core functionality of recommending an ontology from text and using it for extraction.

# %%
# Step 4: Demonstrate serialization
print("Step 4: Serialize recommendation to JSON")
print("-" * 70)

recommendation_dict = recommendation_to_dict(recommendation)
print(json.dumps(recommendation_dict, indent=2))
# Out:
# Step 4: Serialize recommendation to JSON
# ----------------------------------------------------------------------
# {
#   "ontology": {
#     "entity_types": [
#       {
#         "name": "Person",
#         "description": "An individual mentioned in the text (e.g., investigators, clinicians, presenters, patients when named).",
#         "attributes": [
#           {
#             "name": "name",
#             "type": "string",
#             "description": "Full name of the person."
#           },
#           {
#             "name": "role",
#             "type": "string",
#             "description": "Role or function in the context (e.g., principal investigator, neurologist, presenter)."
#           },
#           {
#             "name": "specialty",
#             "type": "string",
#             "description": "Professional specialty or occupation (e.g., neurologist)."
#           },
#           {
#             "name": "affiliation_name",
#             "type": "string",
#             "description": "Name of the primary organization with which the person is affiliated (extractable from text)."
#           }
#         ]
#       },
#       {
#         "name": "Organization",
#         "description": "An institutional entity (e.g., hospitals, research institutions, regulatory agencies, professional societies).",
#         "attributes": [
#           {
#             "name": "name",
#             "type": "string",
#             "description": "Official name of the organization."
#           },
#           {
#             "name": "type",
#             "type": "string",
#             "description": "Category of organization (e.g., hospital, regulatory_agency, professional_society, research_institution)."
#           },
#           {
#             "name": "location_name",
#             "type": "string",
#             "description": "Textual location or headquarters (city, state, country) if mentioned."
#           },
#           {
#             "name": "research_focus",
#             "type": "string",
#             "description": "Short description of the organization's domain or area of research (if stated)."
#           }
#         ]
#       },
#       {
#         "name": "ClinicalTrial",
#         "description": "A clinical study or trial described in the text.",
#         "attributes": [
#           {
#             "name": "trial_id",
#             "type": "string",
#             "description": "Name or identifier of the trial (as given in text)."
#           },
#           {
#             "name": "enrollment_count",
#             "type": "int",
#             "description": "Number of participants enrolled in the trial."
#           },
#           {
#             "name": "age_min",
#             "type": "int",
#             "description": "Minimum participant age included in the trial (years)."
#           },
#           {
#             "name": "age_max",
#             "type": "int",
#             "description": "Maximum participant age included in the trial (years)."
#           },
#           {
#             "name": "duration_weeks",
#             "type": "int",
#             "description": "Planned or actual duration of intervention/follow-up in weeks."
#           },
#           {
#             "name": "control_type",
#             "type": "string",
#             "description": "Control or comparator used (e.g., placebo-controlled, active comparator)."
#           },
#           {
#             "name": "status",
#             "type": "string",
#             "description": "Trial status mentioned (e.g., completed, ongoing, results_presented)."
#           }
#         ]
#       },
#       {
#         "name": "Medication",
#         "description": "A therapeutic compound or drug evaluated or mentioned in the text.",
#         "attributes": [
#           {
#             "name": "name",
#             "type": "string",
#             "description": "Medication name or identifier."
#           },
#           {
#             "name": "indication",
#             "type": "string",
#             "description": "Condition(s) the medication is intended to treat (as mentioned)."
#           },
#           {
#             "name": "mechanism_summary",
#             "type": "string",
#             "description": "Short description of the drug's mechanism of action (e.g., inhibits CGRP receptors)."
#           },
#           {
#             "name": "approval_status",
#             "type": "string",
#             "description": "Regulatory status or expected regulatory action as mentioned (e.g., FDA review expected)."
#           }
#         ]
#       },
#       {
#         "name": "Condition",
#         "description": "A medical condition, disease, or disorder discussed (e.g., chronic migraine).",
#         "attributes": [
#           {
#             "name": "name",
#             "type": "string",
#             "description": "Name of the condition."
#           },
#           {
#             "name": "chronic",
#             "type": "bool",
#             "description": "Whether the condition is described as chronic in the text."
#           },
#           {
#             "name": "frequency_per_month",
#             "type": "float",
#             "description": "Frequency metric if provided (e.g., migraine days per month)."
#           },
#           {
#             "name": "typical_symptoms",
#             "type": "string",
#             "description": "Short description of core symptoms if mentioned."
#           }
#         ]
#       },
#       {
#         "name": "Outcome",
#         "description": "A measured result or endpoint from a study (e.g., reduction in migraine frequency).",
#         "attributes": [
#           {
#             "name": "metric_name",
#             "type": "string",
#             "description": "Name of the outcome metric (e.g., migraine_frequency_reduction)."
#           },
#           {
#             "name": "value",
#             "type": "float",
#             "description": "Numeric value of the outcome (e.g., 50)."
#           },
#           {
#             "name": "unit",
#             "type": "string",
#             "description": "Unit for the outcome value (e.g., percent, days/month)."
#           },
#           {
#             "name": "comparison",
#             "type": "string",
#             "description": "Comparator stated (e.g., versus placebo)."
#           }
#         ]
#       },
#       {
#         "name": "AdverseEvent",
#         "description": "An adverse effect or side effect reported in association with an intervention.",
#         "attributes": [
#           {
#             "name": "name",
#             "type": "string",
#             "description": "Name or description of the adverse event (e.g., nausea)."
#           },
#           {
#             "name": "incidence_rate",
#             "type": "float",
#             "description": "Reported incidence as a percentage (if provided)."
#           },
#           {
#             "name": "severity",
#             "type": "string",
#             "description": "Severity descriptor if given (e.g., common, severe)."
#           }
#         ]
#       },
#       {
#         "name": "BiologicalTarget",
#         "description": "A biological molecule or target referenced as the mechanism of action (e.g., CGRP receptor).",
#         "attributes": [
#           {
#             "name": "name",
#             "type": "string",
#             "description": "Name of the biological target."
#           },
#           {
#             "name": "target_type",
#             "type": "string",
#             "description": "Type of biological entity (e.g., receptor, enzyme, pathway)."
#           },
#           {
#             "name": "role_description",
#             "type": "string",
#             "description": "Short description of its role in disease or mechanism (if present)."
#           }
#         ]
#       },
#       {
#         "name": "Event",
#         "description": "A meeting or conference where results are presented (e.g., American Academy of Neurology conference).",
#         "attributes": [
#           {
#             "name": "name",
#             "type": "string",
#             "description": "Name of the event or conference."
#           },
#           {
#             "name": "location_name",
#             "type": "string",
#             "description": "Location of the event (city, venue) as mentioned."
#           },
#           {
#             "name": "date",
#             "type": "date",
#             "description": "Date or year of the event (if extractable)."
#           },
#           {
#             "name": "reception",
#             "type": "string",
#             "description": "How the presentation was received (e.g., well-received by the medical community)."
#           }
#         ]
#       },
#       {
#         "name": "RegulatoryAction",
#         "description": "A regulatory process or action mentioned (e.g., expected FDA review, approval).",
#         "attributes": [
#           {
#             "name": "action",
#             "type": "string",
#             "description": "Type of regulatory action (e.g., review, approval)."
#           },
#           {
#             "name": "agency_name",
#             "type": "string",
#             "description": "Name of the regulatory agency involved (e.g., FDA)."
#           },
#           {
#             "name": "expected_date",
#             "type": "date",
#             "description": "Expected date or time frame for the action if mentioned."
#           },
#           {
#             "name": "status",
#             "type": "string",
#             "description": "Status or outcome if reported (e.g., pending, approved)."
#           }
#         ]
#       },
#       {
#         "name": "Location",
#         "description": "Geographic place referenced (city, state, country) useful for events and organization locations.",
#         "attributes": [
#           {
#             "name": "name",
#             "type": "string",
#             "description": "Textual name of the location (e.g., Seattle)."
#           },
#           {
#             "name": "city",
#             "type": "string",
#             "description": "City name if present."
#           },
#           {
#             "name": "state_or_region",
#             "type": "string",
#             "description": "State or region if present."
#           },
#           {
#             "name": "country",
#             "type": "string",
#             "description": "Country name if present."
#           }
#         ]
#       }
#     ],
#     "relation_types": [
#       {
#         "name": "works_at",
#         "description": "Indicates that a person is affiliated with or works at an organization.",
#         "domain": "Person",
#         "range": "Organization"
#       },
#       {
#         "name": "leads_trial",
#         "description": "A person (e.g., principal investigator) leads or directs a clinical trial.",
#         "domain": "Person",
#         "range": "ClinicalTrial"
#       },
#       {
#         "name": "conducted_by",
#         "description": "The organization that conducted or hosted the clinical trial.",
#         "domain": "ClinicalTrial",
#         "range": "Organization"
#       },
#       {
#         "name": "tests_medication",
#         "description": "Indicates that a clinical trial evaluated or tested a given medication.",
#         "domain": "ClinicalTrial",
#         "range": "Medication"
#       },
#       {
#         "name": "targets_condition",
#         "description": "The clinical trial is aimed at studying or treating a specific condition.",
#         "domain": "ClinicalTrial",
#         "range": "Condition"
#       },
#       {
#         "name": "has_outcome",
#         "description": "Links a clinical trial to a reported outcome or endpoint.",
#         "domain": "ClinicalTrial",
#         "range": "Outcome"
#       },
#       {
#         "name": "measures_condition",
#         "description": "An outcome metric that measures or quantifies a condition.",
#         "domain": "Outcome",
#         "range": "Condition"
#       },
#       {
#         "name": "reports_adverse_event",
#         "description": "A clinical trial reports one or more adverse events observed among participants.",
#         "domain": "ClinicalTrial",
#         "range": "AdverseEvent"
#       },
#       {
#         "name": "causes_adverse_event",
#         "description": "Indicates an association between a medication and an adverse event.",
#         "domain": "Medication",
#         "range": "AdverseEvent"
#       },
#       {
#         "name": "has_mechanism",
#         "description": "Connects a medication to its biological target or mechanism of action.",
#         "domain": "Medication",
#         "range": "BiologicalTarget"
#       },
#       {
#         "name": "presented_at",
#         "description": "A person presented findings at an event (conference).",
#         "domain": "Person",
#         "range": "Event"
#       },
#       {
#         "name": "reported_at",
#         "description": "The clinical trial's results were reported or presented at an event.",
#         "domain": "ClinicalTrial",
#         "range": "Event"
#       },
#       {
#         "name": "located_in",
#         "description": "Indicates the geographic location of an organization or event.",
#         "domain": "Organization",
#         "range": "Location"
#       },
#       {
#         "name": "event_located_in",
#         "description": "Specifies the geographic location for an event.",
#         "domain": "Event",
#         "range": "Location"
#       },
#       {
#         "name": "reviews",
#         "description": "A regulatory organization reviews trial data or a medication (e.g., FDA reviewing data).",
#         "domain": "Organization",
#         "range": "ClinicalTrial"
#       },
#       {
#         "name": "regulatory_action_by",
#         "description": "Links a regulatory action record to the agency or organization performing it.",
#         "domain": "RegulatoryAction",
#         "range": "Organization"
#       },
#       {
#         "name": "regulatory_action_targets_trial",
#         "description": "Indicates that a regulatory action is targeted at a clinical trial or its data.",
#         "domain": "RegulatoryAction",
#         "range": "ClinicalTrial"
#       },
#       {
#         "name": "regulatory_action_targets_medication",
#         "description": "Indicates that a regulatory action is targeted at a medication (e.g., approval/review).",
#         "domain": "RegulatoryAction",
#         "range": "Medication"
#       }
#     ]
#   },
#   "text_purpose": "Summarize and report a clinical trial evaluating Medication A for chronic migraines \u2014 including study design, participants, results (efficacy and side effects), mechanism of action, presentation at a conference, institutional context, and anticipated regulatory review.",
#   "reasoning": "I designed a balanced ontology focused on clinical research and related entities that appear in the text. Entity types were chosen to cover recurring and central concepts: persons (investigators/presenters), organizations (hospital, FDA, professional society), clinical trials (study-level metadata), medications, medical conditions, outcomes (endpoints/results), adverse events (side effects), biological targets (mechanism), events (conferences), regulatory actions (expected reviews), and locations. This set is general enough to apply across similar clinical-trial reports yet specific enough to capture analytically important distinctions (e.g., outcomes vs. adverse events, trials vs. medications). Relation types were selected to reflect common, meaningful interactions in clinical reports: affiliations (works_at), trial leadership, which organization conducted a trial, trial\u2192medication and trial\u2192condition links, how outcomes map to conditions, reporting of adverse events, mechanism links (medication\u2192target), presentation/reporting at conferences, and regulatory review actions. Attribute choices follow the 'balanced' guideline (2\u20134 useful, extractable attributes per entity) emphasizing information commonly present in such texts (enrollment counts, age ranges, duration, effect sizes, incidence percentages, mechanism descriptions, and expected regulatory dates). The ontology avoids overly specific roles or redundant relations while supporting typical queries: Who led the trial? Where was it conducted? What medication and mechanism were studied? What were the efficacy and side-effect rates? Has the FDA or another agency been engaged? This design should allow consistent classification by different annotators and be reusable across similar clinical trial summaries."
# }

# %% [markdown]
# ## Part 2: Automatic Ontology Recommendation with SpindleExtractor
#
# This section demonstrates how SpindleExtractor can automatically recommend an ontology when initialized without one.

# %%
print("=" * 70)
print("SpindleExtractor with Automatic Ontology Recommendation")
print("=" * 70)
print()

# Example text about a different domain (art/museum)
art_text = """
The Metropolitan Museum of Art acquired a rare 15th-century painting by 
Johannes Vermeer at Sotheby's auction in New York. The artwork, titled 
"Girl with a Pearl Earring Redux," was purchased for $45 million by the 
museum's curator Dr. Elizabeth Sterling. The painting will be displayed 
in the Dutch Masters gallery alongside other works from the Golden Age 
period. Art historian Professor Michael Chen from Yale University 
authenticated the piece and confirmed its provenance. The acquisition was 
funded by the Patterson Foundation's endowment for European art.
"""

print("Step 1: Create SpindleExtractor WITHOUT an ontology")
print("-" * 70)
print("When extract() is called, it will automatically recommend an ontology")
print("based on the text content.")
print()

# Create extractor WITHOUT providing an ontology
extractor_auto = SpindleExtractor()
print("✓ SpindleExtractor created without ontology")
print()

# %%
print("Step 2: Extract triples (ontology will be auto-recommended)")
print("-" * 70)
print(f"Input text:\n{art_text}\n")

# Call extract - this will automatically recommend an ontology first
result_auto = extractor_auto.extract(
    text=art_text,
    source_name="Art Museum News",
    source_url="https://example.com/museum/news/acquisition",
    ontology_scope="balanced"  # Optional: "minimal", "balanced", or "comprehensive"
)

print(f"✓ Ontology automatically recommended and applied!")
print()

# %%
print("Step 3: Inspect the auto-recommended ontology")
print("-" * 70)

print(f"Entity Types ({len(extractor_auto.ontology.entity_types)}):")
for i, et in enumerate(extractor_auto.ontology.entity_types, 1):
    print(f"  {i}. {et.name}: {et.description}")
print()

print(f"Relation Types ({len(extractor_auto.ontology.relation_types)}):")
for i, rt in enumerate(extractor_auto.ontology.relation_types, 1):
    print(f"  {i}. {rt.name}: {rt.description}")
    print(f"     ({rt.domain} → {rt.range})")
print()

# %%
print("Step 4: View extracted triples")
print("-" * 70)

print(f"Extracted {len(result_auto.triples)} triples:\n")
for i, triple in enumerate(result_auto.triples, 1):
    print(f"  {i}. ({triple.subject}) --[{triple.predicate}]--> ({triple.object})")
    print(f"     Source: {triple.source.source_name}")
    print(f"     Evidence snippets: {len(triple.supporting_spans)}")
    if triple.supporting_spans:
        snippet = triple.supporting_spans[0].text[:60] + "..."
        print(f"     \"{snippet}\"")
print()

print(f"Extraction Reasoning:\n  {result_auto.reasoning}\n")

# %%
print("Step 5: Subsequent extractions use the same ontology")
print("-" * 70)

art_text2 = """
The Louvre Museum in Paris announced that it will loan three Monet 
paintings to the National Gallery in London for a special exhibition. 
The curator Marie Dubois coordinated the arrangement with her British 
counterpart. These impressionist works will be featured alongside pieces 
from the Tate Modern's collection.
"""

print(f"Second text:\n{art_text2}\n")

# Subsequent calls will use the already-recommended ontology
result_auto2 = extractor_auto.extract(
    text=art_text2,
    source_name="International Art News",
    existing_triples=result_auto.triples  # Maintain entity consistency
)

print(f"✓ Extracted {len(result_auto2.triples)} more triples using same ontology")
print()

for i, triple in enumerate(result_auto2.triples, 1):
    print(f"  {i}. ({triple.subject}) --[{triple.predicate}]--> ({triple.object})")
print()

# %% [markdown]
# ## Part 3: Conservative Ontology Extension
#
# This section demonstrates how to extend an existing ontology conservatively when encountering new domains.

# %%
print("=" * 80)
print("Conservative Ontology Extension Example")
print("=" * 80)
print()

# Step 1: Start with a business-focused ontology
print("Step 1: Create Initial Business Ontology")
print("-" * 80)

entity_types = [
    {"name": "Person", "description": "An individual person"},
    {"name": "Organization", "description": "A company, institution, or business entity"},
    {"name": "Location", "description": "A geographic place or address"},
    {"name": "Product", "description": "A product or service offered by an organization"}
]

relation_types = [
    {
        "name": "works_at",
        "description": "Employment relationship between a person and organization",
        "domain": "Person",
        "range": "Organization"
    },
    {
        "name": "located_in",
        "description": "Physical location of an organization or person",
        "domain": "Organization",
        "range": "Location"
    },
    {
        "name": "develops",
        "description": "Relationship where an organization creates a product",
        "domain": "Organization",
        "range": "Product"
    },
    {
        "name": "founded",
        "description": "Founding relationship",
        "domain": "Person",
        "range": "Organization"
    }
]

initial_ontology = create_ontology(entity_types, relation_types)

print(f"Initial Ontology:")
print(f"  Entity Types: {[et.name for et in initial_ontology.entity_types]}")
print(f"  Relation Types: {[rt.name for rt in initial_ontology.relation_types]}")
print()

# %%
recommender_ext = OntologyRecommender()

# Step 2: Test with similar domain text (should NOT need extension)
print("Step 2: Analyze Text from Similar Domain")
print("-" * 80)

similar_text = """
TechVentures Inc., a venture capital firm based in San Jose, recently
invested in CloudScale, a cloud infrastructure startup. The investment
was led by Jennifer Martinez, managing partner at TechVentures. CloudScale
develops cloud optimization software and was founded by Tom Wilson in 2020.
"""

print(f"Text:\n{similar_text}\n")

extension1 = recommender_ext.analyze_extension(
    text=similar_text,
    current_ontology=initial_ontology,
    scope="balanced"
)

print(f"Extension Needed: {extension1.needs_extension}")
if extension1.needs_extension:
    print(f"New Types:")
    print(f"  Entities: {[et.name for et in extension1.new_entity_types]}")
    print(f"  Relations: {[rt.name for rt in extension1.new_relation_types]}")
    print(f"\nCritical Information at Risk:")
    print(f"  {extension1.critical_information_at_risk}")
print(f"\nReasoning:")
print(f"  {extension1.reasoning}")
print()

# %%
# Step 3: Test with text from different domain (MIGHT need extension)
print("Step 3: Analyze Text from Medical Domain")
print("-" * 80)

medical_text_ext = """
Dr. Sarah Chen, a cardiologist at Stanford Medical Center, recently published
research on the efficacy of Medication Beta in treating hypertension. The
clinical trial involved 500 patients and showed significant improvement in
blood pressure control. The study was funded by the National Institutes of
Health and published in the Journal of Cardiology.
"""

print(f"Text:\n{medical_text_ext}\n")

extension2 = recommender_ext.analyze_extension(
    text=medical_text_ext,
    current_ontology=initial_ontology,
    scope="balanced"
)

print(f"Extension Needed: {extension2.needs_extension}")
if extension2.needs_extension:
    print(f"\nNew Entity Types:")
    for et in extension2.new_entity_types:
        print(f"  - {et.name}: {et.description}")
    print(f"\nNew Relation Types:")
    for rt in extension2.new_relation_types:
        print(f"  - {rt.name}: {rt.description}")
        print(f"    ({rt.domain} → {rt.range})")
    print(f"\nCritical Information at Risk:")
    print(f"  {extension2.critical_information_at_risk}")
print(f"\nReasoning:")
print(f"  {extension2.reasoning}")
print()

# %%
# Step 4: Apply extension if needed
if extension2.needs_extension:
    print("Step 4: Apply Extension to Ontology")
    print("-" * 80)
    
    extended_ontology = recommender_ext.extend_ontology(initial_ontology, extension2)
    
    print(f"Original Ontology:")
    print(f"  {len(initial_ontology.entity_types)} entity types, "
          f"{len(initial_ontology.relation_types)} relation types")
    print(f"\nExtended Ontology:")
    print(f"  {len(extended_ontology.entity_types)} entity types, "
          f"{len(extended_ontology.relation_types)} relation types")
    print(f"\nAll Entity Types: {[et.name for et in extended_ontology.entity_types]}")
    print(f"All Relation Types: {[rt.name for rt in extended_ontology.relation_types]}")
    print()
    
    # Now extract with the extended ontology
    print("Step 5: Extract Triples with Extended Ontology")
    print("-" * 80)
    
    extractor_ext = SpindleExtractor(extended_ontology)
    result_ext = extractor_ext.extract(medical_text_ext, source_name="Medical Research")
    
    print(f"Extracted {len(result_ext.triples)} triples:\n")
    for i, triple in enumerate(result_ext.triples, 1):
        print(f"  {i}. ({triple.subject}) --[{triple.predicate}]--> ({triple.object})")
    print()

# %%
# Step 6: Demonstrate the analyze_and_extend convenience method
print("Step 6: Using Convenience Method (analyze_and_extend)")
print("-" * 80)

tech_policy_text = """
The Federal Trade Commission, led by Commissioner Lisa Park, announced new
regulations regarding data privacy for social media platforms. The regulation
requires companies to obtain explicit consent before collecting user data.
Meta and Google have six months to comply with the new requirements.
"""

print(f"Text:\n{tech_policy_text}\n")

# Use convenience method with auto_apply
extension3, maybe_new_ontology = recommender_ext.analyze_and_extend(
    text=tech_policy_text,
    current_ontology=initial_ontology,
    scope="balanced",
    auto_apply=True
)

print(f"Extension Needed: {extension3.needs_extension}")

if maybe_new_ontology:
    print(f"\nAutomatically Extended Ontology:")
    print(f"  {len(maybe_new_ontology.entity_types)} entity types, "
          f"{len(maybe_new_ontology.relation_types)} relation types")
    print(f"\nNew Types Added:")
    print(f"  Entities: {[et.name for et in extension3.new_entity_types]}")
    print(f"  Relations: {[rt.name for rt in extension3.new_relation_types]}")
    
    # Extract with new ontology
    extractor_ext2 = SpindleExtractor(maybe_new_ontology)
    result_ext2 = extractor_ext2.extract(tech_policy_text, source_name="Policy News")
    print(f"\nExtracted {len(result_ext2.triples)} triples with extended ontology")
else:
    print(f"\nNo extension needed - using original ontology")
    print(f"Reasoning: {extension3.reasoning}")

print()

# %%
# Step 7: Serialize extension analysis
print("Step 7: Serialize Extension Analysis")
print("-" * 80)

if extension2.needs_extension:
    extension_dict = extension_to_dict(extension2)
    print("Extension Analysis as JSON:")
    print(json.dumps(extension_dict, indent=2))

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
#
# **Part 1: Basic Ontology Recommendation**
# - ✓ Analyzing text to automatically recommend an ontology
# - ✓ Using the recommended ontology to extract triples
# - ✓ Serializing recommendations to JSON
#
# **Part 2: Automatic Ontology Recommendation**
# - ✓ SpindleExtractor initialized without ontology
# - ✓ Ontology automatically recommended from text on first extract()
# - ✓ Auto-recommended ontology used for all subsequent extractions
# - ✓ Principled ontology design with scope levels (minimal/balanced/comprehensive)
# - ✓ Maintains entity consistency across multiple texts
#
# **Part 3: Conservative Ontology Extension**
# - ✓ Conservative extension - only when critical information at risk
# - ✓ Analysis explains WHY extension is/isn't needed
# - ✓ Extensions are backward-compatible additions
# - ✓ Original ontology unchanged - new ontology is created
# - ✓ Existing types preferred over creating new ones
# - ✓ Ontology evolves deliberately, not with every new text
