# %% [markdown]
# # Entity Resolution with Spindle
#
# This notebook demonstrates **semantic entity resolution** – the process of identifying and linking duplicate entities in a knowledge graph using embeddings and LLMs.
#
# ## Overview
#
# Entity resolution uses a three-phase approach
#
# 1. **Semantic Blocking**: Cluster similar entities using embeddings to reduce O(n^2) comparisons
# 2. **Semantic Matching**: Use LLM (Claude) to determine if entities are duplicates with confidence scores
# 3. **Graph Linking**: Create SAME_AS edges to preserve provenance while linking duplicates
#
# This approach is based on techniques from ["The Rise of Semantic Entity Resolution"](https://towardsdatascience.com/the-rise-of-semantic-entity-resolution/).

# %% [markdown]
# ## Setup

# %%
import os
import json
from pathlib import Path

# Spindle imports
from spindle import GraphStore
from spindle.vector_store import ChromaVectorStore, get_default_embedding_function
from spindle.entity_resolution import (
    EntityResolver,
    ResolutionConfig,
    resolve_entities,  # Convenience function
)

print("✅ Imports successful")
# Out:
# ✅ Imports successful

# %% [markdown]
# ## Check API Keys
#
# Entity resolution requires:
# - `ANTHROPIC_API_KEY` for LLM-based matching (Claude Sonnet 4)

# %%
# Check for required API key
if not os.getenv("ANTHROPIC_API_KEY"):
    print("⚠️  ANTHROPIC_API_KEY not set! Set it with: export ANTHROPIC_API_KEY='your-key-here'")
else:
    print("✅ ANTHROPIC_API_KEY configured")
# Out:
# ✅ ANTHROPIC_API_KEY configured

# %% [markdown]
# ## Initialize Stores
#
# We need:
# - **GraphStore**: To store entities and relationships
# - **VectorStore**: To compute embeddings for semantic blocking

# %%
# Initialize graph store
graph_store = GraphStore("entity_resolution_demo")

# Initialize vector store with default embedding function
vector_store = ChromaVectorStore(
    collection_name="resolution_embeddings",
    embedding_function=get_default_embedding_function(),
)

print("✅ Stores initialized")
print(f"Graph DB path: {graph_store.db_path}")
collection_name = getattr(getattr(vector_store, "collection", None), "name", "<unknown>")
print(f"Vectors collection: {collection_name}")
# Out:
# ✅ Stores initialized
# Graph DB path: /Users/thalamus/Repos/spindle/graphs/entity_resolution_demo/graph.db
# Vectors collection: resolution_embeddings

# %% [markdown]
# ## Create Sample Data with Duplicates
#
# Let's create a knowledge graph about tech companies with intentional duplicates:
# - Name variations ("TechCorp" vs "Tech Corp")
# - Abbreviations ("NYC" vs "New York City")
# - Typos and misspellings

# %%
sample_triples = [
    # Company entities (with duplicates)
    {
        "subject": "TechCorp",
        "predicate": "has_type",
        "object": "Company",
        "subject_type": "Organization",
        "object_type": "Type",
        "subject_description": "A leading technology company.",
    },
    {
        "subject": "Tech Corp",  # DUPLICATE: Space variation
        "predicate": "has_type",
        "object": "Company",
        "subject_type": "Organization",
        "object_type": "Type",
        "subject_description": "A technology corporation.",
    },
    {
        "subject": "TechCorp Inc.",  # DUPLICATE: Legal suffix
        "predicate": "has_type",
        "object": "Company",
        "subject_type": "Organization",
        "object_type": "Type",
        "subject_description": "Technology company incorporated in Delaware.",
    },
    # Location entities (with duplicates)
    {
        "subject": "New York City",
        "predicate": "has_type",
        "object": "Location",
        "subject_type": "City",
        "object_type": "Type",
        "subject_description": "The most populous city in the United States.",
    },
    {
        "subject": "NYC",  # DUPLICATE: Abbreviation
        "predicate": "has_type",
        "object": "Location",
        "subject_type": "City",
        "object_type": "Type",
        "subject_description": "Major city in New York state.",
    },
    # People entities (with duplicates)
    {
        "subject": "John Smith",
        "predicate": "has_type",
        "object": "Person",
        "subject_type": "Person",
        "object_type": "Type",
        "subject_description": "CEO of TechCorp",
    },
    {
        "subject": "J. Smith",  # DUPLICATE: Abbreviated first name
        "predicate": "has_type",
        "object": "Person",
        "subject_type": "Person",
        "object_type": "Type",
        "subject_description": "Chief Executive Officer at Tech Corp",
    },
    # Relationships with duplicate entities
    {
        "subject": "TechCorp",
        "predicate": "located_in",
        "object": "New York City",
        "subject_type": "Organization",
        "object_type": "City",
    },
    {
        "subject": "Tech Corp",  # Same relationship with duplicate entities
        "predicate": "located_in",
        "object": "NYC",
        "subject_type": "Organization",
        "object_type": "City",
    },
    {
        "subject": "John Smith",
        "predicate": "works_at",
        "object": "TechCorp",
        "subject_type": "Person",
        "object_type": "Organization",
    },
    {
        "subject": "J. Smith",  # Same relationship with duplicate entities
        "predicate": "employed_by",  # Similar predicate
        "object": "Tech Corp",
        "subject_type": "Person",
        "object_type": "Organization",
    },
]

# %%
# Helper to load sample data using current GraphStore API
def load_sample_triples(store, triples, source_name="sample_data"):
    added_nodes = 0
    added_edges = 0

    for triple in triples:
        subject = triple["subject"]
        subject_type = triple.get("subject_type", "Unknown")
        subject_description = triple.get("subject_description", "")
        subject_metadata = {"sources": [source_name]}

        if store.add_node(
            name=subject,
            entity_type=subject_type,
            description=subject_description,
            metadata=subject_metadata,
        ):
            added_nodes += 1

        obj = triple["object"]
        object_type = triple.get("object_type", "Unknown")
        object_description = triple.get("object_description", "")
        object_metadata = {"sources": [source_name]}

        if store.add_node(
            name=obj,
            entity_type=object_type,
            description=object_description,
            metadata=object_metadata,
        ):
            added_nodes += 1

        metadata = {"sources": [source_name]}
        edge_result = store.add_edge(subject, triple["predicate"], obj, metadata=metadata)
        if edge_result.get("success"):
            added_edges += 1

    return added_nodes, added_edges

# Add triples to graph store
nodes_added, edges_added = load_sample_triples(graph_store, sample_triples)

print(f"✅ Added sample data (nodes: {nodes_added}, edges: {edges_added})")
print(f"\nExpected duplicates")
print(" - TechCorp, Tech Corp, TechCorp Inc.")
print(" - New York City, NYC")
print(" - John Smith, J. Smith")
# Out:
# ✅ Added sample data (nodes: 10, edges: 11)
#
# Expected duplicates
#  - TechCorp, Tech Corp, TechCorp Inc.
#  - New York City, NYC
#  - John Smith, J. Smith

# %%
# Get all nodes
nodes = graph_store.nodes()
print(f"Total nodes: {len(nodes)}")
print("\nNode names:")
for node in nodes:
    print(f" - {node['name']} ({node.get('type', 'unknown')})")
# Out:
# Total nodes: 10
#
# Node names:
#  - TECHCORP (Organization)
#  - COMPANY (Type)
#  - TECH CORP (Organization)
#  - TECHCORP INC. (Organization)
#  - NEW YORK CITY (City)
#  - LOCATION (Type)
#  - NYC (City)
#  - JOHN SMITH (Person)
#  - PERSON (Type)
#  - J. SMITH (Person)

# %%
# Get all edges
edges = graph_store.edges()
print(f"Total edges: {len(edges)}")
print("\nEdges:")
for edge in edges:
    print(f" - {edge['subject']} --[{edge['predicate']}]--> {edge['object']}")
# Out:
# Total edges: 11
#
# Edges:
#  - TECHCORP --[HAS_TYPE]--> COMPANY
#  - TECHCORP --[LOCATED_IN]--> NEW YORK CITY
#  - TECH CORP --[HAS_TYPE]--> COMPANY
#  - TECH CORP --[LOCATED_IN]--> NYC
#  - TECHCORP INC. --[HAS_TYPE]--> COMPANY
#  - NEW YORK CITY --[HAS_TYPE]--> LOCATION
#  - NYC --[HAS_TYPE]--> LOCATION
#  - JOHN SMITH --[HAS_TYPE]--> PERSON
#  - JOHN SMITH --[WORKS_AT]--> TECHCORP
#  - J. SMITH --[HAS_TYPE]--> PERSON
#  - J. SMITH --[EMPLOYED_BY]--> TECH CORP

# %% [markdown]
# ## Configure Entity Resolution
#
# ### Understanding Configuration Parameters
#
# - **blocking_threshold** (0-1): Cosine similarity threshold for clustering
#   - Higher = stricter clusters, fewer comparisons
#   - Lower = looser clusters, more comparisons
#   - Default: 0.85
# - **matching_threshold** (0-1): LLM confidence threshold for duplicates
#   - 0.95 = high confidence only
#   - 0.75 = medium+ confidence
#   - 0.50 = low+ confidence
#   - Default: 0.8
# - **clustering_method**: Algorithm for blocking
#   - `hierarchical`: Agglomerative clustering (default)
#   - `kmeans`: k-means for faster processing
#   - `hdbscan`: Density-based for variable cluster sizes

# %%
# Create resolution configuration
config = ResolutionConfig(
    blocking_threshold=0.85,  # Similarity threshold for clustering
    matching_threshold=0.75,  # Accept medium+ confidence matches
    clustering_method="hierarchical",
    batch_size=20,  # Entities per LLM call
    min_cluster_size=2,  # Minimum entities to consider
    max_cluster_size=50,  # Maximum entities per cluster
)

print("✅ Configuration created")
print(f"Blocking threshold: {config.blocking_threshold}")
print(f"Matching threshold: {config.matching_threshold}")
print(f"Clustering method: {config.clustering_method}")
# Out:
# ✅ Configuration created
# Blocking threshold: 0.85
# Matching threshold: 0.75
# Clustering method: hierarchical

# %% [markdown]
# ## Run Entity Resolution
#
# The resolution pipeline:
# 1. **Serialize** entities to text representations
# 2. Compute embeddings using the vector store
# 3. **Cluster** entities using semantic blocking
# 4. **Match** entities within clusters using LLM
# 5. Create **SAME_AS** edges for duplicates
# 6. **Find connected components** to identify duplicate clusters

# %%
# Create resolver
resolver = EntityResolver(config=config)

# Provide domain context for better matching
context = """
This is a knowledge graph about technology companies and people.
Common variations:
- Corp, Corporation, Inc., LLC are equivalent suffixes
- Abbreviations like NYC = New York City are common
- First name abbreviations (J. = John) are common
"""

# Run resolution
print("Running entity resolution...")
result = resolver.resolve_entities(
    graph_store=graph_store,
    vector_store=vector_store,
    apply_to_nodes=True,
    apply_to_edges=True,
    context=context,
)

print("\n Resolution complete!")
# Out:
# Running entity resolution...
# 2025-11-10T21:59:08.031 [BAML INFO] Function MatchEntities:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 9991ms. StopReason: end_turn. Tokens(in/out): 621/496
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate entities within a group of semantically similar entities.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Entities to analyze:**
#     ---
#     ID: TECHCORP
#     Type: Organization
#     Description: A leading technology company.
#     Attributes: {}
#     ---
#     ID: TECH CORP
#     Type: Organization
#     Description: A technology corporation.
#     Attributes: {}
#     ---
#     ID: TECHCORP INC.
#     Type: Organization
#     Description: Technology company incorporated in Delaware.
#     Attributes: {}
#     ---
#
#     **Task:**
#     Identify which entities in this group are duplicates of each other. Consider:
#
#     1. **Name variations**: "TechCorp", "Tech Corp", "TechCorp Inc." likely refer to the same entity
#     2. **Semantic similarity**: "NYC" and "New York City" are the same
#     3. **Type consistency**: Entities must have compatible types to be duplicates
#     4. **Attribute alignment**: Similar or complementary attributes strengthen a match
#     5. **Description consistency**: Descriptions should be compatible, not contradictory
#
#     **Guidelines:**
#     - Only mark entities as duplicates if you're confident they refer to the same real-world entity
#     - Use "high" confidence for clear matches (obvious name variations, identical descriptions)
#     - Use "medium" confidence for probable matches (semantic similarity, consistent attributes)
#     - Use "low" confidence for possible matches (weak signals, some inconsistency)
#     - Avoid false positives - when in doubt, mark is_duplicate as false
#     - Provide clear reasoning for each match decision
#     - Check for transitive consistency: if A matches B and B matches C, A should match C
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate pairs within this block
#       matches: [
#         {
#           // The unique identifier (name) of the first entity
#           entity1_id: string,
#           // The unique identifier (name) of the second entity
#           entity2_id: string,
#           // Whether these two entities represent the same real-world entity
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation of why these entities are or aren't duplicates, considering name variations, types, descriptions, and attributes
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities have nearly identical names with only a space difference ('TECHCORP' vs 'TECH CORP'). Both are Organizations with very similar descriptions about being technology companies. This is a clear case of name variation for the same entity."
#         },
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities represent the same company with and without the corporate suffix. 'TECHCORP' and 'TECHCORP INC.' refer to the same entity, as 'Inc.' is just the legal incorporation designation. Both are Organizations describing the same technology company, with the second providing additional detail about Delaware incorporation."
#         },
#         {
#           "entity1_id": "TECH CORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "Following transitivity from the previous matches, these represent the same entity. 'TECH CORP' (spaced version) and 'TECHCORP INC.' (with corporate suffix) are both variations of the same technology company name. The descriptions are consistent and complementary."
#         }
#       ],
#       "reasoning": "All three entities represent the same technology company with different name variations: 'TECHCORP' (base name), 'TECH CORP' (spaced version), and 'TECHCORP INC.' (with corporate suffix). The descriptions are all consistent, describing a technology company/corporation. The additional detail about Delaware incorporation in the third entity provides complementary rather than contradictory information. This is a clear case where common corporate naming variations (spacing and Inc. suffix) create multiple representations of the same real-world entity."
#     }
#     ```
#     ---Parsed Response (class EntityMatchingResult)---
#     {
#       "matches": [
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities have nearly identical names with only a space difference ('TECHCORP' vs 'TECH CORP'). Both are Organizations with very similar descriptions about being technology companies. This is a clear case of name variation for the same entity."
#         },
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities represent the same company with and without the corporate suffix. 'TECHCORP' and 'TECHCORP INC.' refer to the same entity, as 'Inc.' is just the legal incorporation designation. Both are Organizations describing the same technology company, with the second providing additional detail about Delaware incorporation."
#         },
#         {
#           "entity1_id": "TECH CORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "Following transitivity from the previous matches, these represent the same entity. 'TECH CORP' (spaced version) and 'TECHCORP INC.' (with corporate suffix) are both variations of the same technology company name. The descriptions are consistent and complementary."
#         }
#       ],
#       "reasoning": "All three entities represent the same technology company with different name variations: 'TECHCORP' (base name), 'TECH CORP' (spaced version), and 'TECHCORP INC.' (with corporate suffix). The descriptions are all consistent, describing a technology company/corporation. The additional detail about Delaware incorporation in the third entity provides complementary rather than contradictory information. This is a clear case where common corporate naming variations (spacing and Inc. suffix) create multiple representations of the same real-world entity."
#     }
# 2025-11-10T21:59:15.392 [BAML INFO] Function MatchEntities:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 7349ms. StopReason: end_turn. Tokens(in/out): 594/304
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate entities within a group of semantically similar entities.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Entities to analyze:**
#     ---
#     ID: JOHN SMITH
#     Type: Person
#     Description: CEO of TechCorp
#     Attributes: {}
#     ---
#     ID: J. SMITH
#     Type: Person
#     Description: Chief Executive Officer at Tech Corp
#     Attributes: {}
#     ---
#
#     **Task:**
#     Identify which entities in this group are duplicates of each other. Consider:
#
#     1. **Name variations**: "TechCorp", "Tech Corp", "TechCorp Inc." likely refer to the same entity
#     2. **Semantic similarity**: "NYC" and "New York City" are the same
#     3. **Type consistency**: Entities must have compatible types to be duplicates
#     4. **Attribute alignment**: Similar or complementary attributes strengthen a match
#     5. **Description consistency**: Descriptions should be compatible, not contradictory
#
#     **Guidelines:**
#     - Only mark entities as duplicates if you're confident they refer to the same real-world entity
#     - Use "high" confidence for clear matches (obvious name variations, identical descriptions)
#     - Use "medium" confidence for probable matches (semantic similarity, consistent attributes)
#     - Use "low" confidence for possible matches (weak signals, some inconsistency)
#     - Avoid false positives - when in doubt, mark is_duplicate as false
#     - Provide clear reasoning for each match decision
#     - Check for transitive consistency: if A matches B and B matches C, A should match C
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate pairs within this block
#       matches: [
#         {
#           // The unique identifier (name) of the first entity
#           entity1_id: string,
#           // The unique identifier (name) of the second entity
#           entity2_id: string,
#           // Whether these two entities represent the same real-world entity
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation of why these entities are or aren't duplicates, considering name variations, types, descriptions, and attributes
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "entity1_id": "JOHN SMITH",
#           "entity2_id": "J. SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities represent the same person based on multiple strong indicators: (1) Name variation - 'J. SMITH' is a common abbreviation for 'JOHN SMITH' where 'J.' represents the first name John, (2) Role equivalence - 'CEO' and 'Chief Executive Officer' are semantically identical positions, (3) Company variation - 'TechCorp' and 'Tech Corp' refer to the same company (space variation is common), (4) Type consistency - both are Person entities. All attributes align perfectly with no contradictory information."
#         }
#       ],
#       "reasoning": "I analyzed the two Person entities for potential duplication. The key factors supporting this match are the clear name abbreviation pattern (J. = John), identical roles with different phrasing (CEO vs Chief Executive Officer), and company name variations that are semantically equivalent (TechCorp vs Tech Corp). Given the context that first name abbreviations are common in this knowledge graph and the perfect alignment of all semantic elements, this is a high-confidence duplicate identification."
#     }
#     ```
#     ---Parsed Response (class EntityMatchingResult)---
#     {
#       "matches": [
#         {
#           "entity1_id": "JOHN SMITH",
#           "entity2_id": "J. SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities represent the same person based on multiple strong indicators: (1) Name variation - 'J. SMITH' is a common abbreviation for 'JOHN SMITH' where 'J.' represents the first name John, (2) Role equivalence - 'CEO' and 'Chief Executive Officer' are semantically identical positions, (3) Company variation - 'TechCorp' and 'Tech Corp' refer to the same company (space variation is common), (4) Type consistency - both are Person entities. All attributes align perfectly with no contradictory information."
#         }
#       ],
#       "reasoning": "I analyzed the two Person entities for potential duplication. The key factors supporting this match are the clear name abbreviation pattern (J. = John), identical roles with different phrasing (CEO vs Chief Executive Officer), and company name variations that are semantically equivalent (TechCorp vs Tech Corp). Given the context that first name abbreviations are common in this knowledge graph and the perfect alignment of all semantic elements, this is a high-confidence duplicate identification."
#     }
# 2025-11-10T21:59:35.709 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 9453ms. StopReason: end_turn. Tokens(in/out): 657/574
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: TECHCORP|HAS_TYPE|COMPANY
#     Triple: TECHCORP -[HAS_TYPE]-> COMPANY
#     Evidence:
#     ---
#     ID: TECH CORP|HAS_TYPE|COMPANY
#     Triple: TECH CORP -[HAS_TYPE]-> COMPANY
#     Evidence:
#     ---
#     ID: TECHCORP INC.|HAS_TYPE|COMPANY
#     Triple: TECHCORP INC. -[HAS_TYPE]-> COMPANY
#     Evidence:
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECH CORP|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges have identical predicates (HAS_TYPE) and objects (COMPANY). The subjects 'TECHCORP' and 'TECH CORP' represent the same entity - one is simply the spaced version of the other company name. This is a common variation in company naming conventions."
#         },
#         {
#           "edge1_id": "TECHCORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECHCORP INC.|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges have identical predicates (HAS_TYPE) and objects (COMPANY). The subjects 'TECHCORP' and 'TECHCORP INC.' represent the same entity, as 'Inc.' is a common corporate suffix that doesn't change the fundamental identity of the company. According to the context, suffixes like Inc. are considered equivalent variations."
#         },
#         {
#           "edge1_id": "TECH CORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECHCORP INC.|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges have identical predicates (HAS_TYPE) and objects (COMPANY). The subjects 'TECH CORP' and 'TECHCORP INC.' represent the same entity - 'TECH CORP' is the spaced version while 'TECHCORP INC.' adds the corporate suffix 'Inc.' Both variations refer to the same company entity."
#         }
#       ],
#       "reasoning": "All three edges in this group are duplicates of each other as they all describe the same fundamental relationship: that TechCorp (in its various name representations) is a company. The subjects represent the same entity with common naming variations (spacing and corporate suffixes), the predicates are identical (HAS_TYPE), and the objects are identical (COMPANY). The confidence level is high for all matches because the entity variations follow standard corporate naming conventions explicitly mentioned in the context."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECH CORP|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges have identical predicates (HAS_TYPE) and objects (COMPANY). The subjects 'TECHCORP' and 'TECH CORP' represent the same entity - one is simply the spaced version of the other company name. This is a common variation in company naming conventions."
#         },
#         {
#           "edge1_id": "TECHCORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECHCORP INC.|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges have identical predicates (HAS_TYPE) and objects (COMPANY). The subjects 'TECHCORP' and 'TECHCORP INC.' represent the same entity, as 'Inc.' is a common corporate suffix that doesn't change the fundamental identity of the company. According to the context, suffixes like Inc. are considered equivalent variations."
#         },
#         {
#           "edge1_id": "TECH CORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECHCORP INC.|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges have identical predicates (HAS_TYPE) and objects (COMPANY). The subjects 'TECH CORP' and 'TECHCORP INC.' represent the same entity - 'TECH CORP' is the spaced version while 'TECHCORP INC.' adds the corporate suffix 'Inc.' Both variations refer to the same company entity."
#         }
#       ],
#       "reasoning": "All three edges in this group are duplicates of each other as they all describe the same fundamental relationship: that TechCorp (in its various name representations) is a company. The subjects represent the same entity with common naming variations (spacing and corporate suffixes), the predicates are identical (HAS_TYPE), and the objects are identical (COMPANY). The confidence level is high for all matches because the entity variations follow standard corporate naming conventions explicitly mentioned in the context."
#     }
# 2025-11-10T21:59:43.895 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 8184ms. StopReason: end_turn. Tokens(in/out): 618/346
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: TECHCORP|LOCATED_IN|NEW YORK CITY
#     Triple: TECHCORP -[LOCATED_IN]-> NEW YORK CITY
#     Evidence:
#     ---
#     ID: TECH CORP|LOCATED_IN|NYC
#     Triple: TECH CORP -[LOCATED_IN]-> NYC
#     Evidence:
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|LOCATED_IN|NEW YORK CITY",
#           "edge2_id": "TECH CORP|LOCATED_IN|NYC",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same relationship between equivalent entities. 'TECHCORP' and 'TECH CORP' are the same company name with minor spacing variation. 'NEW YORK CITY' and 'NYC' are well-known equivalent references to the same location (NYC is the standard abbreviation for New York City). Both edges use identical predicates 'LOCATED_IN' and express the same directional relationship. The only differences are minor formatting variations in entity names that don't change their semantic meaning."
#         }
#       ],
#       "reasoning": "I analyzed the two edges for entity equivalence, predicate matching, and semantic similarity. Both edges describe the same technology company's location in New York City, with only minor textual variations: 'TECHCORP' vs 'TECH CORP' (spacing difference) and 'NEW YORK CITY' vs 'NYC' (full name vs standard abbreviation). These are common variations mentioned in the context guidelines. The predicate 'LOCATED_IN' is identical in both cases, and the relationship direction is consistent. Given the high semantic equivalence despite textual variations, these edges represent duplicate information about the same fact."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|LOCATED_IN|NEW YORK CITY",
#           "edge2_id": "TECH CORP|LOCATED_IN|NYC",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same relationship between equivalent entities. 'TECHCORP' and 'TECH CORP' are the same company name with minor spacing variation. 'NEW YORK CITY' and 'NYC' are well-known equivalent references to the same location (NYC is the standard abbreviation for New York City). Both edges use identical predicates 'LOCATED_IN' and express the same directional relationship. The only differences are minor formatting variations in entity names that don't change their semantic meaning."
#         }
#       ],
#       "reasoning": "I analyzed the two edges for entity equivalence, predicate matching, and semantic similarity. Both edges describe the same technology company's location in New York City, with only minor textual variations: 'TECHCORP' vs 'TECH CORP' (spacing difference) and 'NEW YORK CITY' vs 'NYC' (full name vs standard abbreviation). These are common variations mentioned in the context guidelines. The predicate 'LOCATED_IN' is identical in both cases, and the relationship direction is consistent. Given the high semantic equivalence despite textual variations, these edges represent duplicate information about the same fact."
#     }
# 2025-11-10T21:59:53.731 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 9834ms. StopReason: end_turn. Tokens(in/out): 1002/552
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: TECHCORP|SAME_AS|TECH CORP
#     Triple: TECHCORP -[SAME_AS]-> TECH CORP
#     Evidence: 1 source(s): These entities have nearly identical names with only a space difference ('TECHCORP' vs 'TECH CORP')....
#     ---
#     ID: TECHCORP|SAME_AS|TECHCORP INC.
#     Triple: TECHCORP -[SAME_AS]-> TECHCORP INC.
#     Evidence: 1 source(s): These entities represent the same company with and without the corporate suffix. 'TECHCORP' and 'TEC...
#     ---
#     ID: TECH CORP|SAME_AS|TECHCORP
#     Triple: TECH CORP -[SAME_AS]-> TECHCORP
#     Evidence: 1 source(s): These entities have nearly identical names with only a space difference ('TECHCORP' vs 'TECH CORP')....
#     ---
#     ID: TECH CORP|SAME_AS|TECHCORP INC.
#     Triple: TECH CORP -[SAME_AS]-> TECHCORP INC.
#     Evidence: 1 source(s): Following transitivity from the previous matches, these represent the same entity. 'TECH CORP' (spac...
#     ---
#     ID: TECHCORP INC.|SAME_AS|TECHCORP
#     Triple: TECHCORP INC. -[SAME_AS]-> TECHCORP
#     Evidence: 1 source(s): These entities represent the same company with and without the corporate suffix. 'TECHCORP' and 'TEC...
#     ---
#     ID: TECHCORP INC.|SAME_AS|TECH CORP
#     Triple: TECHCORP INC. -[SAME_AS]-> TECH CORP
#     Evidence: 1 source(s): Following transitivity from the previous matches, these represent the same entity. 'TECH CORP' (spac...
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|SAME_AS|TECH CORP",
#           "edge2_id": "TECH CORP|SAME_AS|TECHCORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the exact same relationship in reverse directions. Both connect TECHCORP and TECH CORP with SAME_AS relationship, and both cite identical evidence about the space difference between the entity names."
#         },
#         {
#           "edge1_id": "TECHCORP|SAME_AS|TECHCORP INC.",
#           "edge2_id": "TECHCORP INC.|SAME_AS|TECHCORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the exact same relationship in reverse directions. Both connect TECHCORP and TECHCORP INC. with SAME_AS relationship, and both cite identical evidence about representing the same company with/without corporate suffix."
#         },
#         {
#           "edge1_id": "TECH CORP|SAME_AS|TECHCORP INC.",
#           "edge2_id": "TECHCORP INC.|SAME_AS|TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the exact same relationship in reverse directions. Both connect TECH CORP and TECHCORP INC. with SAME_AS relationship, and both cite identical evidence about transitivity and representing the same entity."
#         }
#       ],
#       "reasoning": "This analysis focuses on identifying duplicate SAME_AS relationships between three entity variants: TECHCORP, TECH CORP, and TECHCORP INC. Since SAME_AS is a symmetric relationship, edges going in both directions (A→B and B→A) represent the same semantic fact and are therefore duplicates. I identified three pairs of reverse-direction duplicates with high confidence, as they have identical subjects/objects (just swapped), identical predicates, and cite the same evidence sources. The remaining edges represent unique entity pairs and are not duplicates of each other, even though they're part of the same transitivity chain establishing that all three entities refer to the same company."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|SAME_AS|TECH CORP",
#           "edge2_id": "TECH CORP|SAME_AS|TECHCORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the exact same relationship in reverse directions. Both connect TECHCORP and TECH CORP with SAME_AS relationship, and both cite identical evidence about the space difference between the entity names."
#         },
#         {
#           "edge1_id": "TECHCORP|SAME_AS|TECHCORP INC.",
#           "edge2_id": "TECHCORP INC.|SAME_AS|TECHCORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the exact same relationship in reverse directions. Both connect TECHCORP and TECHCORP INC. with SAME_AS relationship, and both cite identical evidence about representing the same company with/without corporate suffix."
#         },
#         {
#           "edge1_id": "TECH CORP|SAME_AS|TECHCORP INC.",
#           "edge2_id": "TECHCORP INC.|SAME_AS|TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the exact same relationship in reverse directions. Both connect TECH CORP and TECHCORP INC. with SAME_AS relationship, and both cite identical evidence about transitivity and representing the same entity."
#         }
#       ],
#       "reasoning": "This analysis focuses on identifying duplicate SAME_AS relationships between three entity variants: TECHCORP, TECH CORP, and TECHCORP INC. Since SAME_AS is a symmetric relationship, edges going in both directions (A→B and B→A) represent the same semantic fact and are therefore duplicates. I identified three pairs of reverse-direction duplicates with high confidence, as they have identical subjects/objects (just swapped), identical predicates, and cite the same evidence sources. The remaining edges represent unique entity pairs and are not duplicates of each other, even though they're part of the same transitivity chain establishing that all three entities refer to the same company."
#     }
# 2025-11-10T22:00:01.617 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 7883ms. StopReason: end_turn. Tokens(in/out): 610/329
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: NEW YORK CITY|HAS_TYPE|LOCATION
#     Triple: NEW YORK CITY -[HAS_TYPE]-> LOCATION
#     Evidence:
#     ---
#     ID: NYC|HAS_TYPE|LOCATION
#     Triple: NYC -[HAS_TYPE]-> LOCATION
#     Evidence:
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "NEW YORK CITY|HAS_TYPE|LOCATION",
#           "edge2_id": "NYC|HAS_TYPE|LOCATION",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges are duplicates because: 1) The subject entities 'NEW YORK CITY' and 'NYC' refer to the same geographical location (NYC is a well-known abbreviation for New York City as mentioned in the context), 2) Both use identical predicates 'HAS_TYPE', 3) Both have identical objects 'LOCATION', 4) The relationship direction is consistent in both cases. This represents the exact same factual statement about the same entity having the same type classification."
#         }
#       ],
#       "reasoning": "I analyzed the two edges by comparing their components systematically. Both edges express the same fundamental relationship - that New York City is classified as a location. The key insight is recognizing that 'NYC' is a standard abbreviation for 'NEW YORK CITY', which was explicitly mentioned in the context as a common variation. Since the predicate and object are identical in both cases, and the subjects refer to the same real-world entity, these edges represent duplicate information in the knowledge graph. The high confidence level is justified because this is a clear case of entity equivalence with identical relationship structure."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "NEW YORK CITY|HAS_TYPE|LOCATION",
#           "edge2_id": "NYC|HAS_TYPE|LOCATION",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges are duplicates because: 1) The subject entities 'NEW YORK CITY' and 'NYC' refer to the same geographical location (NYC is a well-known abbreviation for New York City as mentioned in the context), 2) Both use identical predicates 'HAS_TYPE', 3) Both have identical objects 'LOCATION', 4) The relationship direction is consistent in both cases. This represents the exact same factual statement about the same entity having the same type classification."
#         }
#       ],
#       "reasoning": "I analyzed the two edges by comparing their components systematically. Both edges express the same fundamental relationship - that New York City is classified as a location. The key insight is recognizing that 'NYC' is a standard abbreviation for 'NEW YORK CITY', which was explicitly mentioned in the context as a common variation. Since the predicate and object are identical in both cases, and the subjects refer to the same real-world entity, these edges represent duplicate information in the knowledge graph. The high confidence level is justified because this is a clear case of entity equivalence with identical relationship structure."
#     }
# 2025-11-10T22:00:09.320 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 7702ms. StopReason: end_turn. Tokens(in/out): 614/325
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: JOHN SMITH|HAS_TYPE|PERSON
#     Triple: JOHN SMITH -[HAS_TYPE]-> PERSON
#     Evidence:
#     ---
#     ID: J. SMITH|HAS_TYPE|PERSON
#     Triple: J. SMITH -[HAS_TYPE]-> PERSON
#     Evidence:
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     {
#       "matches": [
#         {
#           "edge1_id": "JOHN SMITH|HAS_TYPE|PERSON",
#           "edge2_id": "J. SMITH|HAS_TYPE|PERSON",
#           "is_duplicate": true,
#           "confidence_level": "medium",
#           "reasoning": "These edges likely represent the same relationship between equivalent entities. 'JOHN SMITH' and 'J. SMITH' are very likely the same person, as 'J.' is a common abbreviation for 'John' and they share the same surname 'SMITH'. Both edges use identical predicates (HAS_TYPE) and objects (PERSON), establishing the same type relationship. However, confidence is medium rather than high because we cannot be 100% certain without additional context that J. SMITH specifically abbreviates John rather than another J-name."
#         }
#       ],
#       "reasoning": "I analyzed the two edges for entity equivalence, predicate matching, and relationship consistency. The key consideration was whether 'JOHN SMITH' and 'J. SMITH' represent the same person. Given that 'J.' is a standard abbreviation for 'John' and both share the surname 'SMITH', combined with identical predicates and objects, these edges most likely describe the same fact about the same individual. The medium confidence reflects the slight uncertainty inherent in name abbreviation matching without additional disambiguating context."
#     }
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "JOHN SMITH|HAS_TYPE|PERSON",
#           "edge2_id": "J. SMITH|HAS_TYPE|PERSON",
#           "is_duplicate": true,
#           "confidence_level": "medium",
#           "reasoning": "These edges likely represent the same relationship between equivalent entities. 'JOHN SMITH' and 'J. SMITH' are very likely the same person, as 'J.' is a common abbreviation for 'John' and they share the same surname 'SMITH'. Both edges use identical predicates (HAS_TYPE) and objects (PERSON), establishing the same type relationship. However, confidence is medium rather than high because we cannot be 100% certain without additional context that J. SMITH specifically abbreviates John rather than another J-name."
#         }
#       ],
#       "reasoning": "I analyzed the two edges for entity equivalence, predicate matching, and relationship consistency. The key consideration was whether 'JOHN SMITH' and 'J. SMITH' represent the same person. Given that 'J.' is a standard abbreviation for 'John' and both share the surname 'SMITH', combined with identical predicates and objects, these edges most likely describe the same fact about the same individual. The medium confidence reflects the slight uncertainty inherent in name abbreviation matching without additional disambiguating context."
#     }
# 2025-11-10T22:00:16.875 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 7552ms. StopReason: end_turn. Tokens(in/out): 674/302
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: JOHN SMITH|SAME_AS|J. SMITH
#     Triple: JOHN SMITH -[SAME_AS]-> J. SMITH
#     Evidence: 1 source(s): These entities represent the same person based on multiple strong indicators: (1) Name variation - '...
#     ---
#     ID: J. SMITH|SAME_AS|JOHN SMITH
#     Triple: J. SMITH -[SAME_AS]-> JOHN SMITH
#     Evidence: 1 source(s): These entities represent the same person based on multiple strong indicators: (1) Name variation - '...
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "JOHN SMITH|SAME_AS|J. SMITH",
#           "edge2_id": "J. SMITH|SAME_AS|JOHN SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same symmetric relationship between identical entities. Both edges express that 'JOHN SMITH' and 'J. SMITH' are the same person, just with reversed subject/object positions. The SAME_AS predicate is inherently symmetric, meaning A SAME_AS B is logically equivalent to B SAME_AS A. Both edges have identical evidence patterns (1 source each with matching reasoning about name variations), and they describe the same fundamental fact about entity equivalence."
#         }
#       ],
#       "reasoning": "This analysis involved two edges with a symmetric SAME_AS relationship between 'JOHN SMITH' and 'J. SMITH'. Since SAME_AS predicates are bidirectional by nature (if A is the same as B, then B is the same as A), these edges represent duplicate information about the same entity equivalence relationship. The evidence overlap and identical semantic meaning despite reversed directionality confirms they are duplicates with high confidence."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "JOHN SMITH|SAME_AS|J. SMITH",
#           "edge2_id": "J. SMITH|SAME_AS|JOHN SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same symmetric relationship between identical entities. Both edges express that 'JOHN SMITH' and 'J. SMITH' are the same person, just with reversed subject/object positions. The SAME_AS predicate is inherently symmetric, meaning A SAME_AS B is logically equivalent to B SAME_AS A. Both edges have identical evidence patterns (1 source each with matching reasoning about name variations), and they describe the same fundamental fact about entity equivalence."
#         }
#       ],
#       "reasoning": "This analysis involved two edges with a symmetric SAME_AS relationship between 'JOHN SMITH' and 'J. SMITH'. Since SAME_AS predicates are bidirectional by nature (if A is the same as B, then B is the same as A), these edges represent duplicate information about the same entity equivalence relationship. The evidence overlap and identical semantic meaning despite reversed directionality confirms they are duplicates with high confidence."
#     }
#
#  Resolution complete!

# %% [markdown]
# ## Analyze Results

# %%
print("=" * 60)
print("RESOLUTION SUMMARY")
print("=" * 60)
print(f"Nodes processed: {result.total_nodes_processed}")
print(f"Edges processed: {result.total_edges_processed}")
print(f"Blocks created: {result.blocks_created}")
print(f"SAME_AS edges created: {result.same_as_edges_created}")
print(f"Duplicate clusters: {result.duplicate_clusters}")
print(f"Execution time: {result.execution_time_seconds:.2f}s")
print("\n" + "=" * 60)
# Out:
# ============================================================
# RESOLUTION SUMMARY
# ============================================================
# Nodes processed: 10
# Edges processed: 19
# Blocks created: 8
# SAME_AS edges created: 14
# Duplicate clusters: 2
# Execution time: 87.67s
#
# ============================================================

# %% [markdown]
# ## Node Matches
#
# Examine which nodes were identified as duplicates:

# %%
print(f"\nNode matches found: {len(result.node_matches)}\n")
for i, match in enumerate(result.node_matches, 1):
    if match.is_duplicate:
        print(f"Match {i}:")
        print(f"  Entity 1: {match.entity1_id}")
        print(f"  Entity 2: {match.entity2_id}")
        print(f"  Confidence: {match.confidence:.2f}")
        print(f"  Reasoning: {match.reasoning}")
        print()
# Out:
# Node matches found: 4
#
# Match 1:
#   Entity 1: TECHCORP
#   Entity 2: TECH CORP
#   Confidence: 0.95
#   Reasoning: These entities have nearly identical names with only a space difference ('TECHCORP' vs 'TECH CORP'). Both are Organizations with very similar descriptions about being technology companies. This is a clear case of name variation for the same entity.
#
# Match 2:
#   Entity 1: TECHCORP
#   Entity 2: TECHCORP INC.
#   Confidence: 0.95
#   Reasoning: These entities represent the same company with and without the corporate suffix. 'TECHCORP' and 'TECHCORP INC.' refer to the same entity, as 'Inc.' is just the legal incorporation designation. Both are Organizations describing the same technology company, with the second providing additional detail about Delaware incorporation.
#
# Match 3:
#   Entity 1: TECH CORP
#   Entity 2: TECHCORP INC.
#   Confidence: 0.95
#   Reasoning: Following transitivity from the previous matches, these represent the same entity. 'TECH CORP' (spaced version) and 'TECHCORP INC.' (with corporate suffix) are both variations of the same technology company name. The descriptions are consistent and complementary.
#
# Match 4:
#   Entity 1: JOHN SMITH
#   Entity 2: J. SMITH
#   Confidence: 0.95
#   Reasoning: These entities represent the same person based on multiple strong indicators: (1) Name variation - 'J. SMITH' is a common abbreviation for 'JOHN SMITH' where 'J.' represents the first name John, (2) Role equivalence - 'CEO' and 'Chief Executive Officer' are semantically identical positions, (3) Company variation - 'TechCorp' and 'Tech Corp' refer to the same company (space variation is common), (4) Type consistency - both are Person entities. All attributes align perfectly with no contradictory information.

# %% [markdown]
# ## Edge Matches
#
# Examine which edges were identified as duplicates:

# %%
print(f"\nEdge matches found: {len(result.edge_matches)}\n")
for i, match in enumerate(result.edge_matches, 1):
    if match.is_duplicate:
        print(f"Match {i}:")
        print(f"  Edge 1: {match.edge1_id}")
        print(f"  Edge 2: {match.edge2_id}")
        print(f"  Confidence: {match.confidence:.2f}")
        print(f"  Reasoning: {match.reasoning}")
        print()
# Out:
# Edge matches found: 10
#
# Match 1:
#   Edge 1: TECHCORP|HAS_TYPE|COMPANY
#   Edge 2: TECH CORP|HAS_TYPE|COMPANY
#   Confidence: 0.95
#   Reasoning: These edges have identical predicates (HAS_TYPE) and objects (COMPANY). The subjects 'TECHCORP' and 'TECH CORP' represent the same entity - one is simply the spaced version of the other company name. This is a common variation in company naming conventions.
#
# Match 2:
#   Edge 1: TECHCORP|HAS_TYPE|COMPANY
#   Edge 2: TECHCORP INC.|HAS_TYPE|COMPANY
#   Confidence: 0.95
#   Reasoning: These edges have identical predicates (HAS_TYPE) and objects (COMPANY). The subjects 'TECHCORP' and 'TECHCORP INC.' represent the same entity, as 'Inc.' is a common corporate suffix that doesn't change the fundamental identity of the company. According to the context, suffixes like Inc. are considered equivalent variations.
#
# Match 3:
#   Edge 1: TECH CORP|HAS_TYPE|COMPANY
#   Edge 2: TECHCORP INC.|HAS_TYPE|COMPANY
#   Confidence: 0.95
#   Reasoning: These edges have identical predicates (HAS_TYPE) and objects (COMPANY). The subjects 'TECH CORP' and 'TECHCORP INC.' represent the same entity - 'TECH CORP' is the spaced version while 'TECHCORP INC.' adds the corporate suffix 'Inc.' Both variations refer to the same company entity.
#
# Match 4:
#   Edge 1: TECHCORP|LOCATED_IN|NEW YORK CITY
#   Edge 2: TECH CORP|LOCATED_IN|NYC
#   Confidence: 0.95
#   Reasoning: These edges represent the same relationship between equivalent entities. 'TECHCORP' and 'TECH CORP' are the same company name with minor spacing variation. 'NEW YORK CITY' and 'NYC' are well-known equivalent references to the same location (NYC is the standard abbreviation for New York City). Both edges use identical predicates 'LOCATED_IN' and express the same directional relationship. The only differences are minor formatting variations in entity names that don't change their semantic meaning.
#
# Match 5:
#   Edge 1: TECHCORP|SAME_AS|TECH CORP
#   Edge 2: TECH CORP|SAME_AS|TECHCORP
#   Confidence: 0.95
#   Reasoning: These edges represent the exact same relationship in reverse directions. Both connect TECHCORP and TECH CORP with SAME_AS relationship, and both cite identical evidence about the space difference between the entity names.
#
# Match 6:
#   Edge 1: TECHCORP|SAME_AS|TECHCORP INC.
#   Edge 2: TECHCORP INC.|SAME_AS|TECHCORP
#   Confidence: 0.95
#   Reasoning: These edges represent the exact same relationship in reverse directions. Both connect TECHCORP and TECHCORP INC. with SAME_AS relationship, and both cite identical evidence about representing the same company with/without corporate suffix.
#
# Match 7:
#   Edge 1: TECH CORP|SAME_AS|TECHCORP INC.
#   Edge 2: TECHCORP INC.|SAME_AS|TECH CORP
#   Confidence: 0.95
#   Reasoning: These edges represent the exact same relationship in reverse directions. Both connect TECH CORP and TECHCORP INC. with SAME_AS relationship, and both cite identical evidence about transitivity and representing the same entity.
#
# Match 8:
#   Edge 1: NEW YORK CITY|HAS_TYPE|LOCATION
#   Edge 2: NYC|HAS_TYPE|LOCATION
#   Confidence: 0.95
#   Reasoning: These edges are duplicates because: 1) The subject entities 'NEW YORK CITY' and 'NYC' refer to the same geographical location (NYC is a well-known abbreviation for New York City as mentioned in the context), 2) Both use identical predicates 'HAS_TYPE', 3) Both have identical objects 'LOCATION', 4) The relationship direction is consistent in both cases. This represents the exact same factual statement about the same entity having the same type classification.
#
# Match 9:
#   Edge 1: JOHN SMITH|HAS_TYPE|PERSON
#   Edge 2: J. SMITH|HAS_TYPE|PERSON
#   Confidence: 0.75
#   Reasoning: These edges likely represent the same relationship between equivalent entities. 'JOHN SMITH' and 'J. SMITH' are very likely the same person, as 'J.' is a common abbreviation for 'John' and they share the same surname 'SMITH'. Both edges use identical predicates (HAS_TYPE) and objects (PERSON), establishing the same type relationship. However, confidence is medium rather than high because we cannot be 100% certain without additional context that J. SMITH specifically abbreviates John rather than another J-name.
#
# Match 10:
#   Edge 1: JOHN SMITH|SAME_AS|J. SMITH
#   Edge 2: J. SMITH|SAME_AS|JOHN SMITH
#   Confidence: 0.95
#   Reasoning: These edges represent the same symmetric relationship between identical entities. Both edges express that 'JOHN SMITH' and 'J. SMITH' are the same person, just with reversed subject/object positions. The SAME_AS predicate is inherently symmetric, meaning A SAME_AS B is logically equivalent to B SAME_AS A. Both edges have identical evidence patterns (1 source each with matching reasoning about name variations), and they describe the same fundamental fact about entity equivalence.

# %% [markdown]
# ## Duplicate Clusters
#
# Groups of connected entities via SAME_AS relationships:

# %%
from spindle.entity_resolution import get_duplicate_clusters

clusters = get_duplicate_clusters(graph_store)

print(f"\nDuplicate clusters found: {len(clusters)}\n")
for i, cluster in enumerate(clusters, 1):
    print(f"Cluster {i}: {sorted(cluster)}")
# Out:
# Duplicate clusters found: 2
#
# Cluster 1: ['TECH CORP', 'TECHCORP', 'TECHCORP INC.']
# Cluster 2: ['J. SMITH', 'JOHN SMITH']

# %% [markdown]
# ## Query Resolved Graph
#
# ### View SAME_AS Edges

# %%
# Query all SAME_AS edges
same_as_edges = graph_store.query_by_pattern(predicate="SAME_AS")

print(f"\nSAME_AS edges in graph: {len(same_as_edges)}\n")
for edge in same_as_edges:
    print(f"{edge['subject']} --[SAME_AS]--> {edge['object']}")

    # Show confidence and reasoning from metadata
    metadata = edge.get("metadata", {})
    if isinstance(metadata, str):
        metadata = json.loads(metadata)

    confidence = metadata.get("confidence", "N/A")
    if confidence == "N/A":
        print("  Confidence: N/A")
    else:
        print(f"  Confidence: {confidence:.2f}")

    reasoning = metadata.get("reasoning")
    if reasoning:
        print(f"  Reasoning: {reasoning}")
    print()
# Out:
# SAME_AS edges in graph: 8
#
# TECHCORP --[SAME_AS]--> TECHCORP INC.
#   Confidence: 0.95
#
# TECHCORP --[SAME_AS]--> TECH CORP
#   Confidence: 0.95
#
# TECH CORP --[SAME_AS]--> TECHCORP INC.
#   Confidence: 0.95
#
# TECH CORP --[SAME_AS]--> TECHCORP
#   Confidence: 0.95
#
# TECHCORP INC. --[SAME_AS]--> TECH CORP
#   Confidence: 0.95
#
# TECHCORP INC. --[SAME_AS]--> TECHCORP
#   Confidence: 0.95
#
# JOHN SMITH --[SAME_AS]--> J. SMITH
#   Confidence: 0.95
#
# J. SMITH --[SAME_AS]--> JOHN SMITH
#   Confidence: 0.95

# %% [markdown]
# ### Get Canonical Entity Names
#
# Find the "primary" entity name for each duplicate cluster:

# %%
print("\nCanonical entity mappings\n")

for cluster in clusters:
    canonical = min(cluster)  # Alphabetically first
    print(f"Canonical: {canonical}")
    for entity in sorted(cluster):
        if entity != canonical:
            print(f"  - {entity}")
    print()
# Out:
# Canonical entity mappings
#
# Canonical: TECH CORP
#   - TECHCORP
#   - TECHCORP INC.
#
# Canonical: J. SMITH
#   - JOHN SMITH

# %% [markdown]
# ## Export Results
#
# Save resolution results for later analysis:

# %%
# Convert result to dictionary
result_dict = result.to_dict()

# Pretty print
print("\nResolution results as JSON:\n")
print(json.dumps(result_dict, indent=2))
# Out:
# Resolution results as JSON:
#
# {
#   "total_nodes_processed": 10,
#   "total_edges_processed": 19,
#   "blocks_created": 8,
#   "same_as_edges_created": 14,
#   "duplicate_clusters": 2,
#   "node_match_count": 4,
#   "edge_match_count": 10,
#   "execution_time_seconds": 87.674432,
#   "config": {
#     "blocking_threshold": 0.85,
#     "matching_threshold": 0.75,
#     "clustering_method": "hierarchical"
#   }
# }

# %%
# Optional: Save to file
output_path = Path("resolution_results.json")

with open(output_path, "w") as f:
    json.dump(result_dict, f, indent=2)

print(f"✅ Results saved to {output_path}")
# Out:
# ✅ Results saved to resolution_results.json

# %% [markdown]
# ## Experiment: Different Configurations
#
# ### Conservative Configuration (High Precision)
#
# Only match entities with very high confidence:

# %%
# Create a fresh graph for comparison
graph_store_conservative = GraphStore("resolution_conservative")
load_sample_triples(
    graph_store_conservative,
    sample_triples,
    source_name="sample_data_conservative",
)

# Conservative config
conservative_config = ResolutionConfig(
    blocking_threshold=0.90,  # Higher threshold
    matching_threshold=0.85,  # Only high confidence
    clustering_method="hierarchical",
    min_cluster_size=3,  # Require at least 3 entities
)

# Run resolution
resolver_conservative = EntityResolver(config=conservative_config)
result_conservative = resolver_conservative.resolve_entities(
    graph_store=graph_store_conservative,
    vector_store=vector_store,
    apply_to_nodes=True,
    apply_to_edges=False,
    context=context,
)

print("\nConservative configuration results:")
print(f"  SAME_AS edges: {result_conservative.same_as_edges_created}")
print(f"  Clusters: {result_conservative.duplicate_clusters}")
print(f"  Node matches: {len(result_conservative.node_matches)}")
# Out:
# Conservative configuration results:
#   SAME_AS edges: 0
#   Clusters: 0
#   Node matches: 0

# %% [markdown]
# ### Aggressive Configuration (High Recall)
#
# Match more entities with lower confidence thresholds:

# %%
# Create a fresh graph for comparison
graph_store_aggressive = GraphStore("resolution_aggressive")
load_sample_triples(
    graph_store_aggressive,
    sample_triples,
    source_name="sample_data_aggressive",
)

# Aggressive config
aggressive_config = ResolutionConfig(
    blocking_threshold=0.75,  # Lower threshold
    matching_threshold=0.65,  # Accept lower confidence
    clustering_method="hierarchical",
    min_cluster_size=2,
)

# Run resolution
resolver_aggressive = EntityResolver(config=aggressive_config)
result_aggressive = resolver_aggressive.resolve_entities(
    graph_store=graph_store_aggressive,
    vector_store=vector_store,
    apply_to_nodes=True,
    apply_to_edges=False,
    context=context,
)

print("\nAggressive configuration results:")
print(f"  SAME_AS edges: {result_aggressive.same_as_edges_created}")
print(f"  Clusters: {result_aggressive.duplicate_clusters}")
print(f"  Node matches: {len(result_aggressive.node_matches)}")
# Out:
# 2025-11-10T22:04:06.455 [BAML INFO] Function MatchEntities:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 12888ms. StopReason: end_turn. Tokens(in/out): 621/577
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate entities within a group of semantically similar entities.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Entities to analyze:**
#     ---
#     ID: TECHCORP
#     Type: Organization
#     Description: A leading technology company.
#     Attributes: {}
#     ---
#     ID: TECH CORP
#     Type: Organization
#     Description: A technology corporation.
#     Attributes: {}
#     ---
#     ID: TECHCORP INC.
#     Type: Organization
#     Description: Technology company incorporated in Delaware.
#     Attributes: {}
#     ---
#
#     **Task:**
#     Identify which entities in this group are duplicates of each other. Consider:
#
#     1. **Name variations**: "TechCorp", "Tech Corp", "TechCorp Inc." likely refer to the same entity
#     2. **Semantic similarity**: "NYC" and "New York City" are the same
#     3. **Type consistency**: Entities must have compatible types to be duplicates
#     4. **Attribute alignment**: Similar or complementary attributes strengthen a match
#     5. **Description consistency**: Descriptions should be compatible, not contradictory
#
#     **Guidelines:**
#     - Only mark entities as duplicates if you're confident they refer to the same real-world entity
#     - Use "high" confidence for clear matches (obvious name variations, identical descriptions)
#     - Use "medium" confidence for probable matches (semantic similarity, consistent attributes)
#     - Use "low" confidence for possible matches (weak signals, some inconsistency)
#     - Avoid false positives - when in doubt, mark is_duplicate as false
#     - Provide clear reasoning for each match decision
#     - Check for transitive consistency: if A matches B and B matches C, A should match C
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate pairs within this block
#       matches: [
#         {
#           // The unique identifier (name) of the first entity
#           entity1_id: string,
#           // The unique identifier (name) of the second entity
#           entity2_id: string,
#           // Whether these two entities represent the same real-world entity
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation of why these entities are or aren't duplicates, considering name variations, types, descriptions, and attributes
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities have nearly identical names with only a space difference ('TECHCORP' vs 'TECH CORP'). Both are Organizations with very similar descriptions ('A leading technology company' vs 'A technology corporation'). The descriptions are semantically equivalent, both referring to technology companies, with 'leading' and 'corporation' being compatible descriptors."
#         },
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities have the same core name 'TECHCORP' with the second having the common corporate suffix 'INC.' The context explicitly states that 'Corp, Corporation, Inc., LLC are equivalent suffixes'. Both are Organizations with compatible descriptions about technology companies. The incorporation detail in Delaware for the second entity is additional information that doesn't contradict the first entity."
#         },
#         {
#           "entity1_id": "TECH CORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "Following transitive consistency from the previous matches, and applying the same reasoning: 'TECH CORP' is the spaced version of the core name, while 'TECHCORP INC.' is the combined version with corporate suffix. Both refer to technology companies with compatible descriptions. All three entities appear to represent the same real-world technology corporation with different name formatting variations."
#         }
#       ],
#       "reasoning": "All three entities appear to represent the same technology company with different name variations. The analysis shows: (1) TECHCORP vs TECH CORP differs only by spacing, (2) TECHCORP vs TECHCORP INC. differs only by the corporate suffix, and (3) all have compatible Organization types and descriptions about technology companies. The context guidelines confirm that spacing differences and corporate suffixes like 'Inc.' are common variations for the same entity. The transitive relationship holds consistently - if TECHCORP matches both others, then all three represent the same real-world entity. High confidence is appropriate given the clear name variation patterns and semantic consistency across descriptions."
#     }
#     ```
#     ---Parsed Response (class EntityMatchingResult)---
#     {
#       "matches": [
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities have nearly identical names with only a space difference ('TECHCORP' vs 'TECH CORP'). Both are Organizations with very similar descriptions ('A leading technology company' vs 'A technology corporation'). The descriptions are semantically equivalent, both referring to technology companies, with 'leading' and 'corporation' being compatible descriptors."
#         },
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities have the same core name 'TECHCORP' with the second having the common corporate suffix 'INC.' The context explicitly states that 'Corp, Corporation, Inc., LLC are equivalent suffixes'. Both are Organizations with compatible descriptions about technology companies. The incorporation detail in Delaware for the second entity is additional information that doesn't contradict the first entity."
#         },
#         {
#           "entity1_id": "TECH CORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "Following transitive consistency from the previous matches, and applying the same reasoning: 'TECH CORP' is the spaced version of the core name, while 'TECHCORP INC.' is the combined version with corporate suffix. Both refer to technology companies with compatible descriptions. All three entities appear to represent the same real-world technology corporation with different name formatting variations."
#         }
#       ],
#       "reasoning": "All three entities appear to represent the same technology company with different name variations. The analysis shows: (1) TECHCORP vs TECH CORP differs only by spacing, (2) TECHCORP vs TECHCORP INC. differs only by the corporate suffix, and (3) all have compatible Organization types and descriptions about technology companies. The context guidelines confirm that spacing differences and corporate suffixes like 'Inc.' are common variations for the same entity. The transitive relationship holds consistently - if TECHCORP matches both others, then all three represent the same real-world entity. High confidence is appropriate given the clear name variation patterns and semantic consistency across descriptions."
#     }
# 2025-11-10T22:04:14.647 [BAML INFO] Function MatchEntities:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 8190ms. StopReason: end_turn. Tokens(in/out): 594/309
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate entities within a group of semantically similar entities.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Entities to analyze:**
#     ---
#     ID: JOHN SMITH
#     Type: Person
#     Description: CEO of TechCorp
#     Attributes: {}
#     ---
#     ID: J. SMITH
#     Type: Person
#     Description: Chief Executive Officer at Tech Corp
#     Attributes: {}
#     ---
#
#     **Task:**
#     Identify which entities in this group are duplicates of each other. Consider:
#
#     1. **Name variations**: "TechCorp", "Tech Corp", "TechCorp Inc." likely refer to the same entity
#     2. **Semantic similarity**: "NYC" and "New York City" are the same
#     3. **Type consistency**: Entities must have compatible types to be duplicates
#     4. **Attribute alignment**: Similar or complementary attributes strengthen a match
#     5. **Description consistency**: Descriptions should be compatible, not contradictory
#
#     **Guidelines:**
#     - Only mark entities as duplicates if you're confident they refer to the same real-world entity
#     - Use "high" confidence for clear matches (obvious name variations, identical descriptions)
#     - Use "medium" confidence for probable matches (semantic similarity, consistent attributes)
#     - Use "low" confidence for possible matches (weak signals, some inconsistency)
#     - Avoid false positives - when in doubt, mark is_duplicate as false
#     - Provide clear reasoning for each match decision
#     - Check for transitive consistency: if A matches B and B matches C, A should match C
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate pairs within this block
#       matches: [
#         {
#           // The unique identifier (name) of the first entity
#           entity1_id: string,
#           // The unique identifier (name) of the second entity
#           entity2_id: string,
#           // Whether these two entities represent the same real-world entity
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation of why these entities are or aren't duplicates, considering name variations, types, descriptions, and attributes
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "entity1_id": "JOHN SMITH",
#           "entity2_id": "J. SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities represent the same person based on multiple strong indicators: (1) Name variation - 'J. SMITH' is a common abbreviation for 'JOHN SMITH' where 'J.' represents the first name John; (2) Role consistency - both are described as CEO/Chief Executive Officer, which are the same position; (3) Company consistency - 'TechCorp' and 'Tech Corp' are name variations of the same company (one word vs. two words); (4) Type compatibility - both are Person entities. All evidence points to this being the same individual with minor variations in how their name and company are recorded."
#         }
#       ],
#       "reasoning": "This analysis involved comparing two Person entities with similar names and roles. The key factors that led to identifying them as duplicates were the standard name abbreviation pattern (J. = John), identical executive roles (CEO = Chief Executive Officer), and equivalent company name variations (TechCorp = Tech Corp). These are all common variations found in business contexts where the same person's information might be recorded slightly differently across different sources or systems."
#     }
#     ```
#     ---Parsed Response (class EntityMatchingResult)---
#     {
#       "matches": [
#         {
#           "entity1_id": "JOHN SMITH",
#           "entity2_id": "J. SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities represent the same person based on multiple strong indicators: (1) Name variation - 'J. SMITH' is a common abbreviation for 'JOHN SMITH' where 'J.' represents the first name John; (2) Role consistency - both are described as CEO/Chief Executive Officer, which are the same position; (3) Company consistency - 'TechCorp' and 'Tech Corp' are name variations of the same company (one word vs. two words); (4) Type compatibility - both are Person entities. All evidence points to this being the same individual with minor variations in how their name and company are recorded."
#         }
#       ],
#       "reasoning": "This analysis involved comparing two Person entities with similar names and roles. The key factors that led to identifying them as duplicates were the standard name abbreviation pattern (J. = John), identical executive roles (CEO = Chief Executive Officer), and equivalent company name variations (TechCorp = Tech Corp). These are all common variations found in business contexts where the same person's information might be recorded slightly differently across different sources or systems."
#     }
#
# Aggressive configuration results:
#   SAME_AS edges: 4
#   Clusters: 2
#   Node matches: 4

# %% [markdown]
# ### Compare Configurations

# %%
import pandas as pd

comparison = pd.DataFrame([
    {
        "Config": "Default",
        "Blocking Threshold": 0.85,
        "Matching Threshold": 0.75,
        "SAME_AS Edges": result.same_as_edges_created,
        "Clusters": result.duplicate_clusters,
        "Matches": len(result.node_matches),
    },
    {
        "Config": "Conservative",
        "Blocking Threshold": 0.90,
        "Matching Threshold": 0.85,
        "SAME_AS Edges": result_conservative.same_as_edges_created,
        "Clusters": result_conservative.duplicate_clusters,
        "Matches": len(result_conservative.node_matches),
    },
    {
        "Config": "Aggressive",
        "Blocking Threshold": 0.75,
        "Matching Threshold": 0.65,
        "SAME_AS Edges": result_aggressive.same_as_edges_created,
        "Clusters": result_aggressive.duplicate_clusters,
        "Matches": len(result_aggressive.node_matches),
    },
])

print("\nConfiguration comparison\n")
print(comparison.to_string(index=False))
# Out:
# Configuration comparison
#
#       Config  Blocking Threshold  Matching Threshold  SAME_AS Edges  Clusters  Matches
#      Default                0.85                0.75             14         2        4
# Conservative                0.90                0.85              0         0        0
#   Aggressive                0.75                0.65              4         2        4

# %% [markdown]
# ## Convenience Function
#
# You can also use the `resolve_entities` convenience function:

# %%
# Create a fresh graph
graph_store_simple = GraphStore("resolution_simple")
load_sample_triples(
    graph_store_simple,
    sample_triples,
    source_name="sample_data_default",
)

# Use convenience function (uses default config)
result_simple = resolve_entities(
    graph_store=graph_store_simple,
    vector_store=vector_store,
    apply_to_nodes=True,
    apply_to_edges=True,
    context=context,
)

print("\nConvenience function results:")
print(f"  SAME_AS edges: {result_simple.same_as_edges_created}")
print(f"  Clusters: {result_simple.duplicate_clusters}")
# Out:
# 2025-11-10T22:05:32.368 [BAML INFO] Function MatchEntities:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 9367ms. StopReason: end_turn. Tokens(in/out): 621/464
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate entities within a group of semantically similar entities.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Entities to analyze:**
#     ---
#     ID: TECHCORP
#     Type: Organization
#     Description: A leading technology company.
#     Attributes: {}
#     ---
#     ID: TECH CORP
#     Type: Organization
#     Description: A technology corporation.
#     Attributes: {}
#     ---
#     ID: TECHCORP INC.
#     Type: Organization
#     Description: Technology company incorporated in Delaware.
#     Attributes: {}
#     ---
#
#     **Task:**
#     Identify which entities in this group are duplicates of each other. Consider:
#
#     1. **Name variations**: "TechCorp", "Tech Corp", "TechCorp Inc." likely refer to the same entity
#     2. **Semantic similarity**: "NYC" and "New York City" are the same
#     3. **Type consistency**: Entities must have compatible types to be duplicates
#     4. **Attribute alignment**: Similar or complementary attributes strengthen a match
#     5. **Description consistency**: Descriptions should be compatible, not contradictory
#
#     **Guidelines:**
#     - Only mark entities as duplicates if you're confident they refer to the same real-world entity
#     - Use "high" confidence for clear matches (obvious name variations, identical descriptions)
#     - Use "medium" confidence for probable matches (semantic similarity, consistent attributes)
#     - Use "low" confidence for possible matches (weak signals, some inconsistency)
#     - Avoid false positives - when in doubt, mark is_duplicate as false
#     - Provide clear reasoning for each match decision
#     - Check for transitive consistency: if A matches B and B matches C, A should match C
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate pairs within this block
#       matches: [
#         {
#           // The unique identifier (name) of the first entity
#           entity1_id: string,
#           // The unique identifier (name) of the second entity
#           entity2_id: string,
#           // Whether these two entities represent the same real-world entity
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation of why these entities are or aren't duplicates, considering name variations, types, descriptions, and attributes
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities have identical names with only a space variation ('TECHCORP' vs 'TECH CORP'). Both are Organizations with very similar descriptions referring to technology companies. The space difference is a common naming variation."
#         },
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities share the same core name 'TECHCORP' with the second having the corporate suffix 'INC.' which is equivalent to the base name per the context guidelines. Both are Organizations describing technology companies. The incorporation detail in the description is complementary information, not contradictory."
#         },
#         {
#           "entity1_id": "TECH CORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "Following transitive consistency from the previous matches, these represent the same entity. 'TECH CORP' (space variation) and 'TECHCORP INC.' (corporate suffix) both refer to the same technology company, with compatible descriptions and identical types."
#         }
#       ],
#       "reasoning": "All three entities represent the same technology company with common naming variations: spacing differences and corporate suffixes. They all have the Organization type, compatible descriptions about technology companies, and no contradictory information. The variations follow standard corporate naming patterns where 'TechCorp', 'Tech Corp', and 'TechCorp Inc.' would typically refer to the same legal entity. The transitive consistency check confirms all three should be considered duplicates of each other."
#     }
#     ```
#     ---Parsed Response (class EntityMatchingResult)---
#     {
#       "matches": [
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities have identical names with only a space variation ('TECHCORP' vs 'TECH CORP'). Both are Organizations with very similar descriptions referring to technology companies. The space difference is a common naming variation."
#         },
#         {
#           "entity1_id": "TECHCORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities share the same core name 'TECHCORP' with the second having the corporate suffix 'INC.' which is equivalent to the base name per the context guidelines. Both are Organizations describing technology companies. The incorporation detail in the description is complementary information, not contradictory."
#         },
#         {
#           "entity1_id": "TECH CORP",
#           "entity2_id": "TECHCORP INC.",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "Following transitive consistency from the previous matches, these represent the same entity. 'TECH CORP' (space variation) and 'TECHCORP INC.' (corporate suffix) both refer to the same technology company, with compatible descriptions and identical types."
#         }
#       ],
#       "reasoning": "All three entities represent the same technology company with common naming variations: spacing differences and corporate suffixes. They all have the Organization type, compatible descriptions about technology companies, and no contradictory information. The variations follow standard corporate naming patterns where 'TechCorp', 'Tech Corp', and 'TechCorp Inc.' would typically refer to the same legal entity. The transitive consistency check confirms all three should be considered duplicates of each other."
#     }
# 2025-11-10T22:05:42.460 [BAML INFO] Function MatchEntities:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 10090ms. StopReason: end_turn. Tokens(in/out): 594/331
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate entities within a group of semantically similar entities.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Entities to analyze:**
#     ---
#     ID: JOHN SMITH
#     Type: Person
#     Description: CEO of TechCorp
#     Attributes: {}
#     ---
#     ID: J. SMITH
#     Type: Person
#     Description: Chief Executive Officer at Tech Corp
#     Attributes: {}
#     ---
#
#     **Task:**
#     Identify which entities in this group are duplicates of each other. Consider:
#
#     1. **Name variations**: "TechCorp", "Tech Corp", "TechCorp Inc." likely refer to the same entity
#     2. **Semantic similarity**: "NYC" and "New York City" are the same
#     3. **Type consistency**: Entities must have compatible types to be duplicates
#     4. **Attribute alignment**: Similar or complementary attributes strengthen a match
#     5. **Description consistency**: Descriptions should be compatible, not contradictory
#
#     **Guidelines:**
#     - Only mark entities as duplicates if you're confident they refer to the same real-world entity
#     - Use "high" confidence for clear matches (obvious name variations, identical descriptions)
#     - Use "medium" confidence for probable matches (semantic similarity, consistent attributes)
#     - Use "low" confidence for possible matches (weak signals, some inconsistency)
#     - Avoid false positives - when in doubt, mark is_duplicate as false
#     - Provide clear reasoning for each match decision
#     - Check for transitive consistency: if A matches B and B matches C, A should match C
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate pairs within this block
#       matches: [
#         {
#           // The unique identifier (name) of the first entity
#           entity1_id: string,
#           // The unique identifier (name) of the second entity
#           entity2_id: string,
#           // Whether these two entities represent the same real-world entity
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation of why these entities are or aren't duplicates, considering name variations, types, descriptions, and attributes
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "entity1_id": "JOHN SMITH",
#           "entity2_id": "J. SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities represent the same person with strong evidence: (1) 'J. SMITH' is a clear abbreviation of 'JOHN SMITH' where 'J.' represents the first name John, (2) Both hold the same executive position - 'CEO' and 'Chief Executive Officer' are equivalent titles, (3) They work at the same company - 'TechCorp' and 'Tech Corp' are name variations of the same entity (space variation), (4) Both are Person type entities, making them compatible for matching. The combination of name abbreviation pattern, identical role, and same company provides overwhelming evidence these refer to the same individual."
#         }
#       ],
#       "reasoning": "I analyzed the two Person entities for potential duplication. The key factors supporting a match were: name abbreviation pattern (J. = John), equivalent job titles (CEO = Chief Executive Officer), and company name variation (TechCorp = Tech Corp). This represents a classic case of the same person being referenced with different levels of formality - one using full name and abbreviated company name, the other using abbreviated personal name and full company name. No contradictory information was found, and all attributes align consistently."
#     }
#     ```
#     ---Parsed Response (class EntityMatchingResult)---
#     {
#       "matches": [
#         {
#           "entity1_id": "JOHN SMITH",
#           "entity2_id": "J. SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These entities represent the same person with strong evidence: (1) 'J. SMITH' is a clear abbreviation of 'JOHN SMITH' where 'J.' represents the first name John, (2) Both hold the same executive position - 'CEO' and 'Chief Executive Officer' are equivalent titles, (3) They work at the same company - 'TechCorp' and 'Tech Corp' are name variations of the same entity (space variation), (4) Both are Person type entities, making them compatible for matching. The combination of name abbreviation pattern, identical role, and same company provides overwhelming evidence these refer to the same individual."
#         }
#       ],
#       "reasoning": "I analyzed the two Person entities for potential duplication. The key factors supporting a match were: name abbreviation pattern (J. = John), equivalent job titles (CEO = Chief Executive Officer), and company name variation (TechCorp = Tech Corp). This represents a classic case of the same person being referenced with different levels of formality - one using full name and abbreviated company name, the other using abbreviated personal name and full company name. No contradictory information was found, and all attributes align consistently."
#     }
# 2025-11-10T22:05:57.104 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 9937ms. StopReason: end_turn. Tokens(in/out): 657/556
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: TECHCORP|HAS_TYPE|COMPANY
#     Triple: TECHCORP -[HAS_TYPE]-> COMPANY
#     Evidence:
#     ---
#     ID: TECH CORP|HAS_TYPE|COMPANY
#     Triple: TECH CORP -[HAS_TYPE]-> COMPANY
#     Evidence:
#     ---
#     ID: TECHCORP INC.|HAS_TYPE|COMPANY
#     Triple: TECHCORP INC. -[HAS_TYPE]-> COMPANY
#     Evidence:
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECH CORP|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "The subjects 'TECHCORP' and 'TECH CORP' are equivalent entities - one is simply the spaced version of the other. Both have identical predicates (HAS_TYPE) and objects (COMPANY), representing the exact same relationship."
#         },
#         {
#           "edge1_id": "TECHCORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECHCORP INC.|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "The subjects 'TECHCORP' and 'TECHCORP INC.' refer to the same entity, as 'Inc.' is just a corporate suffix equivalent to the base company name. Both edges have identical predicates and objects, expressing the same type relationship."
#         },
#         {
#           "edge1_id": "TECH CORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECHCORP INC.|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "The subjects 'TECH CORP' and 'TECHCORP INC.' represent the same entity - 'TECH CORP' is the spaced version and 'TECHCORP INC.' includes the corporate suffix, but both refer to the same company. Identical predicates and objects confirm this is the same relationship."
#         }
#       ],
#       "reasoning": "All three edges describe the same fundamental relationship: that TechCorp is a company. The variations in the subject entity names ('TECHCORP', 'TECH CORP', 'TECHCORP INC.') are standard company name variations - spacing differences and corporate suffixes like 'Inc.' are equivalent according to the context guidelines. Since all predicates (HAS_TYPE) and objects (COMPANY) are identical, and the subjects refer to the same entity with different formatting, all three edges are duplicates of each other with high confidence."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECH CORP|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "The subjects 'TECHCORP' and 'TECH CORP' are equivalent entities - one is simply the spaced version of the other. Both have identical predicates (HAS_TYPE) and objects (COMPANY), representing the exact same relationship."
#         },
#         {
#           "edge1_id": "TECHCORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECHCORP INC.|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "The subjects 'TECHCORP' and 'TECHCORP INC.' refer to the same entity, as 'Inc.' is just a corporate suffix equivalent to the base company name. Both edges have identical predicates and objects, expressing the same type relationship."
#         },
#         {
#           "edge1_id": "TECH CORP|HAS_TYPE|COMPANY",
#           "edge2_id": "TECHCORP INC.|HAS_TYPE|COMPANY",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "The subjects 'TECH CORP' and 'TECHCORP INC.' represent the same entity - 'TECH CORP' is the spaced version and 'TECHCORP INC.' includes the corporate suffix, but both refer to the same company. Identical predicates and objects confirm this is the same relationship."
#         }
#       ],
#       "reasoning": "All three edges describe the same fundamental relationship: that TechCorp is a company. The variations in the subject entity names ('TECHCORP', 'TECH CORP', 'TECHCORP INC.') are standard company name variations - spacing differences and corporate suffixes like 'Inc.' are equivalent according to the context guidelines. Since all predicates (HAS_TYPE) and objects (COMPANY) are identical, and the subjects refer to the same entity with different formatting, all three edges are duplicates of each other with high confidence."
#     }
# 2025-11-10T22:06:04.073 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 6967ms. StopReason: end_turn. Tokens(in/out): 618/343
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: TECHCORP|LOCATED_IN|NEW YORK CITY
#     Triple: TECHCORP -[LOCATED_IN]-> NEW YORK CITY
#     Evidence:
#     ---
#     ID: TECH CORP|LOCATED_IN|NYC
#     Triple: TECH CORP -[LOCATED_IN]-> NYC
#     Evidence:
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|LOCATED_IN|NEW YORK CITY",
#           "edge2_id": "TECH CORP|LOCATED_IN|NYC",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same relationship between equivalent entities. The subjects 'TECHCORP' and 'TECH CORP' are the same company name with minor spacing variation. The predicates are identical (LOCATED_IN). The objects 'NEW YORK CITY' and 'NYC' refer to the same location, as NYC is a well-known abbreviation for New York City. Both edges express the same fact that TechCorp is located in New York City."
#         }
#       ],
#       "reasoning": "I analyzed the two edges for entity equivalence, predicate matching, and semantic similarity. The key factors in identifying these as duplicates were: (1) Subject entities are equivalent - 'TECHCORP' vs 'TECH CORP' represent the same company with minor formatting differences, (2) Predicates are identical - both use 'LOCATED_IN', (3) Object entities are equivalent - 'NEW YORK CITY' and 'NYC' refer to the same geographic location, with NYC being a standard abbreviation. Since both edges express the identical relationship between the same real-world entities, they are clear duplicates with high confidence."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|LOCATED_IN|NEW YORK CITY",
#           "edge2_id": "TECH CORP|LOCATED_IN|NYC",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same relationship between equivalent entities. The subjects 'TECHCORP' and 'TECH CORP' are the same company name with minor spacing variation. The predicates are identical (LOCATED_IN). The objects 'NEW YORK CITY' and 'NYC' refer to the same location, as NYC is a well-known abbreviation for New York City. Both edges express the same fact that TechCorp is located in New York City."
#         }
#       ],
#       "reasoning": "I analyzed the two edges for entity equivalence, predicate matching, and semantic similarity. The key factors in identifying these as duplicates were: (1) Subject entities are equivalent - 'TECHCORP' vs 'TECH CORP' represent the same company with minor formatting differences, (2) Predicates are identical - both use 'LOCATED_IN', (3) Object entities are equivalent - 'NEW YORK CITY' and 'NYC' refer to the same geographic location, with NYC being a standard abbreviation. Since both edges express the identical relationship between the same real-world entities, they are clear duplicates with high confidence."
#     }
# 2025-11-10T22:06:13.637 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 9561ms. StopReason: end_turn. Tokens(in/out): 998/528
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: TECHCORP|SAME_AS|TECH CORP
#     Triple: TECHCORP -[SAME_AS]-> TECH CORP
#     Evidence: 1 source(s): These entities have identical names with only a space variation ('TECHCORP' vs 'TECH CORP'). Both ar...
#     ---
#     ID: TECHCORP|SAME_AS|TECHCORP INC.
#     Triple: TECHCORP -[SAME_AS]-> TECHCORP INC.
#     Evidence: 1 source(s): These entities share the same core name 'TECHCORP' with the second having the corporate suffix 'INC....
#     ---
#     ID: TECH CORP|SAME_AS|TECHCORP
#     Triple: TECH CORP -[SAME_AS]-> TECHCORP
#     Evidence: 1 source(s): These entities have identical names with only a space variation ('TECHCORP' vs 'TECH CORP'). Both ar...
#     ---
#     ID: TECH CORP|SAME_AS|TECHCORP INC.
#     Triple: TECH CORP -[SAME_AS]-> TECHCORP INC.
#     Evidence: 1 source(s): Following transitive consistency from the previous matches, these represent the same entity. 'TECH C...
#     ---
#     ID: TECHCORP INC.|SAME_AS|TECHCORP
#     Triple: TECHCORP INC. -[SAME_AS]-> TECHCORP
#     Evidence: 1 source(s): These entities share the same core name 'TECHCORP' with the second having the corporate suffix 'INC....
#     ---
#     ID: TECHCORP INC.|SAME_AS|TECH CORP
#     Triple: TECHCORP INC. -[SAME_AS]-> TECH CORP
#     Evidence: 1 source(s): Following transitive consistency from the previous matches, these represent the same entity. 'TECH C...
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     Looking at these edges, I can see they all represent SAME_AS relationships between three variations of the same company entity: "TECHCORP", "TECH CORP", and "TECHCORP INC." Since SAME_AS is a symmetric relationship, edges going in opposite directions between the same entities are duplicates.
#
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|SAME_AS|TECH CORP",
#           "edge2_id": "TECH CORP|SAME_AS|TECHCORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same symmetric SAME_AS relationship between identical entities, just in opposite directions. Both have matching evidence about identical names with space variation."
#         },
#         {
#           "edge1_id": "TECHCORP|SAME_AS|TECHCORP INC.",
#           "edge2_id": "TECHCORP INC.|SAME_AS|TECHCORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same symmetric SAME_AS relationship between identical entities in opposite directions. Both have matching evidence about sharing the same core name with corporate suffix variation."
#         },
#         {
#           "edge1_id": "TECH CORP|SAME_AS|TECHCORP INC.",
#           "edge2_id": "TECHCORP INC.|SAME_AS|TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same symmetric SAME_AS relationship between identical entities in opposite directions. Both reference transitive consistency as evidence for the relationship."
#         }
#       ],
#       "reasoning": "All edges use the SAME_AS predicate, which is inherently symmetric - meaning A SAME_AS B is equivalent to B SAME_AS A. The analysis identified three pairs of edges that represent the same relationships in opposite directions between the same entities. Each pair has matching or complementary evidence supporting the same underlying fact about entity equivalence. No contradictory information was found, and all edges describe the same fundamental relationships within this entity resolution cluster."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "TECHCORP|SAME_AS|TECH CORP",
#           "edge2_id": "TECH CORP|SAME_AS|TECHCORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same symmetric SAME_AS relationship between identical entities, just in opposite directions. Both have matching evidence about identical names with space variation."
#         },
#         {
#           "edge1_id": "TECHCORP|SAME_AS|TECHCORP INC.",
#           "edge2_id": "TECHCORP INC.|SAME_AS|TECHCORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same symmetric SAME_AS relationship between identical entities in opposite directions. Both have matching evidence about sharing the same core name with corporate suffix variation."
#         },
#         {
#           "edge1_id": "TECH CORP|SAME_AS|TECHCORP INC.",
#           "edge2_id": "TECHCORP INC.|SAME_AS|TECH CORP",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same symmetric SAME_AS relationship between identical entities in opposite directions. Both reference transitive consistency as evidence for the relationship."
#         }
#       ],
#       "reasoning": "All edges use the SAME_AS predicate, which is inherently symmetric - meaning A SAME_AS B is equivalent to B SAME_AS A. The analysis identified three pairs of edges that represent the same relationships in opposite directions between the same entities. Each pair has matching or complementary evidence supporting the same underlying fact about entity equivalence. No contradictory information was found, and all edges describe the same fundamental relationships within this entity resolution cluster."
#     }
# 2025-11-10T22:06:20.647 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 7008ms. StopReason: end_turn. Tokens(in/out): 610/310
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: NEW YORK CITY|HAS_TYPE|LOCATION
#     Triple: NEW YORK CITY -[HAS_TYPE]-> LOCATION
#     Evidence:
#     ---
#     ID: NYC|HAS_TYPE|LOCATION
#     Triple: NYC -[HAS_TYPE]-> LOCATION
#     Evidence:
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "NEW YORK CITY|HAS_TYPE|LOCATION",
#           "edge2_id": "NYC|HAS_TYPE|LOCATION",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges are duplicates because: 1) The subjects 'NEW YORK CITY' and 'NYC' refer to the same geographical entity (NYC is a well-known abbreviation for New York City as mentioned in the context), 2) Both use identical predicates 'HAS_TYPE', 3) Both have identical objects 'LOCATION', 4) Both express the exact same relationship - that New York City is a location. The only difference is the abbreviated form of the subject entity."
#         }
#       ],
#       "reasoning": "This analysis involved comparing two edges with the same predicate and object but different subject entities. The key consideration was whether 'NEW YORK CITY' and 'NYC' represent the same entity. Given the context explicitly states that abbreviations like 'NYC = New York City' are common in this knowledge graph, these are clearly the same entity. Since both edges express identical typing relationships (entity type classification) using the same predicate and object, they represent duplicate information about the same real-world fact."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "NEW YORK CITY|HAS_TYPE|LOCATION",
#           "edge2_id": "NYC|HAS_TYPE|LOCATION",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges are duplicates because: 1) The subjects 'NEW YORK CITY' and 'NYC' refer to the same geographical entity (NYC is a well-known abbreviation for New York City as mentioned in the context), 2) Both use identical predicates 'HAS_TYPE', 3) Both have identical objects 'LOCATION', 4) Both express the exact same relationship - that New York City is a location. The only difference is the abbreviated form of the subject entity."
#         }
#       ],
#       "reasoning": "This analysis involved comparing two edges with the same predicate and object but different subject entities. The key consideration was whether 'NEW YORK CITY' and 'NYC' represent the same entity. Given the context explicitly states that abbreviations like 'NYC = New York City' are common in this knowledge graph, these are clearly the same entity. Since both edges express identical typing relationships (entity type classification) using the same predicate and object, they represent duplicate information about the same real-world fact."
#     }
# 2025-11-10T22:06:28.985 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 8336ms. StopReason: end_turn. Tokens(in/out): 614/340
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: JOHN SMITH|HAS_TYPE|PERSON
#     Triple: JOHN SMITH -[HAS_TYPE]-> PERSON
#     Evidence:
#     ---
#     ID: J. SMITH|HAS_TYPE|PERSON
#     Triple: J. SMITH -[HAS_TYPE]-> PERSON
#     Evidence:
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "JOHN SMITH|HAS_TYPE|PERSON",
#           "edge2_id": "J. SMITH|HAS_TYPE|PERSON",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges are duplicates because: 1) The subjects 'JOHN SMITH' and 'J. SMITH' represent the same person, with 'J.' being a common abbreviation for 'John' as noted in the context, 2) Both have identical predicates 'HAS_TYPE', 3) Both have identical objects 'PERSON', 4) The relationship direction is the same in both cases. This is a straightforward case of name variation where the abbreviated form 'J. SMITH' refers to the same individual as 'JOHN SMITH'."
#         }
#       ],
#       "reasoning": "This analysis involved comparing two edges that both assert a person's type classification. The key consideration was whether 'JOHN SMITH' and 'J. SMITH' refer to the same entity. Given the context that first name abbreviations like 'J. = John' are common in this knowledge graph, and both edges have identical predicates and objects, these represent the same factual assertion about the same person expressed with different name formats. The high confidence level is justified because this follows a standard abbreviation pattern explicitly mentioned in the context guidelines."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "JOHN SMITH|HAS_TYPE|PERSON",
#           "edge2_id": "J. SMITH|HAS_TYPE|PERSON",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges are duplicates because: 1) The subjects 'JOHN SMITH' and 'J. SMITH' represent the same person, with 'J.' being a common abbreviation for 'John' as noted in the context, 2) Both have identical predicates 'HAS_TYPE', 3) Both have identical objects 'PERSON', 4) The relationship direction is the same in both cases. This is a straightforward case of name variation where the abbreviated form 'J. SMITH' refers to the same individual as 'JOHN SMITH'."
#         }
#       ],
#       "reasoning": "This analysis involved comparing two edges that both assert a person's type classification. The key consideration was whether 'JOHN SMITH' and 'J. SMITH' refer to the same entity. Given the context that first name abbreviations like 'J. = John' are common in this knowledge graph, and both edges have identical predicates and objects, these represent the same factual assertion about the same person expressed with different name formats. The high confidence level is justified because this follows a standard abbreviation pattern explicitly mentioned in the context guidelines."
#     }
# 2025-11-10T22:06:38.066 [BAML INFO] Function MatchEdges:
#     Client: CustomSonnet4 (claude-sonnet-4-20250514) - 9079ms. StopReason: end_turn. Tokens(in/out): 686/331
#     ---PROMPT---
#     user: You are an expert in entity resolution for knowledge graphs. Your task is to identify duplicate edges (relationships) within a group of semantically similar edges.**Context about this knowledge graph:**
#
#     This is a knowledge graph about technology companies and people.
#     Common variations:
#     - Corp, Corporation, Inc., LLC are equivalent suffixes
#     - Abbreviations like NYC = New York City are common
#     - First name abbreviations (J. = John) are common
#
#
#     **Edges to analyze:**
#     ---
#     ID: JOHN SMITH|SAME_AS|J. SMITH
#     Triple: JOHN SMITH -[SAME_AS]-> J. SMITH
#     Evidence: 1 source(s): These entities represent the same person with strong evidence: (1) 'J. SMITH' is a clear abbreviatio...
#     ---
#     ID: J. SMITH|SAME_AS|JOHN SMITH
#     Triple: J. SMITH -[SAME_AS]-> JOHN SMITH
#     Evidence: 1 source(s): These entities represent the same person with strong evidence: (1) 'J. SMITH' is a clear abbreviatio...
#     ---
#
#     **Task:**
#     Identify which edges in this group are duplicates of each other. Consider:
#
#     1. **Entity equivalence**: Subject and object entities should be the same or known duplicates
#     2. **Predicate equivalence**: Predicates should express the same relationship (e.g., "works_at" vs "employed_by")
#     3. **Evidence overlap**: Duplicates often cite the same or overlapping source text
#     4. **Direction consistency**: Ensure relationship direction is the same
#     5. **Temporal consistency**: Check if edges describe the same timeframe
#
#     **Guidelines:**
#     - Only mark edges as duplicates if they represent the same relationship between the same entities
#     - Use "high" confidence for edges with identical subjects, predicates, objects
#     - Use "medium" confidence for edges with equivalent predicates and matching entities
#     - Use "low" confidence for edges with similar but not identical structure
#     - Edges with contradictory information (different dates, different evidence) are NOT duplicates
#     - Provide clear reasoning for each match decision
#     - Consider that edges from different sources can still be duplicates if they express the same fact
#
#     Answer in JSON using this schema:
#     {
#       // List of identified duplicate edge pairs within this block
#       matches: [
#         {
#           // Identifier for first edge in format 'subject|predicate|object'
#           edge1_id: string,
#           // Identifier for second edge in format 'subject|predicate|object'
#           edge2_id: string,
#           // Whether these edges represent the same relationship
#           is_duplicate: bool,
#           // Confidence in the match decision: 'high', 'medium', or 'low'
#           confidence_level: string,
#           // Detailed explanation considering subject/object similarity, predicate equivalence, and evidence overlap
#           reasoning: string,
#         }
#       ],
#       // Overall reasoning about the matching process and decisions made
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "matches": [
#         {
#           "edge1_id": "JOHN SMITH|SAME_AS|J. SMITH",
#           "edge2_id": "J. SMITH|SAME_AS|JOHN SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same identity relationship but in opposite directions. Both edges connect the same two entities (JOHN SMITH and J. SMITH) with the SAME_AS predicate, which is inherently bidirectional. The evidence for both edges is nearly identical, both referencing that 'J. SMITH' is a clear abbreviation of 'JOHN SMITH'. Since SAME_AS relationships are symmetric by nature, these represent the same factual assertion about entity equivalence."
#         }
#       ],
#       "reasoning": "This analysis involves two edges that establish a SAME_AS relationship between 'JOHN SMITH' and 'J. SMITH'. The key insight is that SAME_AS is a symmetric relationship - if A is the same as B, then B is the same as A. Both edges have virtually identical evidence citing the abbreviation pattern, and they connect the same pair of entities. The only difference is the directional representation (A->B vs B->A), but since this represents identity equivalence, both directions express the same underlying fact. Therefore, these are duplicates with high confidence."
#     }
#     ```
#     ---Parsed Response (class EdgeMatchingResult)---
#     {
#       "matches": [
#         {
#           "edge1_id": "JOHN SMITH|SAME_AS|J. SMITH",
#           "edge2_id": "J. SMITH|SAME_AS|JOHN SMITH",
#           "is_duplicate": true,
#           "confidence_level": "high",
#           "reasoning": "These edges represent the same identity relationship but in opposite directions. Both edges connect the same two entities (JOHN SMITH and J. SMITH) with the SAME_AS predicate, which is inherently bidirectional. The evidence for both edges is nearly identical, both referencing that 'J. SMITH' is a clear abbreviation of 'JOHN SMITH'. Since SAME_AS relationships are symmetric by nature, these represent the same factual assertion about entity equivalence."
#         }
#       ],
#       "reasoning": "This analysis involves two edges that establish a SAME_AS relationship between 'JOHN SMITH' and 'J. SMITH'. The key insight is that SAME_AS is a symmetric relationship - if A is the same as B, then B is the same as A. Both edges have virtually identical evidence citing the abbreviation pattern, and they connect the same pair of entities. The only difference is the directional representation (A->B vs B->A), but since this represents identity equivalence, both directions express the same underlying fact. Therefore, these are duplicates with high confidence."
#     }
#
# Convenience function results:
#   SAME_AS edges: 14
#   Clusters: 2

# %% [markdown]
# ## Best Practices & Troubleshooting
#
# ### Configuration Guidelines
#
# **Conservative (high precision)**
# - blocking_threshold=0.90
# - matching_threshold=0.85
# - min_cluster_size=3
# - Use when false positives are costly
#
# **Aggressive (high recall)**
# - blocking_threshold=0.75
# - matching_threshold=0.65
# - min_cluster_size=2
# - Use when missing duplicates is costly
#
# **Balanced (default)**
# - Uses ResolutionConfig() defaults
# - Good starting point for most use cases
#
# ### Common Issues
#
# **No matches found**
# - Lower blocking_threshold to 0.75–0.80
# - Lower matching_threshold to 0.70
# - Check embeddings are working
# - Verify entities actually have duplicates
#
# **Too many false positives**
# - Raise matching_threshold to 0.85–0.90
# - Raise blocking_threshold to 0.90+
# - Improve context with domain information
# - Check entity descriptions for quality
#
# **LLM errors**
# - Verify ANTHROPIC_API_KEY is set
# - Reduce batch_size to avoid rate limits
# - Check for malformed entity data

# %% [markdown]
# ## Next Steps
#
# - **Larger datasets**: Try resolution on a knowledge graph with 100+ entities
# - **Custom clustering**: Experiment with HDBSCAN for variable cluster sizes
# - **Edge resolution**: Focus on duplicate edge detection
# - **Integrations**: Use resolved graphs in downstream applications
# - **Monitoring**: Track resolution quality metrics over time

# %% [markdown]
# ## References
#
# - [Entity Resolution Documentation](../../docs/ENTITY_RESOLUTION.md)
# - [Demo Script](../../demos/example_entity_resolution.py)
# - [Tests](../../tests/test_entity_resolution.py)
# - [The Rise of Semantic Entity Resolution](https://towardsdatascience.com/the-rise-of-semantic-entity-resolution/)
