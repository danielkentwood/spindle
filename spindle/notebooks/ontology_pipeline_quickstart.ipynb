# %% [markdown]
# # Ontology Pipeline Quick Start
#
# This notebook demonstrates how to use the Ontology Pipeline to build semantic knowledge systems from a corpus of documents.
#
# The pipeline consists of six stages:
# 1. **Controlled Vocabulary** - Extract and define key terms
# 2. **Metadata Standards** - Define metadata schema
# 3. **Taxonomy** - Build hierarchical structure
# 4. **Thesaurus** - Add semantic relationships (BT, NT, RT)
# 5. **Ontology** - Generate entity and relation types
# 6. **Knowledge Graph** - Extract triples and build queryable graph

# %% [markdown]
# ## Setup

# %%
# Import required modules
from pathlib import Path

from spindle.graph_store import GraphStore
from spindle.ingestion.storage import DocumentCatalog
from spindle.ingestion.storage.corpus import CorpusManager
from spindle.pipeline import (
    PipelineOrchestrator,
    PipelineStage,
    ExtractionStrategyType,
)

# %%
# Run this to clean up first
import os
import shutil
if os.path.exists("pipeline_demo.db"):
    os.remove("pipeline_demo.db")
if os.path.exists("pipeline_demo_graph"):
    shutil.rmtree("pipeline_demo_graph")

# %%
# Initialize storage components
catalog = DocumentCatalog("sqlite:///pipeline_demo.db")
corpus_manager = CorpusManager(catalog)
graph_store = GraphStore("pipeline_demo_graph")

# Create the pipeline orchestrator
orchestrator = PipelineOrchestrator(corpus_manager, graph_store)
orchestrator.register_default_stages()

print("Pipeline orchestrator initialized with all stages")
# Out:
# Pipeline orchestrator initialized with all stages

# %% [markdown]
# ## Step 1: Create a Corpus
#
# A corpus is a collection of documents that will be processed through the Ontology Pipeline.

# %%
# Create a corpus for our documents
corpus = corpus_manager.create_corpus(
    name="Demo Corpus",
    description="Sample documents for demonstrating the Ontology Pipeline",
)

print(f"Created corpus: {corpus.corpus_id}")
print(f"Name: {corpus.name}")
# Out:
# Created corpus: 40480027-952b-48d7-8c05-ac924e0f6671
# Name: Demo Corpus

# %% [markdown]
# ## Step 2: Add Sample Documents
#
# For this demo, we'll simulate documents by directly inserting sample text.
# In production, you'd first ingest documents using `spindle-ingest`.

# %%
# Sample documents about AI and machine learning
sample_texts = [
    """
    Machine learning is a subset of artificial intelligence that enables computers 
    to learn from data without being explicitly programmed. Deep learning, a further 
    subset, uses neural networks with multiple layers to model complex patterns.
    
    Supervised learning algorithms learn from labeled training data to make predictions.
    Common examples include classification and regression tasks. In contrast, 
    unsupervised learning finds patterns in unlabeled data, such as clustering.
    
    TensorFlow and PyTorch are popular deep learning frameworks used by researchers
    and practitioners worldwide. Google developed TensorFlow while Meta created PyTorch.
    """,
    """
    Natural language processing (NLP) is a field of AI focused on the interaction
    between computers and human language. Transformer models have revolutionized NLP,
    enabling breakthrough applications like GPT and BERT.
    
    Large language models (LLMs) are trained on massive text datasets and can
    generate human-like text, answer questions, and perform various language tasks.
    
    OpenAI developed GPT-4, while Google created PaLM and Gemini. These models
    use attention mechanisms to process sequential data effectively.
    """,
    """
    Computer vision enables machines to interpret and understand visual information
    from images and videos. Convolutional neural networks (CNNs) are fundamental
    to many computer vision applications.
    
    Object detection, image classification, and semantic segmentation are key
    computer vision tasks. YOLO and ResNet are influential architectures in this field.
    
    Applications include autonomous vehicles, medical imaging, and facial recognition.
    """
]

print(f"Prepared {len(sample_texts)} sample documents")
# Out:
# Prepared 3 sample documents

# %%
# For demo purposes, we'll manually create chunk artifacts
# In production, use spindle-ingest to properly ingest documents

from datetime import datetime
import uuid

from sqlalchemy.orm import Session
from spindle.ingestion.storage.catalog import ChunkRow, DocumentRow

# First, create document and chunk records
doc_ids = []
with catalog.session() as session:
    for i, text in enumerate(sample_texts):
        doc_id = f"demo_doc_{i}"
        chunk_id = f"demo_chunk_{i}"
        doc_ids.append(doc_id)
        
        # Create document record
        session.merge(DocumentRow(
            document_id=doc_id,
            source_path=f"sample_{i}.txt",
            checksum=str(hash(text)),
            loader_name="demo",
            template_name="default",
            metadata_={"title": f"Sample Document {i}"},
            created_at=datetime.utcnow(),
            bytes_read=len(text),
        ))
        
        # Create chunk record
        session.merge(ChunkRow(
            chunk_id=chunk_id,
            document_id=doc_id,
            text=text.strip(),
            metadata_={"index": i},
        ))

# Then add documents to corpus (outside the session to avoid lock)
corpus_manager.add_documents(corpus.corpus_id, doc_ids)

print(f"Added {len(sample_texts)} documents to corpus")
print(f"Document count: {corpus_manager.get_corpus_document_count(corpus.corpus_id)}")
# Out:
# Added 3 documents to corpus
# Document count: 3

# %% [markdown]
# ## Step 3: Run the Pipeline
#
# We can run stages individually or all at once.

# %%
# Run all pipeline stages
print("Running all pipeline stages...\n")

results = orchestrator.run_all(
    corpus,
    strategy_type=ExtractionStrategyType.SEQUENTIAL,
    stop_on_error=True,
)

for result in results:
    icon = "✓" if result.success else "✗"
    print(f"{icon} {result.stage.value}: ", end="")
    if result.success:
        print(f"{result.artifact_count} artifacts")
    else:
        print(f"FAILED - {result.error_message}")
# Out:
# Running all pipeline stages...
#
# 2025-11-27T23:29:48.965 [BAML INFO] Function ExtractControlledVocabulary:
#     Client: CustomGPT5Mini (gpt-5-mini-2025-08-07) - 38489ms. StopReason: completed. Tokens(in/out): 604/2634
#     ---PROMPT---
#     system: You are a knowledge organization expert specializing in controlled vocabulary development.
#     Your task is to extract key terms from the text and create clean, disambiguated vocabulary entries.
#     user: TEXT TO ANALYZE:
#     Machine learning is a subset of artificial intelligence that enables computers
#         to learn from data without being explicitly programmed. Deep learning, a further
#         subset, uses neural networks with multiple layers to model complex patterns.
#
#         Supervised learning algorithms learn from labeled training data to make predictions.
#         Common examples include classification and regression tasks. In contrast,
#         unsupervised learning finds patterns in unlabeled data, such as clustering.
#
#         TensorFlow and PyTorch are popular deep learning frameworks used by researchers
#         and practitioners worldwide. Google developed TensorFlow while Meta created PyTorch.
#
#     DOCUMENT ID: demo_doc_0
#
#
#     CONTROLLED VOCABULARY PRINCIPLES:
#
#     1. **Term Selection**: Identify key concepts, entities, and domain-specific terms
#        - Focus on nouns and noun phrases
#        - Include technical/domain terms that need definition
#        - Skip common words that don't need clarification
#
#     2. **Preferred Label**: Choose the most standard/canonical form
#        - Use singular form for countable nouns
#        - Use the most commonly accepted spelling
#        - Prefer full terms over abbreviations (but list abbreviations as synonyms)
#
#     3. **Definition**: Write clear, concise definitions
#        - Start with the category: "A [category] that..."
#        - Include distinguishing characteristics
#        - Keep to 1-2 sentences
#
#     4. **Synonyms**: List alternative forms
#        - Abbreviations and acronyms
#        - Variant spellings
#        - Related terms that are used interchangeably in this context
#
#     5. **Domain**: Identify the subject area
#        - Be specific but not overly narrow
#        - Examples: "healthcare", "finance", "technology", "legal"
#
#     DEDUPLICATION:
#     - If a concept already exists in the existing vocabulary, do NOT create a duplicate
#     - Instead, you may suggest additional synonyms in your reasoning
#     - Generate unique term_ids using format: "term_[document_id]_[index]"
#
#     Answer in JSON using this schema:
#     {
#       // Extracted vocabulary terms with definitions
#       terms: [
#         {
#           // Unique identifier for this term
#           term_id: string,
#           // The canonical/preferred form of this term
#           preferred_label: string,
#           // Clear definition explaining what this term means in context
#           definition: string,
#           // Alternative terms or phrases that mean the same thing
#           synonyms: string[],
#           // The subject domain this term belongs to (e.g., 'medical', 'legal', 'technology')
#           domain: string or null,
#         }
#       ],
#       // Brief summary of the domains/topics covered in the text
#       domain_summary: string,
#       // Explanation of term selection and definition choices
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     {
#       "terms": [
#         {
#           "term_id": "term_demo_doc_0_1",
#           "preferred_label": "machine learning",
#           "definition": "A subfield of artificial intelligence that enables computers to improve performance on tasks by learning patterns from data rather than following explicit programmed rules.",
#           "synonyms": [
#             "ML"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_2",
#           "preferred_label": "artificial intelligence",
#           "definition": "A broad field of computer science that focuses on creating systems capable of performing tasks that normally require human intelligence.",
#           "synonyms": [
#             "AI"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_3",
#           "preferred_label": "deep learning",
#           "definition": "A subset of machine learning that uses neural networks with multiple layers to automatically learn hierarchical representations of data.",
#           "synonyms": [
#             "DL"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_4",
#           "preferred_label": "neural network",
#           "definition": "A computational model that consists of interconnected layers of simple processing units (neurons) which can be trained to recognize patterns from data.",
#           "synonyms": [
#             "neural networks",
#             "NN"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_5",
#           "preferred_label": "supervised learning",
#           "definition": "A category of machine learning that trains models using labeled examples so they can make predictions on new inputs.",
#           "synonyms": [
#             "supervised machine learning"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_6",
#           "preferred_label": "labeled training data",
#           "definition": "A dataset used for training supervised learning models in which each input instance is paired with a correct output label.",
#           "synonyms": [
#             "labeled data",
#             "training data (labeled)"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_7",
#           "preferred_label": "unsupervised learning",
#           "definition": "A category of machine learning that discovers structure or patterns in data that have no associated target labels.",
#           "synonyms": [
#             "unsupervised machine learning"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_8",
#           "preferred_label": "unlabeled data",
#           "definition": "Data that lacks target labels or annotations and is typically used in unsupervised learning to find underlying structure.",
#           "synonyms": [
#             "unlabeled dataset",
#             "unlabelled data"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_9",
#           "preferred_label": "classification",
#           "definition": "A supervised learning task that assigns discrete category labels to input instances based on learned patterns.",
#           "synonyms": [
#             "classification task"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_10",
#           "preferred_label": "regression",
#           "definition": "A supervised learning task that predicts continuous numeric values for input instances.",
#           "synonyms": [
#             "regression task"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_11",
#           "preferred_label": "clustering",
#           "definition": "An unsupervised learning method that groups similar data instances into clusters based on feature similarity.",
#           "synonyms": [
#             "cluster analysis",
#             "clustering task"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_12",
#           "preferred_label": "TensorFlow",
#           "definition": "A deep learning framework for building and training neural network models, developed and maintained by Google.",
#           "synonyms": [
#             "TensorFlow (library)",
#             "TF"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_0_13",
#           "preferred_label": "PyTorch",
#           "definition": "A deep learning framework and scientific computing library for building neural network models, developed and maintained by Meta.",
#           "synonyms": [
#             "PyTorch (library)",
#             "torch (informal)"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_0_14",
#           "preferred_label": "Google",
#           "definition": "A multinational technology company that develops products and tools for internet services and machine learning, including TensorFlow.",
#           "synonyms": [
#             "Google LLC"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_0_15",
#           "preferred_label": "Meta",
#           "definition": "A multinational technology company (formerly Facebook, Inc.) involved in social media and research, and the creator/maintainer of PyTorch.",
#           "synonyms": [
#             "Meta Platforms",
#             "Facebook (former name)"
#           ],
#           "domain": "technology"
#         }
#       ],
#       "domain_summary": "Technology (artificial intelligence): concepts and tools related to machine learning and deep learning, including learning paradigms (supervised, unsupervised), tasks (classification, regression, clustering), data types (labeled/unlabeled training data), neural network models, and popular frameworks (TensorFlow, PyTorch).",
#       "reasoning": "Term selection focused on nouns and domain-specific phrases present in the source text: core concepts (machine learning, artificial intelligence, deep learning), model types (neural network), learning paradigms and data types (supervised learning, unsupervised learning, labeled training data, unlabeled data), common tasks (classification, regression, clustering), and tooling/actors (TensorFlow, PyTorch, Google, Meta). Preferred labels use canonical singular forms and commonly accepted spellings; abbreviations (e.g., ML, AI, DL, NN, TF) and common variant forms are included in synonyms. Definitions follow the guideline to start with a category phrase ('A ... that') and provide 1–2 concise sentences emphasizing distinguishing characteristics and context. Company entries are included because the text attributes framework authorship to them. No deduplication against an external vocabulary was performed here; if a term already exists in an existing vocabulary, the suggested synonyms list can be used to map this preferred label to the existing concept."
#     }
#     ---Parsed Response (class VocabularyExtractionResult)---
#     {
#       "terms": [
#         {
#           "term_id": "term_demo_doc_0_1",
#           "preferred_label": "machine learning",
#           "definition": "A subfield of artificial intelligence that enables computers to improve performance on tasks by learning patterns from data rather than following explicit programmed rules.",
#           "synonyms": [
#             "ML"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_2",
#           "preferred_label": "artificial intelligence",
#           "definition": "A broad field of computer science that focuses on creating systems capable of performing tasks that normally require human intelligence.",
#           "synonyms": [
#             "AI"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_3",
#           "preferred_label": "deep learning",
#           "definition": "A subset of machine learning that uses neural networks with multiple layers to automatically learn hierarchical representations of data.",
#           "synonyms": [
#             "DL"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_4",
#           "preferred_label": "neural network",
#           "definition": "A computational model that consists of interconnected layers of simple processing units (neurons) which can be trained to recognize patterns from data.",
#           "synonyms": [
#             "neural networks",
#             "NN"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_5",
#           "preferred_label": "supervised learning",
#           "definition": "A category of machine learning that trains models using labeled examples so they can make predictions on new inputs.",
#           "synonyms": [
#             "supervised machine learning"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_6",
#           "preferred_label": "labeled training data",
#           "definition": "A dataset used for training supervised learning models in which each input instance is paired with a correct output label.",
#           "synonyms": [
#             "labeled data",
#             "training data (labeled)"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_7",
#           "preferred_label": "unsupervised learning",
#           "definition": "A category of machine learning that discovers structure or patterns in data that have no associated target labels.",
#           "synonyms": [
#             "unsupervised machine learning"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_8",
#           "preferred_label": "unlabeled data",
#           "definition": "Data that lacks target labels or annotations and is typically used in unsupervised learning to find underlying structure.",
#           "synonyms": [
#             "unlabeled dataset",
#             "unlabelled data"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_9",
#           "preferred_label": "classification",
#           "definition": "A supervised learning task that assigns discrete category labels to input instances based on learned patterns.",
#           "synonyms": [
#             "classification task"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_10",
#           "preferred_label": "regression",
#           "definition": "A supervised learning task that predicts continuous numeric values for input instances.",
#           "synonyms": [
#             "regression task"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_11",
#           "preferred_label": "clustering",
#           "definition": "An unsupervised learning method that groups similar data instances into clusters based on feature similarity.",
#           "synonyms": [
#             "cluster analysis",
#             "clustering task"
#           ],
#           "domain": "technology (artificial intelligence)"
#         },
#         {
#           "term_id": "term_demo_doc_0_12",
#           "preferred_label": "TensorFlow",
#           "definition": "A deep learning framework for building and training neural network models, developed and maintained by Google.",
#           "synonyms": [
#             "TensorFlow (library)",
#             "TF"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_0_13",
#           "preferred_label": "PyTorch",
#           "definition": "A deep learning framework and scientific computing library for building neural network models, developed and maintained by Meta.",
#           "synonyms": [
#             "PyTorch (library)",
#             "torch (informal)"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_0_14",
#           "preferred_label": "Google",
#           "definition": "A multinational technology company that develops products and tools for internet services and machine learning, including TensorFlow.",
#           "synonyms": [
#             "Google LLC"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_0_15",
#           "preferred_label": "Meta",
#           "definition": "A multinational technology company (formerly Facebook, Inc.) involved in social media and research, and the creator/maintainer of PyTorch.",
#           "synonyms": [
#             "Meta Platforms",
#             "Facebook (former name)"
#           ],
#           "domain": "technology"
#         }
#       ],
#       "domain_summary": "Technology (artificial intelligence): concepts and tools related to machine learning and deep learning, including learning paradigms (supervised, unsupervised), tasks (classification, regression, clustering), data types (labeled/unlabeled training data), neural network models, and popular frameworks (TensorFlow, PyTorch).",
#       "reasoning": "Term selection focused on nouns and domain-specific phrases present in the source text: core concepts (machine learning, artificial intelligence, deep learning), model types (neural network), learning paradigms and data types (supervised learning, unsupervised learning, labeled training data, unlabeled data), common tasks (classification, regression, clustering), and tooling/actors (TensorFlow, PyTorch, Google, Meta). Preferred labels use canonical singular forms and commonly accepted spellings; abbreviations (e.g., ML, AI, DL, NN, TF) and common variant forms are included in synonyms. Definitions follow the guideline to start with a category phrase ('A ... that') and provide 1–2 concise sentences emphasizing distinguishing characteristics and context. Company entries are included because the text attributes framework authorship to them. No deduplication against an external vocabulary was performed here; if a term already exists in an existing vocabulary, the suggested synonyms list can be used to map this preferred label to the existing concept."
#     }
# 2025-11-27T23:29:56.330 [BAML INFO] Function ExtractControlledVocabulary:
#     Client: CustomHaiku (claude-3-5-haiku-20241022) - 7359ms. StopReason: end_turn. Tokens(in/out): 1277/440
#     ---PROMPT---
#     user: You are a knowledge organization expert specializing in controlled vocabulary development.
#     Your task is to extract key terms from the text and create clean, disambiguated vocabulary entries.TEXT TO ANALYZE:
#     Natural language processing (NLP) is a field of AI focused on the interaction
#         between computers and human language. Transformer models have revolutionized NLP,
#         enabling breakthrough applications like GPT and BERT.
#
#         Large language models (LLMs) are trained on massive text datasets and can
#         generate human-like text, answer questions, and perform various language tasks.
#
#         OpenAI developed GPT-4, while Google created PaLM and Gemini. These models
#         use attention mechanisms to process sequential data effectively.
#
#     DOCUMENT ID: demo_doc_1
#
#     EXISTING VOCABULARY:
#     The following terms have already been extracted. You should:
#     1. Use consistent naming - if a term exists, use the SAME preferred_label
#     2. Add new synonyms to existing terms rather than creating duplicates
#     3. Only create new terms for genuinely different concepts
#
#     - machine learning: A subfield of artificial intelligence that enables computers to improve performance on tasks by learning patterns from data rather than following explicit programmed rules.
#       Synonyms: ML
#     - artificial intelligence: A broad field of computer science that focuses on creating systems capable of performing tasks that normally require human intelligence.
#       Synonyms: AI
#     - deep learning: A subset of machine learning that uses neural networks with multiple layers to automatically learn hierarchical representations of data.
#       Synonyms: DL
#     - neural network: A computational model that consists of interconnected layers of simple processing units (neurons) which can be trained to recognize patterns from data.
#       Synonyms: neural networks, NN
#     - supervised learning: A category of machine learning that trains models using labeled examples so they can make predictions on new inputs.
#       Synonyms: supervised machine learning
#     - labeled training data: A dataset used for training supervised learning models in which each input instance is paired with a correct output label.
#       Synonyms: labeled data, training data (labeled)
#     - unsupervised learning: A category of machine learning that discovers structure or patterns in data that have no associated target labels.
#       Synonyms: unsupervised machine learning
#     - unlabeled data: Data that lacks target labels or annotations and is typically used in unsupervised learning to find underlying structure.
#       Synonyms: unlabeled dataset, unlabelled data
#     - classification: A supervised learning task that assigns discrete category labels to input instances based on learned patterns.
#       Synonyms: classification task
#     - regression: A supervised learning task that predicts continuous numeric values for input instances.
#       Synonyms: regression task
#     - clustering: An unsupervised learning method that groups similar data instances into clusters based on feature similarity.
#       Synonyms: cluster analysis, clustering task
#     - TensorFlow: A deep learning framework for building and training neural network models, developed and maintained by Google.
#       Synonyms: TensorFlow (library), TF
#     - PyTorch: A deep learning framework and scientific computing library for building neural network models, developed and maintained by Meta.
#       Synonyms: PyTorch (library), torch (informal)
#     - Google: A multinational technology company that develops products and tools for internet services and machine learning, including TensorFlow.
#       Synonyms: Google LLC
#     - Meta: A multinational technology company (formerly Facebook, Inc.) involved in social media and research, and the creator/maintainer of PyTorch.
#       Synonyms: Meta Platforms, Facebook (former name)
#
#     CONTROLLED VOCABULARY PRINCIPLES:
#
#     1. **Term Selection**: Identify key concepts, entities, and domain-specific terms
#        - Focus on nouns and noun phrases
#        - Include technical/domain terms that need definition
#        - Skip common words that don't need clarification
#
#     2. **Preferred Label**: Choose the most standard/canonical form
#        - Use singular form for countable nouns
#        - Use the most commonly accepted spelling
#        - Prefer full terms over abbreviations (but list abbreviations as synonyms)
#
#     3. **Definition**: Write clear, concise definitions
#        - Start with the category: "A [category] that..."
#        - Include distinguishing characteristics
#        - Keep to 1-2 sentences
#
#     4. **Synonyms**: List alternative forms
#        - Abbreviations and acronyms
#        - Variant spellings
#        - Related terms that are used interchangeably in this context
#
#     5. **Domain**: Identify the subject area
#        - Be specific but not overly narrow
#        - Examples: "healthcare", "finance", "technology", "legal"
#
#     DEDUPLICATION:
#     - If a concept already exists in the existing vocabulary, do NOT create a duplicate
#     - Instead, you may suggest additional synonyms in your reasoning
#     - Generate unique term_ids using format: "term_[document_id]_[index]"
#
#     Answer in JSON using this schema:
#     {
#       // Extracted vocabulary terms with definitions
#       terms: [
#         {
#           // Unique identifier for this term
#           term_id: string,
#           // The canonical/preferred form of this term
#           preferred_label: string,
#           // Clear definition explaining what this term means in context
#           definition: string,
#           // Alternative terms or phrases that mean the same thing
#           synonyms: string[],
#           // The subject domain this term belongs to (e.g., 'medical', 'legal', 'technology')
#           domain: string or null,
#         }
#       ],
#       // Brief summary of the domains/topics covered in the text
#       domain_summary: string,
#       // Explanation of term selection and definition choices
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     {
#         "terms": [
#             {
#                 "term_id": "term_demo_doc_1_1",
#                 "preferred_label": "natural language processing",
#                 "definition": "A subfield of artificial intelligence focused on enabling computers to understand, interpret, and generate human language through computational techniques.",
#                 "synonyms": ["NLP"],
#                 "domain": "artificial intelligence"
#             },
#             {
#                 "term_id": "term_demo_doc_1_2",
#                 "preferred_label": "transformer model",
#                 "definition": "A type of neural network architecture that uses attention mechanisms to process sequential data, enabling advanced language understanding and generation.",
#                 "synonyms": ["transformer neural network"],
#                 "domain": "machine learning"
#             },
#             {
#                 "term_id": "term_demo_doc_1_3",
#                 "preferred_label": "large language model",
#                 "definition": "An advanced AI model trained on extensive text datasets that can generate human-like text, answer questions, and perform various language-related tasks.",
#                 "synonyms": ["LLM", "large neural language model"],
#                 "domain": "artificial intelligence"
#             },
#             {
#                 "term_id": "term_demo_doc_1_4",
#                 "preferred_label": "attention mechanism",
#                 "definition": "A neural network technique that allows models to dynamically focus on different parts of input data when processing sequential information.",
#                 "synonyms": [],
#                 "domain": "machine learning"
#             }
#         ],
#         "domain_summary": "Artificial Intelligence, Natural Language Processing, Machine Learning",
#         "reasoning": "Terms were selected based on their technical specificity and importance in the context of AI and language models. Definitions aim to capture the core functionality and distinguishing characteristics of each concept. Synonyms were added to provide alternative references, and existing vocabulary was consulted to prevent duplication."
#     }
#     ---Parsed Response (class VocabularyExtractionResult)---
#     {
#       "terms": [
#         {
#           "term_id": "term_demo_doc_1_1",
#           "preferred_label": "natural language processing",
#           "definition": "A subfield of artificial intelligence focused on enabling computers to understand, interpret, and generate human language through computational techniques.",
#           "synonyms": [
#             "NLP"
#           ],
#           "domain": "artificial intelligence"
#         },
#         {
#           "term_id": "term_demo_doc_1_2",
#           "preferred_label": "transformer model",
#           "definition": "A type of neural network architecture that uses attention mechanisms to process sequential data, enabling advanced language understanding and generation.",
#           "synonyms": [
#             "transformer neural network"
#           ],
#           "domain": "machine learning"
#         },
#         {
#           "term_id": "term_demo_doc_1_3",
#           "preferred_label": "large language model",
#           "definition": "An advanced AI model trained on extensive text datasets that can generate human-like text, answer questions, and perform various language-related tasks.",
#           "synonyms": [
#             "LLM",
#             "large neural language model"
#           ],
#           "domain": "artificial intelligence"
#         },
#         {
#           "term_id": "term_demo_doc_1_4",
#           "preferred_label": "attention mechanism",
#           "definition": "A neural network technique that allows models to dynamically focus on different parts of input data when processing sequential information.",
#           "synonyms": [],
#           "domain": "machine learning"
#         }
#       ],
#       "domain_summary": "Artificial Intelligence, Natural Language Processing, Machine Learning",
#       "reasoning": "Terms were selected based on their technical specificity and importance in the context of AI and language models. Definitions aim to capture the core functionality and distinguishing characteristics of each concept. Synonyms were added to provide alternative references, and existing vocabulary was consulted to prevent duplication."
#     }
# 2025-11-27T23:30:29.502 [BAML INFO] Function ExtractControlledVocabulary:
#     Client: CustomGPT5Mini (gpt-5-mini-2025-08-07) - 33155ms. StopReason: completed. Tokens(in/out): 1274/2094
#     ---PROMPT---
#     system: You are a knowledge organization expert specializing in controlled vocabulary development.
#     Your task is to extract key terms from the text and create clean, disambiguated vocabulary entries.
#     user: TEXT TO ANALYZE:
#     Computer vision enables machines to interpret and understand visual information
#         from images and videos. Convolutional neural networks (CNNs) are fundamental
#         to many computer vision applications.
#
#         Object detection, image classification, and semantic segmentation are key
#         computer vision tasks. YOLO and ResNet are influential architectures in this field.
#
#         Applications include autonomous vehicles, medical imaging, and facial recognition.
#
#     DOCUMENT ID: demo_doc_2
#
#     EXISTING VOCABULARY:
#     The following terms have already been extracted. You should:
#     1. Use consistent naming - if a term exists, use the SAME preferred_label
#     2. Add new synonyms to existing terms rather than creating duplicates
#     3. Only create new terms for genuinely different concepts
#
#     - machine learning: A subfield of artificial intelligence that enables computers to improve performance on tasks by learning patterns from data rather than following explicit programmed rules.
#       Synonyms: ML
#     - artificial intelligence: A broad field of computer science that focuses on creating systems capable of performing tasks that normally require human intelligence.
#       Synonyms: AI
#     - deep learning: A subset of machine learning that uses neural networks with multiple layers to automatically learn hierarchical representations of data.
#       Synonyms: DL
#     - neural network: A computational model that consists of interconnected layers of simple processing units (neurons) which can be trained to recognize patterns from data.
#       Synonyms: neural networks, NN
#     - supervised learning: A category of machine learning that trains models using labeled examples so they can make predictions on new inputs.
#       Synonyms: supervised machine learning
#     - labeled training data: A dataset used for training supervised learning models in which each input instance is paired with a correct output label.
#       Synonyms: labeled data, training data (labeled)
#     - unsupervised learning: A category of machine learning that discovers structure or patterns in data that have no associated target labels.
#       Synonyms: unsupervised machine learning
#     - unlabeled data: Data that lacks target labels or annotations and is typically used in unsupervised learning to find underlying structure.
#       Synonyms: unlabeled dataset, unlabelled data
#     - classification: A supervised learning task that assigns discrete category labels to input instances based on learned patterns.
#       Synonyms: classification task
#     - regression: A supervised learning task that predicts continuous numeric values for input instances.
#       Synonyms: regression task
#     - clustering: An unsupervised learning method that groups similar data instances into clusters based on feature similarity.
#       Synonyms: cluster analysis, clustering task
#     - TensorFlow: A deep learning framework for building and training neural network models, developed and maintained by Google.
#       Synonyms: TensorFlow (library), TF
#     - PyTorch: A deep learning framework and scientific computing library for building neural network models, developed and maintained by Meta.
#       Synonyms: PyTorch (library), torch (informal)
#     - Google: A multinational technology company that develops products and tools for internet services and machine learning, including TensorFlow.
#       Synonyms: Google LLC
#     - Meta: A multinational technology company (formerly Facebook, Inc.) involved in social media and research, and the creator/maintainer of PyTorch.
#       Synonyms: Meta Platforms, Facebook (former name)
#     - natural language processing: A subfield of artificial intelligence focused on enabling computers to understand, interpret, and generate human language through computational techniques.
#       Synonyms: NLP
#     - transformer model: A type of neural network architecture that uses attention mechanisms to process sequential data, enabling advanced language understanding and generation.
#       Synonyms: transformer neural network
#     - large language model: An advanced AI model trained on extensive text datasets that can generate human-like text, answer questions, and perform various language-related tasks.
#       Synonyms: LLM, large neural language model
#     - attention mechanism: A neural network technique that allows models to dynamically focus on different parts of input data when processing sequential information.
#       Synonyms:
#
#     CONTROLLED VOCABULARY PRINCIPLES:
#
#     1. **Term Selection**: Identify key concepts, entities, and domain-specific terms
#        - Focus on nouns and noun phrases
#        - Include technical/domain terms that need definition
#        - Skip common words that don't need clarification
#
#     2. **Preferred Label**: Choose the most standard/canonical form
#        - Use singular form for countable nouns
#        - Use the most commonly accepted spelling
#        - Prefer full terms over abbreviations (but list abbreviations as synonyms)
#
#     3. **Definition**: Write clear, concise definitions
#        - Start with the category: "A [category] that..."
#        - Include distinguishing characteristics
#        - Keep to 1-2 sentences
#
#     4. **Synonyms**: List alternative forms
#        - Abbreviations and acronyms
#        - Variant spellings
#        - Related terms that are used interchangeably in this context
#
#     5. **Domain**: Identify the subject area
#        - Be specific but not overly narrow
#        - Examples: "healthcare", "finance", "technology", "legal"
#
#     DEDUPLICATION:
#     - If a concept already exists in the existing vocabulary, do NOT create a duplicate
#     - Instead, you may suggest additional synonyms in your reasoning
#     - Generate unique term_ids using format: "term_[document_id]_[index]"
#
#     Answer in JSON using this schema:
#     {
#       // Extracted vocabulary terms with definitions
#       terms: [
#         {
#           // Unique identifier for this term
#           term_id: string,
#           // The canonical/preferred form of this term
#           preferred_label: string,
#           // Clear definition explaining what this term means in context
#           definition: string,
#           // Alternative terms or phrases that mean the same thing
#           synonyms: string[],
#           // The subject domain this term belongs to (e.g., 'medical', 'legal', 'technology')
#           domain: string or null,
#         }
#       ],
#       // Brief summary of the domains/topics covered in the text
#       domain_summary: string,
#       // Explanation of term selection and definition choices
#       reasoning: string,
#     }
#
#     ---LLM REPLY---
#     {
#       "terms": [
#         {
#           "term_id": "term_demo_doc_2_1",
#           "preferred_label": "computer vision",
#           "definition": "A field of technology that enables machines to interpret and understand visual information from images and videos, typically using algorithms and machine learning models.",
#           "synonyms": [
#             "computer vision (CV)"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_2",
#           "preferred_label": "convolutional neural network",
#           "definition": "A type of deep neural network that uses convolutional layers to automatically learn spatial hierarchies of features from image data and other grid-like inputs.",
#           "synonyms": [
#             "CNN"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_3",
#           "preferred_label": "object detection",
#           "definition": "A computer vision task that identifies and localizes instances of semantic objects (e.g., people, cars) within an image or video by producing bounding boxes and class labels.",
#           "synonyms": [
#             "object recognition (localization and classification)"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_4",
#           "preferred_label": "image classification",
#           "definition": "A computer vision task that assigns a single or multiple category label(s) to an entire image based on learned visual patterns.",
#           "synonyms": [
#             "image categorization"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_5",
#           "preferred_label": "semantic segmentation",
#           "definition": "A computer vision task that assigns a class label to each pixel in an image, producing a dense, per-pixel classification map of semantic regions.",
#           "synonyms": [
#             "pixel-wise classification"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_6",
#           "preferred_label": "You Only Look Once (YOLO)",
#           "definition": "A real-time object detection family of deep learning architectures that predict bounding boxes and class probabilities directly from full images in a single evaluation.",
#           "synonyms": [
#             "YOLO"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_7",
#           "preferred_label": "residual neural network",
#           "definition": "A deep learning architecture that uses residual (skip) connections to ease training of very deep neural networks by allowing gradients to flow more effectively.",
#           "synonyms": [
#             "ResNet",
#             "residual network"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_8",
#           "preferred_label": "autonomous vehicle",
#           "definition": "A transportation system that uses sensors, computer vision, and machine learning to perceive the environment and perform driving tasks with minimal or no human intervention.",
#           "synonyms": [
#             "self-driving vehicle",
#             "autonomous car"
#           ],
#           "domain": "transportation"
#         },
#         {
#           "term_id": "term_demo_doc_2_9",
#           "preferred_label": "medical imaging",
#           "definition": "An application area in healthcare that uses imaging technologies and image analysis methods, often including computer vision and machine learning, to visualize and diagnose medical conditions.",
#           "synonyms": [
#             "medical image analysis"
#           ],
#           "domain": "healthcare"
#         },
#         {
#           "term_id": "term_demo_doc_2_10",
#           "preferred_label": "facial recognition",
#           "definition": "A technology and application that uses computer vision and pattern recognition to detect and identify or verify an individual's identity from facial images or video.",
#           "synonyms": [
#             "face recognition",
#             "face identification"
#           ],
#           "domain": "security"
#         }
#       ],
#       "domain_summary": "The document covers topics in computer vision and related deep learning architectures (e.g., CNNs, ResNet, YOLO), core vision tasks (object detection, image classification, semantic segmentation), and applications including transportation (autonomous vehicles), healthcare (medical imaging), and security (facial recognition).",
#       "reasoning": "I extracted distinct, domain-relevant nouns and noun phrases from the text following the controlled vocabulary principles: preferring canonical full forms, singular nouns, concise category-led definitions, and listing common abbreviations as synonyms. I did not duplicate existing concepts already in the provided vocabulary (e.g., 'neural network', 'deep learning', 'machine learning'). Where a new concept is closely related to existing entries (for example, 'convolutional neural network' relates to the existing 'neural network' and 'deep learning' terms), I created a separate entry because it is a specific architecture type that warrants its own definition and added the common abbreviation 'CNN' as a synonym. For architecture names (YOLO and ResNet) I provided preferred labels in full form with their common acronyms as synonyms. For application areas I chose specific but not overly narrow domains (transportation, healthcare, security) to indicate the primary context in which those terms are used. Term IDs follow the required 'term_[document_id]_[index]' pattern."
#     }
#     ---Parsed Response (class VocabularyExtractionResult)---
#     {
#       "terms": [
#         {
#           "term_id": "term_demo_doc_2_1",
#           "preferred_label": "computer vision",
#           "definition": "A field of technology that enables machines to interpret and understand visual information from images and videos, typically using algorithms and machine learning models.",
#           "synonyms": [
#             "computer vision (CV)"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_2",
#           "preferred_label": "convolutional neural network",
#           "definition": "A type of deep neural network that uses convolutional layers to automatically learn spatial hierarchies of features from image data and other grid-like inputs.",
#           "synonyms": [
#             "CNN"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_3",
#           "preferred_label": "object detection",
#           "definition": "A computer vision task that identifies and localizes instances of semantic objects (e.g., people, cars) within an image or video by producing bounding boxes and class labels.",
#           "synonyms": [
#             "object recognition (localization and classification)"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_4",
#           "preferred_label": "image classification",
#           "definition": "A computer vision task that assigns a single or multiple category label(s) to an entire image based on learned visual patterns.",
#           "synonyms": [
#             "image categorization"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_5",
#           "preferred_label": "semantic segmentation",
#           "definition": "A computer vision task that assigns a class label to each pixel in an image, producing a dense, per-pixel classification map of semantic regions.",
#           "synonyms": [
#             "pixel-wise classification"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_6",
#           "preferred_label": "You Only Look Once (YOLO)",
#           "definition": "A real-time object detection family of deep learning architectures that predict bounding boxes and class probabilities directly from full images in a single evaluation.",
#           "synonyms": [
#             "YOLO"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_7",
#           "preferred_label": "residual neural network",
#           "definition": "A deep learning architecture that uses residual (skip) connections to ease training of very deep neural networks by allowing gradients to flow more effectively.",
#           "synonyms": [
#             "ResNet",
#             "residual network"
#           ],
#           "domain": "technology"
#         },
#         {
#           "term_id": "term_demo_doc_2_8",
#           "preferred_label": "autonomous vehicle",
#           "definition": "A transportation system that uses sensors, computer vision, and machine learning to perceive the environment and perform driving tasks with minimal or no human intervention.",
#           "synonyms": [
#             "self-driving vehicle",
#             "autonomous car"
#           ],
#           "domain": "transportation"
#         },
#         {
#           "term_id": "term_demo_doc_2_9",
#           "preferred_label": "medical imaging",
#           "definition": "An application area in healthcare that uses imaging technologies and image analysis methods, often including computer vision and machine learning, to visualize and diagnose medical conditions.",
#           "synonyms": [
#             "medical image analysis"
#           ],
#           "domain": "healthcare"
#         },
#         {
#           "term_id": "term_demo_doc_2_10",
#           "preferred_label": "facial recognition",
#           "definition": "A technology and application that uses computer vision and pattern recognition to detect and identify or verify an individual's identity from facial images or video.",
#           "synonyms": [
#             "face recognition",
#             "face identification"
#           ],
#           "domain": "security"
#         }
#       ],
#       "domain_summary": "The document covers topics in computer vision and related deep learning architectures (e.g., CNNs, ResNet, YOLO), core vision tasks (object detection, image classification, semantic segmentation), and applications including transportation (autonomous vehicles), healthcare (medical imaging), and security (facial recognition).",
#       "reasoning": "I extracted distinct, domain-relevant nouns and noun phrases from the text following the controlled vocabulary principles: preferring canonical full forms, singular nouns, concise category-led definitions, and listing common abbreviations as synonyms. I did not duplicate existing concepts already in the provided vocabulary (e.g., 'neural network', 'deep learning', 'machine learning'). Where a new concept is closely related to existing entries (for example, 'convolutional neural network' relates to the existing 'neural network' and 'deep learning' terms), I created a separate entry because it is a specific architecture type that warrants its own definition and added the common abbreviation 'CNN' as a synonym. For architecture names (YOLO and ResNet) I provided preferred labels in full form with their common acronyms as synonyms. For application areas I chose specific but not overly narrow domains (transportation, healthcare, security) to indicate the primary context in which those terms are used. Term IDs follow the required 'term_[document_id]_[index]' pattern."
#     }
# 2025-11-27T23:30:38.411 [BAML INFO] Function ExtractMetadataSchema:
#     Client: CustomHaiku (claude-3-5-haiku-20241022) - 8869ms. StopReason: end_turn. Tokens(in/out): 583/595
#     ---PROMPT---
#     user: You are an information architect specializing in metadata standards.
#     Analyze the document to identify metadata elements that describe its structure and content.DOCUMENT TEXT (sample):
#     Machine learning is a subset of artificial intelligence that enables computers
# ...
#             }
#           },
#           "source": {
#             "source_name": "sample_2.txt",
#             "source_url": null
#           },
#           "supporting_spans": [
#             {
#               "text": "Applications include autonomous vehicles, medical imaging, and facial recognition",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         }
#       ],
#       "reasoning": "Extracted triples focus on computer vision technologies, tasks, and applications. Linked computer vision to artificial intelligence, identified key architectures like CNNs, YOLO, and ResNet, and mapped their relationships to tasks like object detection and image classification. Captured application domains such as autonomous vehicles."
#     }
#     ---Parsed Response (class ExtractionResult)---
#     {
#       "triples": [
#         {
#           "subject": {
#             "name": "Computer Vision",
#             "type": "ResearchArea",
#             "description": "A scientific field focused on enabling machines to interpret and understand visual information from images and videos",
#             "custom_atts": {
#               "name": {
#                 "value": "Computer Vision",
#                 "type": "string"
#               },
#               "definition": {
#                 "value": "A field of artificial intelligence that enables machines to interpret and understand visual information",
#                 "type": "string"
#               },
#               "aliases": {
#                 "value": "machine vision, image understanding",
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "related_to",
#           "object": {
#             "name": "Artificial Intelligence",
#             "type": "ResearchArea",
#             "description": "A broad field of computer science focused on creating intelligent machines",
#             "custom_atts": {
#               "name": {
#                 "value": "Artificial Intelligence",
#                 "type": "string"
#               },
#               "definition": {
#                 "value": null,
#                 "type": "string"
#               },
#               "aliases": {
#                 "value": "AI",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "sample_2.txt",
#             "source_url": null
#           },
#           "supporting_spans": [
#             {
#               "text": "Computer vision enables machines to interpret and understand visual information from images and videos",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "Convolutional Neural Networks (CNNs)",
#             "type": "ModelArchitecture",
#             "description": "Neural network architecture specialized for processing visual and image data",
#             "custom_atts": {
#               "name": {
#                 "value": "Convolutional Neural Networks (CNNs)",
#                 "type": "string"
#               },
#               "description": {
#                 "value": "Neural network architecture specialized for processing visual and image data",
#                 "type": "string"
#               },
#               "typical_tasks": {
#                 "value": "image classification, object detection, semantic segmentation",
#                 "type": "string"
#               },
#               "notable_variants": {
#                 "value": "ResNet",
#                 "type": "string"
#               },
#               "primary_components": {
#                 "value": null,
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "performs_task",
#           "object": {
#             "name": "Object Detection",
#             "type": "Task",
#             "description": "A computer vision task of identifying and locating objects within an image",
#             "custom_atts": {
#               "name": {
#                 "value": "Object Detection",
#                 "type": "string"
#               },
#               "output_type": {
#                 "value": "bounding box",
#                 "type": "string"
#               },
#               "typical_modalities": {
#                 "value": "image",
#                 "type": "string"
#               },
#               "supervision": {
#                 "value": "supervised",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "sample_2.txt",
#             "source_url": null
#           },
#           "supporting_spans": [
#             {
#               "text": "Object detection, image classification, and semantic segmentation are key computer vision tasks",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "Convolutional Neural Networks (CNNs)",
#             "type": "ModelArchitecture",
#             "description": "Neural network architecture specialized for processing visual and image data",
#             "custom_atts": {
#               "name": {
#                 "value": "Convolutional Neural Networks (CNNs)",
#                 "type": "string"
#               },
#               "description": {
#                 "value": "Neural network architecture specialized for processing visual and image data",
#                 "type": "string"
#               },
#               "typical_tasks": {
#                 "value": "image classification, object detection, semantic segmentation",
#                 "type": "string"
#               },
#               "notable_variants": {
#                 "value": "ResNet",
#                 "type": "string"
#               },
#               "primary_components": {
#                 "value": null,
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "performs_task",
#           "object": {
#             "name": "Image Classification",
#             "type": "Task",
#             "description": "A computer vision task of categorizing images into predefined classes",
#             "custom_atts": {
#               "name": {
#                 "value": "Image Classification",
#                 "type": "string"
#               },
#               "output_type": {
#                 "value": "categorical label",
#                 "type": "string"
#               },
#               "typical_modalities": {
#                 "value": "image",
#                 "type": "string"
#               },
#               "supervision": {
#                 "value": "supervised",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "sample_2.txt",
#             "source_url": null
#           },
#           "supporting_spans": [
#             {
#               "text": "Object detection, image classification, and semantic segmentation are key computer vision tasks",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "Convolutional Neural Networks (CNNs)",
#             "type": "ModelArchitecture",
#             "description": "Neural network architecture specialized for processing visual and image data",
#             "custom_atts": {
#               "name": {
#                 "value": "Convolutional Neural Networks (CNNs)",
#                 "type": "string"
#               },
#               "description": {
#                 "value": "Neural network architecture specialized for processing visual and image data",
#                 "type": "string"
#               },
#               "typical_tasks": {
#                 "value": "image classification, object detection, semantic segmentation",
#                 "type": "string"
#               },
#               "notable_variants": {
#                 "value": "ResNet",
#                 "type": "string"
#               },
#               "primary_components": {
#                 "value": null,
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "performs_task",
#           "object": {
#             "name": "Semantic Segmentation",
#             "type": "Task",
#             "description": "A computer vision task of classifying each pixel in an image into a semantic category",
#             "custom_atts": {
#               "name": {
#                 "value": "Semantic Segmentation",
#                 "type": "string"
#               },
#               "output_type": {
#                 "value": "pixel mask",
#                 "type": "string"
#               },
#               "typical_modalities": {
#                 "value": "image",
#                 "type": "string"
#               },
#               "supervision": {
#                 "value": "supervised",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "sample_2.txt",
#             "source_url": null
#           },
#           "supporting_spans": [
#             {
#               "text": "Object detection, image classification, and semantic segmentation are key computer vision tasks",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "YOLO",
#             "type": "ModelArchitecture",
#             "description": "An object detection architecture known for real-time detection capabilities",
#             "custom_atts": {
#               "name": {
#                 "value": "YOLO",
#                 "type": "string"
#               },
#               "description": {
#                 "value": "Object detection architecture known for real-time detection capabilities",
#                 "type": "string"
#               },
#               "typical_tasks": {
#                 "value": "object detection",
#                 "type": "string"
#               },
#               "notable_variants": {
#                 "value": null,
#                 "type": "string"
#               },
#               "primary_components": {
#                 "value": null,
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "performs_task",
#           "object": {
#             "name": "Object Detection",
#             "type": "Task",
#             "description": "A computer vision task of identifying and locating objects within an image",
#             "custom_atts": {
#               "name": {
#                 "value": "Object Detection",
#                 "type": "string"
#               },
#               "output_type": {
#                 "value": "bounding box",
#                 "type": "string"
#               },
#               "typical_modalities": {
#                 "value": "image",
#                 "type": "string"
#               },
#               "supervision": {
#                 "value": "supervised",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "sample_2.txt",
#             "source_url": null
#           },
#           "supporting_spans": [
#             {
#               "text": "YOLO and ResNet are influential architectures in this field",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "ResNet",
#             "type": "ModelArchitecture",
#             "description": "A deep convolutional neural network architecture with residual learning",
#             "custom_atts": {
#               "name": {
#                 "value": "ResNet",
#                 "type": "string"
#               },
#               "description": {
#                 "value": "Deep convolutional neural network architecture with residual learning",
#                 "type": "string"
#               },
#               "typical_tasks": {
#                 "value": "image classification",
#                 "type": "string"
#               },
#               "notable_variants": {
#                 "value": null,
#                 "type": "string"
#               },
#               "primary_components": {
#                 "value": null,
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "performs_task",
#           "object": {
#             "name": "Image Classification",
#             "type": "Task",
#             "description": "A computer vision task of categorizing images into predefined classes",
#             "custom_atts": {
#               "name": {
#                 "value": "Image Classification",
#                 "type": "string"
#               },
#               "output_type": {
#                 "value": "categorical label",
#                 "type": "string"
#               },
#               "typical_modalities": {
#                 "value": "image",
#                 "type": "string"
#               },
#               "supervision": {
#                 "value": "supervised",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "sample_2.txt",
#             "source_url": null
#           },
#           "supporting_spans": [
#             {
#               "text": "YOLO and ResNet are influential architectures in this field",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         },
#         {
#           "subject": {
#             "name": "Object Detection",
#             "type": "Task",
#             "description": "A computer vision task of identifying and locating objects within an image",
#             "custom_atts": {
#               "name": {
#                 "value": "Object Detection",
#                 "type": "string"
#               },
#               "output_type": {
#                 "value": "bounding box",
#                 "type": "string"
#               },
#               "typical_modalities": {
#                 "value": "image",
#                 "type": "string"
#               },
#               "supervision": {
#                 "value": "supervised",
#                 "type": "string"
#               }
#             }
#           },
#           "predicate": "applied_in",
#           "object": {
#             "name": "Autonomous Vehicle",
#             "type": "ApplicationDomain",
#             "description": "An industry focusing on developing self-driving vehicles and related technologies",
#             "custom_atts": {
#               "name": {
#                 "value": "Autonomous Vehicle",
#                 "type": "string"
#               },
#               "examples_of_use": {
#                 "value": "self-driving cars, autonomous transportation",
#                 "type": "string"
#               },
#               "regulatory_or_safety_concerns": {
#                 "value": "safety, liability, ethical decision-making",
#                 "type": "string"
#               }
#             }
#           },
#           "source": {
#             "source_name": "sample_2.txt",
#             "source_url": null
#           },
#           "supporting_spans": [
#             {
#               "text": "Applications include autonomous vehicles, medical imaging, and facial recognition",
#               "start": null,
#               "end": null
#             }
#           ],
#           "extraction_datetime": null
#         }
#       ],
#       "reasoning": "Extracted triples focus on computer vision technologies, tasks, and applications. Linked computer vision to artificial intelligence, identified key architectures like CNNs, YOLO, and ResNet, and mapped their relationships to tasks like object detection and image classification. Captured application domains such as autonomous vehicles."
#     }
# ✓ vocabulary: 29 artifacts
# ✓ metadata: 36 artifacts
# ✓ taxonomy: 87 artifacts
# ✓ thesaurus: 38 artifacts
# ✓ ontology: 1 artifacts
# ✓ knowledge_graph: 29 artifacts

# %% [markdown]
# ## Step 4: Explore the Results
#
# ### Controlled Vocabulary

# %%
# Get the vocabulary stage and load terms
vocab_stage = orchestrator.get_stage(PipelineStage.VOCABULARY)
terms = vocab_stage.load_artifacts(corpus.corpus_id)

print(f"Extracted {len(terms)} vocabulary terms:\n")
for term in terms:
    print(f"• {term.preferred_label}")
    print(f"  Definition: {term.definition[:100]}...")
    if term.synonyms:
        print(f"  Synonyms: {', '.join(term.synonyms)}")
    print()
# Out:
# Extracted 29 vocabulary terms:
#
# • machine learning
#   Definition: A subfield of artificial intelligence that enables computers to improve performance on tasks by lear...
#   Synonyms: ML
#
# • artificial intelligence
#   Definition: A broad field of computer science that focuses on creating systems capable of performing tasks that ...
#   Synonyms: AI
#
# • deep learning
#   Definition: A subset of machine learning that uses neural networks with multiple layers to automatically learn h...
#   Synonyms: DL
#
# • neural network
#   Definition: A computational model that consists of interconnected layers of simple processing units (neurons) wh...
#   Synonyms: neural networks, NN
#
# • supervised learning
#   Definition: A category of machine learning that trains models using labeled examples so they can make prediction...
#   Synonyms: supervised machine learning
#
# • labeled training data
#   Definition: A dataset used for training supervised learning models in which each input instance is paired with a...
#   Synonyms: labeled data, training data (labeled)
#
# • unsupervised learning
#   Definition: A category of machine learning that discovers structure or patterns in data that have no associated ...
#   Synonyms: unsupervised machine learning
#
# • unlabeled data
#   Definition: Data that lacks target labels or annotations and is typically used in unsupervised learning to find ...
#   Synonyms: unlabeled dataset, unlabelled data
#
# • classification
#   Definition: A supervised learning task that assigns discrete category labels to input instances based on learned...
#   Synonyms: classification task
#
# • regression
#   Definition: A supervised learning task that predicts continuous numeric values for input instances....
#   Synonyms: regression task
#
# • clustering
#   Definition: An unsupervised learning method that groups similar data instances into clusters based on feature si...
#   Synonyms: cluster analysis, clustering task
#
# • TensorFlow
#   Definition: A deep learning framework for building and training neural network models, developed and maintained ...
#   Synonyms: TensorFlow (library), TF
#
# • PyTorch
#   Definition: A deep learning framework and scientific computing library for building neural network models, devel...
#   Synonyms: PyTorch (library), torch (informal)
#
# • Google
#   Definition: A multinational technology company that develops products and tools for internet services and machin...
#   Synonyms: Google LLC
#
# • Meta
#   Definition: A multinational technology company (formerly Facebook, Inc.) involved in social media and research, ...
#   Synonyms: Meta Platforms, Facebook (former name)
#
# • natural language processing
#   Definition: A subfield of artificial intelligence focused on enabling computers to understand, interpret, and ge...
#   Synonyms: NLP
#
# • transformer model
#   Definition: A type of neural network architecture that uses attention mechanisms to process sequential data, ena...
#   Synonyms: transformer neural network
#
# • large language model
#   Definition: An advanced AI model trained on extensive text datasets that can generate human-like text, answer qu...
#   Synonyms: LLM, large neural language model
#
# • attention mechanism
#   Definition: A neural network technique that allows models to dynamically focus on different parts of input data ...
#
# • computer vision
#   Definition: A field of technology that enables machines to interpret and understand visual information from imag...
#   Synonyms: computer vision (CV)
#
# • convolutional neural network
#   Definition: A type of deep neural network that uses convolutional layers to automatically learn spatial hierarch...
#   Synonyms: CNN
#
# • object detection
#   Definition: A computer vision task that identifies and localizes instances of semantic objects (e.g., people, ca...
#   Synonyms: object recognition (localization and classification)
#
# • image classification
#   Definition: A computer vision task that assigns a single or multiple category label(s) to an entire image based ...
#   Synonyms: image categorization
#
# • semantic segmentation
#   Definition: A computer vision task that assigns a class label to each pixel in an image, producing a dense, per-...
#   Synonyms: pixel-wise classification
#
# • You Only Look Once (YOLO)
#   Definition: A real-time object detection family of deep learning architectures that predict bounding boxes and c...
#   Synonyms: YOLO
#
# • residual neural network
#   Definition: A deep learning architecture that uses residual (skip) connections to ease training of very deep neu...
#   Synonyms: ResNet, residual network
#
# • autonomous vehicle
#   Definition: A transportation system that uses sensors, computer vision, and machine learning to perceive the env...
#   Synonyms: self-driving vehicle, autonomous car
#
# • medical imaging
#   Definition: An application area in healthcare that uses imaging technologies and image analysis methods, often i...
#   Synonyms: medical image analysis
#
# • facial recognition
#   Definition: A technology and application that uses computer vision and pattern recognition to detect and identif...
#   Synonyms: face recognition, face identification

# %% [markdown]
# ### Ontology

# %%
# Get the generated ontology
ontology_stage = orchestrator.get_stage(PipelineStage.ONTOLOGY)
ontology = ontology_stage.get_ontology(corpus.corpus_id)

if ontology:
    print(f"Generated ontology with:")
    print(f"  - {len(ontology.entity_types)} entity types")
    print(f"  - {len(ontology.relation_types)} relation types")
    print()
    
    print("Entity Types:")
    for et in ontology.entity_types:
        print(f"  • {et.name}: {et.description}")
    
    print("\nRelation Types:")
    for rt in ontology.relation_types:
        print(f"  • {rt.name}: {rt.domain} → {rt.range}")
# Out:
# Generated ontology with:
#   - 9 entity types
#   - 12 relation types
#
# Entity Types:
#   • ResearchArea: High-level scientific or technological field (e.g., artificial intelligence).
#   • Technique: A method, approach, or subfield used within a research area (e.g., machine learning, deep learning).
#   • ModelArchitecture: An architecture or model family for computation/learning (e.g., neural network, transformer, CNN, YOLO, ResNet, large language model).
#   • Framework: Software library or framework used to build/train models (e.g., TensorFlow, PyTorch, YOLO implementations).
#   • Organization: Commercial, academic, or non-profit organization involved in development or research (e.g., Google, Meta).
#   • Dataset: A dataset used for model training or evaluation, including information about labels (e.g., labeled training data, unlabeled data).
#   • Task: A concrete ML/AI task or problem (e.g., classification, regression, clustering, object detection, image classification, semantic segmentation, facial recognition).
#   • ApplicationDomain: An application area or industry where techniques and models are applied (e.g., autonomous vehicle, medical imaging, security).
#   • Component: A reusable functional component or mechanism used inside architectures (e.g., attention mechanism).
#
# Relation Types:
#   • is_subfield_of: Technique → ResearchArea
#   • specializes_in: Technique → Technique
#   • implements_architecture: Framework → ModelArchitecture
#   • developed_by: Framework → Organization
#   • trained_on: ModelArchitecture → Dataset
#   • performs_task: ModelArchitecture → Task
#   • applied_in: Task → ApplicationDomain
#   • has_component: ModelArchitecture → Component
#   • related_to: ResearchArea → Technique
#   • variant_of: ModelArchitecture → ModelArchitecture
#   • uses_framework: ModelArchitecture → Framework
#   • dataset_for: Dataset → Task

# %% [markdown]
# ## Summary
#
# This notebook demonstrated the complete Ontology Pipeline workflow:
#
# 1. Created a corpus to organize documents
# 2. Added sample documents about AI/ML
# 3. Ran all six pipeline stages
# 4. Explored the extracted artifacts:
#    - Controlled vocabulary with definitions
#    - Domain ontology with entity and relation types
#
# For production use:
# - Use `spindle-ingest` to properly ingest documents
# - Use `spindle-pipeline` CLI for batch processing
# - Access the REST API for integration with other systems
#
# ### Next Steps
# - Explore the full taxonomy, thesaurus, and knowledge graph
# - Try different extraction strategies (batch, sample-based)
# - Query the knowledge graph for insights
